# %%
import glob
import os
import numpy as np
import io
import pickle
import re
from keras.models import Model
from keras.preprocessing.text import Tokenizer
from keras.layers import Dense, Embedding, Input, LSTM
from keras.preprocessing.sequence import pad_sequences
from keras.optimizers import Adam, SGD
from keras.callbacks import Callback
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from itertools import groupby
from keras.models import model_from_json
# Out:
# Using TensorFlow backend.

# %%
from numpy.random import seed
seed(1)
from tensorflow import set_random_seed
set_random_seed(2)

# %%
regex = re.compile("article([0-9]+).*")

def loadDataTask3(folder):
    result = []
    fileNames = glob.glob(folder + "/*.txt")
    for fileName in fileNames:
        article = fileName.split("/")[-1].split(".")[0]
        # labels = readLabelTask3(folder + "/" + article + ".task3.labels")
        articleId = regex.match(article).group(1)
        f = open(fileName, "r", encoding="utf8")
        data = f.read()
        f.close()
        sentences = [x for x in data.split("\n") if x != ""]
        split = [x for x in splitWithIndices(data, "\n")]
        # result.append({"id": articleId, "data": data, "sentences": sentences, "labels": labels, "split": split})
        result.append({"id": articleId, "data": data, "sentences": sentences, "split": split})
        
    return result

def readLabelTask3(fileName):
    result = []
    f = open(fileName, "r")
    result = f.readlines()
    f.close()
    result = [x.replace("\n", "").split("\t") for x in result]
    return result

def splitWithIndices(s, c=' '):
    p = 0
    for k, g in groupby(s, lambda x:x==c):
        q = p + sum(1 for i in g)
        if not k:
            yield p, q # or p, q-1 if you are really sure you want that
        p = q

# %%
#dev_data = loadDataTask3("train-split/tasks-2-3/train-dev/")
dev_data = loadDataTask3("dev-INPUT/tasks-2-3/dev/")

# %%
### tokenization
with open('tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)
word2idx = tokenizer.word_index
idx2word = {v:k for k, v in word2idx.items()}
max_sequence_length = 129

# %%
label2index = {
    "Appeal_to_Authority": 0,
    "Appeal_to_fear-prejudice": 1,
    "Bandwagon": 2,
    "Black-and-White_Fallacy": 3,
    "Causal_Oversimplification": 4,
    "Doubt": 5,
    "Exaggeration,Minimisation": 6,
    "Flag-Waving": 7,
    "Loaded_Language": 8,
    "Name_Calling,Labeling": 9,
    "Obfuscation,Intentional_Vagueness,Confusion": 10,
    "Red_Herring": 11,
    "Reductio_ad_hitlerum": 12,
    "Repetition": 13,
    "Slogans": 14,
    "Straw_Men": 15,
    "Thought-terminating_Cliches": 16,
    "Whataboutism": 17
}

index2label = [
    "Appeal_to_Authority",
    "Appeal_to_fear-prejudice",
    "Bandwagon",
    "Black-and-White_Fallacy",
    "Causal_Oversimplification",
    "Doubt",
    "Exaggeration,Minimisation",
    "Flag-Waving",
    "Loaded_Language",
    "Name_Calling,Labeling",
    "Obfuscation,Intentional_Vagueness,Confusion",
    "Red_Herring",
    "Reductio_ad_hitlerum",
    "Repetition",
    "Slogans",
    "Straw_Men",
    "Thought-terminating_Cliches",
    "Whataboutism"
              ]

# %%
LATENT_DIM = 25

def updateSentence(sentence, char, start=None, stop=None):
    if start is None:
        start = 0;
        
    if stop is None:
        stop = len(sentence)
        
    s = list(sentence)
    for i in range(start, stop):
        if i < len(s):
            if s[i] in '!"#$%&()*+,-./:;<=>?@[\]^_`{|}~ ':
                s[i] = " "
            if s[i] not in [" ", "\n"]:
                s[i] = char
    return "".join(s)

def word2label(word):
    if word[0] == "A":
        return 0
    else:
        return 1
    
def sen2label(sen):
    result = [word2label(x) for x in sen if x != ""]
    return result

def predictModel(tokenizer, data, version, result, calcPerf=False):
    pred_X = []
    pred_loc = []
    for x in data:
        pred_X += x["sentences"]
        pred_loc += [(x["id"], y[0], y[1]) for y in x["split"]]
    
    input_sequences = pad_sequences(tokenizer.texts_to_sequences(pred_X),
                                    maxlen=max_sequence_length, padding='post')
    #output_sequences = pad_sequences(orig_Y, maxlen=max_sequence_length, padding='post')
    #output_sequences = np.reshape(output_sequences, output_sequences.shape + (1,))
    print('Shape of data tensor:', input_sequences.shape)
    #print('Shape of output tensor:', output_sequences.shape)
    
    # load json and create model
    json_file = open('model_prob_cnn_{:}.json'.format(version), 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    model = model_from_json(loaded_model_json)
    # load weights into new model
    model.load_weights('model_prob_cnn_{:}.h5'.format(version))
    print("Loaded model from disk")
    
    #with open('model_{:}_{:}.pickle'.format(label2index[label], version), 'rb') as handle:
    #    model = pickle.load(handle)
        
        
    z = np.zeros((len(input_sequences), LATENT_DIM))
    
    #pred_Y = model.predict([input_sequences, z, z]).round().astype(int)
    pred_Y = model.predict(input_sequences).round().astype(int)
    pred_Y = np.reshape(pred_Y, pred_Y.shape[:2])
    
    if calcPerf:
        act_Y = []
        for x in data:
            dataMask = updateSentence(x["data"], "A")
            for l in x["labels"]:
                dataMask = updateSentence(dataMask, "B", int(l[2]), int(l[3]))
            outcome = [sen2label(y.split(" ")) for y in dataMask.split("\n") if y != ""]
            act_Y += outcome
            
        output_sequences = pad_sequences(act_Y, maxlen=max_sequence_length, padding='post')
        print(f1_score(output_sequences, pred_Y, average='micro'))
        
        
    for i, x in enumerate(pred_Y):
        if sum(x) > 0:
            articleId = pred_loc[i][0]
            sen_start = pred_loc[i][1]
            sen = pred_X[i]
            pos = extractIndices(sen, x, sen_start)
            for p in pos:
                result.append([articleId, str(p[0]), str(p[1]), sen[(p[0] - sen_start):(p[1] - sen_start)]])
    return result

# %%
def extractIndices(sentence, pred, sen_start):
    s = list(sentence)
    for i in range(len(s)):
        if s[i] in '!"#$%&()*+,-./:;<=>?@[\]^_`{|}~ ':
            s[i] = " "
    #word split
    split = [x for x in splitWithIndices(s)]
    
    #pred indices
    idx = [i for i in range(len(split)) if pred[i] == 1]
    if len(idx) == 0:
        return []
    prev = None
    start = []
    end = []
    for x in idx:
        if prev is None:
            start.append(x)
        elif prev + 1 < x:
            end.append(prev)
            start.append(x)
        prev = x
    end.append(idx[-1])
    
    labels = [x for x in zip(start, end) if x[0] < x[1]]
    return [(split[l[0]][0] + sen_start, split[l[1]][1] + sen_start) for l in labels]
        
    
def predictLabel(data, version):
    with open('tokenizer_label.pickle', 'rb') as handle:
        tokenizer_label = pickle.load(handle)
    pred_X = [x[3] for x in data]
    max_sequence_length = 81
    input_sequences = pad_sequences(tokenizer_label.texts_to_sequences(pred_X),
                                    maxlen=max_sequence_length, padding='post')
    print('Shape of data tensor:', input_sequences.shape)
    
    # load json and create model
    json_file = open('model_label_cnn_{:}.json'.format(version), 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    model = model_from_json(loaded_model_json)
    # load weights into new model
    model.load_weights('model_label_cnn_{:}.h5'.format(version))
    print("Loaded model from disk")
    
    
    #pred_Y = model.predict([input_sequences, z, z]).round().astype(int)
    pred_Y = model.predict(input_sequences)
    pred_Y = [np.argmax(x) for x in pred_Y]
    
    result = []
    for i in range(len(pred_Y)):
        result.append([data[i][0], index2label[pred_Y[i]], data[i][1], data[i][2]])
    return result

def exportResult(result):
    with open("example-submission-task3-predictions_comb.txt", "w") as fout:
        for key, group in groupby(result, lambda x: x[0]):
            for thing in group:
                fout.write('\t'.join(thing[0:4]) + "\n")

# %%
result = []
result = predictModel(tokenizer, dev_data, "v1", result)
result = predictLabel(result, "v1")
#result = [x for x in result if x[1] not in ["Slogans", "Name_Calling,Labeling", "Loaded_Language"]]
#result = [x for x in result if x[1] not in ["Loaded_Language"]]
result = [x for x in result if x[1] not in ["Appeal_to_fear-prejudice", 
                                            "Appeal_to_Authority", 
                                            "Obfuscation,Intentional_Vagueness,Confusion",
                                            "Bandwagon",
                                            "Reductio_ad_hitlerum", 
                                            "Straw_Men", 
                                            "Whataboutism", 
                                            "Red_Herring", 
                                            "Repetition", 
                                            "Thought-terminating_Cliches", 
                                            "Slogans", 
                                            "Causal_Oversimplification"]]
exportResult(result)
# Out:
# Shape of data tensor: (2034, 129)
# Loaded model from disk
# Shape of data tensor: (856, 81)
# Loaded model from disk

# %%
rrr
# Out:
# [['697444415',
#   '168',
#   '217',
#   'shot in the pelvis during the horrific attack and'],
#  ['697444415', '745', '777', 'shooter, every other person that'],
#  ['697444415', '824', '831', 'as well'],
#  ['697444415', '937', '943', 'he ran'],
#  ['697444415', '1144', '1169', 'a sudden bullets are just'],
#  ['697444415', '1411', '1424', 'just going to'],
#  ['697444415', '2068', '2082', 'you get out of'],
#  ['697444415', '2376', '2384', 'was just'],
#  ['697444415', '2695', '2725', 'no, you can’t go out here, you'],
#  ['697444415', '2805', '2834', 'obviously a huge bombshell in'],
#  ['111111132', '147', '155', 'huge fan'],
#  ['111111132',
#   '246',
#   '296',
#   'play matching games about Bible stories and listen'],
#  ['111111132', '1771', '1808', 'and violates the personal consciences'],
#  ['111111132', '2262', '2292', 'beneficial and is a good thing'],
#  ['111111132', '2437', '2445', 'for some'],
#  ['111111132',
#   '2671',
#   '2738',
#   'religion, but it teaches character and respect and how important it'],
#  ['111111132',
#   '2892',
#   '2951',
#   'their backers argue that the program’s popularity shouldn’t'],
#  ['111111132',
#   '3251',
#   '3305',
#   'advocate the Ten Commandments and treat stories in the'],
#  ['111111132', '3440', '3461', 'of how safe and happy'],
#  ['111111132', '4313', '4320', 'to hell'],
#  ['111111132', '5436', '5475', 'mosque, but the vast majority of houses'],
#  ['111111132', '5731', '5768', 'fil-A billboard in Princeton, another'],
#  ['111111132', '5796', '5810', 'Heaven or Hell'],
#  ['111111132', '5878', '5899', 'in Princeton for more'],
#  ['111111132',
#   '6225',
#   '6332',
#   'not just poetry and prose in the Bible, but from what I’ve read almost every piece of history that’s in the'],
#  ['111111132',
#   '6404',
#   '6488',
#   'as a book of faith but as a pretty accurate account of history that informs us about'],
#  ['111111132', '6823', '6854', 'irrefutable lessons in morality'],
#  ['111111132',
#   '6945',
#   '7025',
#   'to get a whole lot of good ideas that are going to stick with you and make you a'],
#  ['111111132', '7580', '7607', 'a pretty clear violation of'],
#  ['111111132',
#   '7657',
#   '7736',
#   'and leadership responsible for spreading what she says is a false sense of what'],
#  ['111111132',
#   '8611',
#   '8720',
#   'are not a Christian, a Christian is a person who strives to be more Christ like with everything they do and I'],
#  ['111111132', '10118', '10124', 'have a'],
#  ['111111132', '10175', '10193', 'can have the Bible'],
#  ['111111132', '10867', '10885', 'and there are only'],
#  ['111111132',
#   '11654',
#   '11712',
#   'people of faith are doing their religion a disservice when'],
#  ['111111132',
#   '11867',
#   '11916',
#   'supporters of another religion wanted a course on'],
#  ['111111132',
#   '12018',
#   '12080',
#   'they need to remember that liberty of conscience is not up for'],
#  ['111111132', '12336', '12340', 'be a'],
#  ['698092698', '237', '247', 'forced him'],
#  ['698092698', '449', '461', 'murder of 58'],
#  ['698092698', '632', '643', 'about it or'],
#  ['706636401', '489', '533', 'Vegas Strip or attempting to stop those that'],
#  ['706636401', '1055', '1071', 'a “large amount”'],
#  ['706636401', '1390', '1396', 'can be'],
#  ['706636401', '1609', '1635', 'to show two men attempt to'],
#  ['706636401', '2689', '2719', 'muzzle flashes coming from the'],
#  ['706636401', '3368', '3391', 'following footage seems'],
#  ['706636401', '3666', '3695', 'so far never seen the footage'],
#  ['706636401',
#   '3837',
#   '3957',
#   'story has been proven, time and time again, to be absolutely false and in fact nothing more than a pathetic attempt at a'],
#  ['697454736', '810', '820', 'toward God'],
#  ['697454736',
#   '984',
#   '1039',
#   'a good theologian and a fine man, but he still seems to'],
#  ['697454736', '1267', '1295', 'life-state in which they are'],
#  ['697454736', '1381', '1397', 'states that “the'],
#  ['697454736',
#   '2900',
#   '2953',
#   'to show that Professors Brugger and Seifert are wrong'],
#  ['697454736', '3011', '3022', 'to continue'],
#  ['697454736',
#   '3287',
#   '3400',
#   'in the midst of great human limitations, can be more pleasing to God than a life which appears outwardly in order'],
#  ['697454736',
#   '4141',
#   '4189',
#   'such situations discern in conscience that He is'],
#  ['697454736', '4230', '4260', 'in the right direction—even if'],
#  ['697454736',
#   '4408',
#   '4455',
#   'It is sad that this beautiful and compassionate'],
#  ['697454736',
#   '4478',
#   '4531',
#   'been so completely misunderstood by scholars who have'],
#  ['697454736', '4809', '4816', 'show in'],
#  ['697454736',
#   '4932',
#   '4999',
#   'that a “move away from sin” is what is pleasing to God, even if the'],
#  ['697454736', '5511', '5524', 'would involve'],
#  ['697454736', '6026', '6044', '“remarried” people'],
#  ['697454736', '6401', '6423', 'and “remarried” people'],
#  ['697454736', '6608', '6628', 'what is happening in'],
#  ['697454736', '6833', '6872', 'not a mere ecclesiastical law, to which'],
#  ['697454736', '6882', '6893', 'is bound in'],
#  ['697454736', '6905', '6935', '“without exception”---is being'],
#  ['697454736',
#   '7080',
#   '7149',
#   'A moral catastrophe is self-evidently underway and it is not possible'],
#  ['697454736',
#   '7628',
#   '7674',
#   'of whom you insult with your superficial and I'],
#  ['697454736', '8083', '8096', 'should follow'],
#  ['697454736',
#   '8153',
#   '8240',
#   'heart and mind, but above all with open eyes, for you have clearly shut them to what is'],
#  ['697454736', '10019', '10042', "don't know exactly what"],
#  ['697454736', '11482', '11513', 'dictates of the Immortal God in'],
#  ['697454736', '11709', '11739', 'admission of public adulterers'],
#  ['697454736', '11835', '11843', 'woman he'],
#  ['697454736', '11956', '11979', 'afraid Dr. Fastiggi has'],
#  ['697454736', '12049', '12058', 'him, I am'],
#  ['697454736',
#   '12525',
#   '12571',
#   'comprehension of pertinent ecclesiological and'],
#  ['696264594',
#   '0',
#   '65',
#   'The American Jewish Historical Society Hosts Destroy Israel Event'],
#  ['696264594',
#   '144',
#   '230',
#   'investigative journalist and writer focusing on the radical left and Islamic terrorism'],
#  ['696264594', '368', '377', 'Voice for'],
#  ['696264594', '393', '403', 'Israel BDS'],
#  ['696264594', '409', '427', 'group that defends'],
#  ['696264594', '471', '502', 'an anti-Semite who accused Jews'],
#  ['696264594',
#   '993',
#   '1143',
#   'Islamic anti-Semitism by claiming that the “distrust Moslems feel towards Jews” is due to “two acts of betrayal by Jewish tribes against the Prophet.”'],
#  ['696264594',
#   '1382',
#   '1504',
#   'Jewish community gradually consolidated its power, wealth, and influence in all sectors of society" especially in "crucial'],
#  ['696264594',
#   '1662',
#   '1708',
#   'strengthens “conspiracy theories about ‘Jewish'],
#  ['696264594',
#   '1890',
#   '1989',
#   'The American Jewish Historical Society is co-sponsoring a JVP anti-Israel event by two opponents of'],
#  ['696264594',
#   '2065',
#   '2117',
#   'Emma Lazarus Award, named after a passionate Zionist'],
#  ['696264594', '2289', '2328', 'didn’t endorse Israel, but some sort of'],
#  ['696264594', '2386', '2413', 'well for the Christians and'],
#  ['696264594',
#   '2439',
#   '2484',
#   'The American Jewish Historical Society is not'],
#  ['696264594', '2506', '2524', 'one-state event by'],
#  ['696264594', '3637', '3642', 'if he'],
#  ['696264594', '3673', '3681', 'that CJH'],
#  ['696264594',
#   '3719',
#   '3775',
#   'JVP event featured Efrat Yerday, an anti-Israel activist'],
#  ['696264594', '3842', '3861', 'not only dispossess'],
#  ['696264594', '3880', '3903', 'it also dispossesses in'],
#  ['696264594', '4630', '4642', 'The American'],
#  ['696264594', '4650', '4668', 'Historical Society'],
#  ['696264594', '5183', '5221', 'anti-Israel hate group IfNotNow, which'],
#  ['696264594', '5564', '5571', 'what is'],
#  ['696264594',
#   '5760',
#   '5860',
#   'of shocking behavior is taking place inside Jewish organizations whose inner workings most people in'],
#  ['696264594', '5922', '5964', 'Unlike CJH, the American Jewish Historical'],
#  ['696264594',
#   '6047',
#   '6134',
#   'the radical anti-Jewish and anti-Israel left to serve anti-Semitic narratives is tragic'],
#  ['696264594', '6452', '6463', 'anti-Israel'],
#  ['696264594', '6742', '6761', 'a woman who accused'],
#  ['696264594',
#   '6830',
#   '6880',
#   'leftists at the AJHS are clearly not leaving their'],
#  ['696264594', '7113', '7148', 'When the American Jewish Historical'],
#  ['696264594', '7197', '7231', 'hate group attacking the existence'],
#  ['696264594', '7283', '7315', 'terrorism and anti-Semitism, the'],
#  ['696264594', '7384', '7423', 'and those who want to destroy Israel or'],
#  ['696264594',
#   '7447',
#   '7508',
#   'Israel radicalism of the left grows, such choices will become'],
#  ['696264594', '7596', '7636', 'Israel left makes many important enemies'],
#  ['696264594', '7699', '7743', 'that can blacklist, smear and silence almost'],
#  ['696264594',
#   '7863',
#   '7908',
#   'When we think about Nazi Germany, we remember'],
#  ['696264594',
#   '7963',
#   '8039',
#   'too intimidated and uncertain to rise against anti-Semitism when they saw it'],
#  ['696264594',
#   '8075',
#   '8127',
#   'so many people are afraid to do the right thing when'],
#  ['696264594', '8153', '8184', 'us how irrelevant history makes'],
#  ['696264594',
#   '8218',
#   '8367',
#   'the Center for Jewish History and the American Jewish Historical Society, for those on the inside who see the corruption of their organizations every'],
#  ['696264594', '8493', '8504', 'out against'],
#  ['696264594', '8602', '8646', 'libels and a speaker who defends Hamas, when'],
#  ['696735702', '233', '241', 'dead and'],
#  ['696735702', '890', '906', 'massacre because'],
#  ['696735702', '3366', '3380', 'adrenaline and'],
#  ['111111113', '102', '127', "— here's the story behind"],
#  ['111111113', '259', '288', 'firestorm of outrage Thursday'],
#  ['111111113', '296', '328', 'as top conservatives and critics'],
#  ['111111113', '1846', '1853', 'do harm'],
#  ['111111113', '2046', '2054', 'the most'],
#  ['111111113', '2140', '2151', 'and history'],
#  ['111111113',
#   '3823',
#   '3884',
#   'that politicians across this country continue to endanger the'],
#  ['111111113',
#   '3904',
#   '3961',
#   'with sanctuary policies while ignoring the harm inflicted'],
#  ['111111113', '4026', '4034', 'over not'],
#  ['111111113', '4259', '4273', 'place too much'],
#  ['111111113', '4865', '4893', 'Steinle would still be alive'],
#  ['111111113', '5668', '5686', 'being violent, and'],
#  ['111111113', '5745', '5762', 'complete travesty'],
#  ['111111113', '5856', '5900', "of a violent crime before Steinle's shooting"],
#  ['111111113',
#   '6256',
#   '6319',
#   'They have both condemned Trump for "sensationalizing" Steinle\'s'],
#  ['697959084',
#   '188',
#   '249',
#   'story surrounding the worst mass shooting in American history'],
#  ['697959084', '1309', '1339', 'done everything in their power'],
#  ['697959084', '1522', '1546', 'mistake in my mind about'],
#  ['697959084', '1826', '1838', 'crescendo of'],
#  ['697959084', '2143', '2175', 'see the screams and see hundreds'],
#  ['697959084',
#   '2808',
#   '2887',
#   'that authorities have lied to the American people about the worst mass shooting'],
#  ['697959084', '2948', '2983', 'the reasons for these lies actually'],
#  ['695833178', '1510', '1534', 'the horrific shooting DO'],
#  ['695833178',
#   '1992',
#   '2080',
#   'This throws their entire narrative into question and makes one wonder what else is being'],
#  ['695833178', '2395', '2410', 'literally every'],
#  ['695833178', '2510', '2538', 'cannot be trusted and should'],
#  ['695833178',
#   '2610',
#   '2695',
#   'really did act alone and this evidence is some sort of mistake, there is surely video'],
#  ['695833178',
#   '3136',
#   '3182',
#   'in the worst mass shooting in American history'],
#  ['697472447',
#   '494',
#   '549',
#   'this alleged hero, even though we’ve already seen crime'],
#  ['697472447', '1012', '1051', 'the gunman and causing him to panic and'],
#  ['697472447', '1921', '1936', '“random patrol”'],
#  ['697472447', '2376', '2408', 'media we do not feel comfortable'],
#  ['697472447', '2710', '2746', 'of what happened ahead of the attack'],
#  ['697472447', '3397', '3440', 'so why change the narrative to make it even'],
#  ['111111124', '3902', '3918', 'Russian meddling'],
#  ['111111124', '4331', '4361', 'team and thinks will advance a'],
#  ['111111124',
#   '4646',
#   '4751',
#   'consequence to a President who cares about nothing about the country and everything about his narrow self'],
#  ['111111137', '2660', '2676', 'turning point in'],
#  ['704856340',
#   '399',
#   '520',
#   'once again calling into question almost every aspect of what actually happened during the worst mass shooting in American'],
#  ['704856340', '1826', '1869', 'shooter was pinned down or “just sheltering'],
#  ['704856340', '1926', '1937', 'as Ambellas'],
#  ['704856340',
#   '4099',
#   '4165',
#   'despite authorities desperately trying to prevent it from reaching'],
#  ['704856340', '4218', '4237', 'one that includes a'],
#  ['704856340',
#   '4247',
#   '4314',
#   'amount of evidence pointing towards a classic deep state false flag'],
#  ['698018235', '229', '259', 'The American Jewish Historical'],
#  ['698018235',
#   '268',
#   '329',
#   'was caught collaborating with JVP; a radical anti-Israel hate'],
#  ['698018235', '535', '544', 'Voice for'],
#  ['698018235', '560', '570', 'Israel BDS'],
#  ['698018235', '576', '594', 'group that defends'],
#  ['698018235', '638', '669', 'an anti-Semite who accused Jews'],
#  ['698018235', '756', '776', 'a Jewish Homeland or'],
#  ['698018235', '1487', '1513', 'Israel hate sites like the'],
#  ['698018235', '1560', '1573', 'accustomed to'],
#  ['698018235',
#   '1659',
#   '1751',
#   'Any Jew who opposes the Occupation — or opposes Zionism itself — knows that feeling of being'],
#  ['698018235', '2088', '2109', 'noble to stand up for'],
#  ['698018235',
#   '2146',
#   '2214',
#   'institutions — particularly the American Jewish Historical Society —'],
#  ['698018235', '2234', '2277', 'dissent, and effectively exclude all Jewish'],
#  ['698018235',
#   '2283',
#   '2339',
#   'Zionists, then they have not only lost a rapidly growing'],
#  ['698018235',
#   '2484',
#   '2532',
#   'like Dan Fishback are entitled to exploit Jewish'],
#  ['698018235',
#   '2550',
#   '2606',
#   'propoaganda... even while they advocate a boycott of the'],
#  ['698018235',
#   '2736',
#   '2797',
#   'boycotting his play is a violation of Jewishness because Jews'],
#  ['698018235',
#   '2863',
#   '2949',
#   'argument that Jews are supposed to welcome is that of people who hate the existence of'],
#  ['698018235', '2969', '3000', 'Not of Jewish nationhood itself'],
#  ['698018235',
#   '3070',
#   '3122',
#   'a propaganda campaign that was intentionally crafted'],
#  ['698018235',
#   '3315',
#   '3373',
#   'campaign intended to attack the human rights of the Jewish'],
#  ['698018235', '3464', '3483', "what's good for the"],
#  ['698018235', '3591', '3622', "Jewish community won't let them"],
#  ['111111134', '321', '367', 'Lawyers for Assange and Manafort denounced the'],
#  ['111111134',
#   '471',
#   '544',
#   'campaign and WikiLeaks, which released tens of thousands of emails stolen'],
#  ['111111134', '622', '642', 'to undermine Trump’s'],
#  ['111111134', '1087', '1096', 'or anyone'],
#  ['111111134', '1483', '1506', 'that Manafort never met'],
#  ['111111134', '1585', '1597', 'Guardian for'],
#  ['111111134', '1776', '1785', 'to Sweden'],
#  ['703821117', '186', '216', 'the most ingenious and cunning'],
#  ['703821117', '2367', '2402', 'the nation’s democratically elected'],
#  ['703821117', '2700', '2736', 'it targeted for assassination, there'],
#  ['703821117', '2925', '2934', 'States or'],
#  ['703821117', '3923', '3960', 'assassination was even more brilliant'],
#  ['703821117', '4731', '4775', 'Why frame an innocent man who is situated in'],
#  ['703821117', '5053', '5077', 'cunningness of the cover'],
#  ['703821117', '5164', '5179', 'that could mean'],
#  ['703821117', '6046', '6081', 'who almost certainly are Soviet and'],
#  ['703821117', '6316', '6322', 'of war'],
#  ['703821117', '6324', '6346', 'That means nuclear war'],
#  ['703821117', '6386', '6397', 'no way that'],
#  ['703821117', '6534', '6542', 'part and'],
#  ['703821117', '6690', '6707', 'the assassination'],
#  ['703821117',
#   '10062',
#   '10111',
#   'don’t know but I certainly felt quite comfortable'],
#  ['703821117', '10469', '10488', 'commentators should'],
#  ['703821117', '11099', '11105', 'A liar'],
#  ['703821117',
#   '11607',
#   '11664',
#   'duty to violate their nation’s constitution and violently'],
#  ['703821117', '12003', '12034', 'admitted perjurer and convicted'],
#  ['703821117',
#   '12582',
#   '12643',
#   'Marines hated communists and had just helped kill millions of'],
#  ['703821117', '12680', '12705', 'genuine communist want to'],
#  ['703821117', '12845', '12864', 'Union, or Europe to'],
#  ['703821117', '12908', '12917', 'height of'],
#  ['703821117', '12988', '13006', 'Union and promised'],
#  ['703821117', '13125', '13144', 'in the country, and'],
#  ['703821117', '13324', '13355', 'abuse, humiliate, persecute, or'],
#  ['703821117',
#   '13450',
#   '13501',
#   'Manning, Edward Snowden, and other people they have'],
#  ['703821117', '13782', '13794', 'communism in'],
#  ['703821117',
#   '13807',
#   '13862',
#   'is able to saunter across the Cold War stage of history'],
#  ['703821117',
#   '13868',
#   '13916',
#   'long after the McCarthy hearings, without nary a'],
#  ['703821117', '14568', '14581', 'could be only'],
#  ['703821117', '15071', '15081', 'Things are'],
#  ['703821117', '15093', '15104', 'going to go'],
#  ['703821117', '15550', '15559', 'he really'],
#  ['703821117',
#   '16182',
#   '16226',
#   'That’s where ingenuity and cunning come into'],
#  ['703821117',
#   '16477',
#   '16536',
#   'supposed communist confederates in the front, which in turn'],
#  ['703821117', '16785', '16827', 'of the most brilliant and cunning ruses in'],
#  ['703821117', '16978', '17013', 'secret fraudulent and bogus autopsy'],
#  ['703821117', '17195', '17232', 'a conspiracy because it might lead to'],
#  ['703821117', '17639', '17675', 'that the assassination could lead to'],
#  ['703821117',
#   '17954',
#   '18009',
#   'secret for decades, when many people won’t care anymore'],
#  ['703821117', '18232', '18245', 'who questions'],
#  ['703821117', '18285', '18302', 'sympathizer” or a'],
#  ['703821117', '18326', '18363', 'The CIA’s cunning cover-up in the JFK'],
#  ['703821117', '18504', '18530', 'secret records secret from'],
#  ['703821117',
#   '18535',
#   '18613',
#   'American people, the CIA’s cunning cover-up of the JFK assassination continues'],
#  ['111111131', '321', '351', 'to a triumphant outcome in his'],
#  ['111111131',
#   '761',
#   '830',
#   "one of America's longtime adversaries will forever illustrate Trump's"],
#  ['111111131', '1830', '1857', 'fast as it can mechanically'],
#  ['111111131',
#   '1971',
#   '2020',
#   'Kim, a brutal dictator responsible for the deaths'],
#  ['111111131', '2041', '2059', 'citizens but of at'],
#  ['111111131', '2911', '2916', 'a big'],
#  ['111111131',
#   '3768',
#   '3850',
#   'people in the world will think of this as a (inaudible) form of fantasy ... from a'],
#  ['111111131', '4158', '4170', 'talented man'],
#  ['111111131', '4241', '4275', 'Trump continued praising the North'],
#  ['111111131', '4300', '4306', 'to run'],
#  ['111111131', '4450', '4465', 'run it, and run'],
#  ['111111131',
#   '4636',
#   '4700',
#   "striking warmth given Kim's iron grip on power and dismal record"],
#  ['111111131',
#   '4770',
#   '4935',
#   'for normalizing a regime routinely called out for its human rights abuses, that over years has built an image of fearsome renegade regime, throwing around threats of'],
#  ['111111131',
#   '5468',
#   '5519',
#   'taunts, ratcheting up tensions and leading to fears'],
#  ['111111131',
#   '6878',
#   '6947',
#   'pictures beamed around the world reflect a commanding leader making a'],
#  ['111111131', '7133', '7141', 'a highly'],
#  ['703698295', '339', '349', 'the status'],
#  ['703698295',
#   '856',
#   '932',
#   'lack of clarity inevitably risks sinning against the Holy Spirit, the Spirit'],
#  ['703698295',
#   '1027',
#   '1115',
#   'not merely open to those who hold views counter to Christian belief, but who support and'],
#  ['703698295', '1570', '1593', 'criticism, but that you'],
#  ['703698295', '1662', '1676', 'fear they will'],
#  ['703698295',
#   '1871',
#   '1971',
#   'the irony: how a man expressing grave concerns that there is an atmosphere of fear of being punished'],
#  ['703698295',
#   '2029',
#   '2079',
#   'Perhaps the most astonishing aspect of this little'],
#  ['703698295', '2092', '2117', 'just how completely blind'],
#  ['703698295', '2276', '2298', 'it looks extremely bad'],
#  ['703698295', '2314', '2347', 'fog of irony weren’t thick enough'],
#  ['703698295', '2455', '2470', 'cabal have done'],
#  ['703698295', '2693', '2703', 'and vulgar'],
#  ['703698295',
#   '2975',
#   '3039',
#   'the outrage is doing the opposite of dying down, and is surely a'],
#  ['703698295', '3056', '3075', 'up Catholics – even'],
#  ['703698295',
#   '3092',
#   '3138',
#   'never identify themselves as Traditionalists –'],
#  ['703698295',
#   '3811',
#   '3867',
#   'nor a controversialist, but a humble and straightforward'],
#  ['703698295', '3972', '3995', 'if we were not see more'],
#  ['703698295',
#   '4058',
#   '4118',
#   'it’s going to become harder and harder for men of conscience'],
#  ['703698295', '5310', '5338', 'even mock” critics of Amoris'],
#  ['703698295', '5429', '5453', 'so is committing a “kind'],
#  ['703698295', '5570', '5582', 'of reprisals'],
#  ['703698295',
#   '5644',
#   '5728',
#   'The letter “expresses the concerns of many more people than just me, ordinary people'],
#  ['703698295', '5846', '5872', 'I believe God wanted me to'],
#  ['703698295', '6100', '6107', 'weak is'],
#  ['703698295',
#   '6680',
#   '6781',
#   'conservative writers as a beleaguered champion of Catholic orthodoxy persecuted by the regime for his'],
#  ['703698295',
#   '6928',
#   '6983',
#   'clearly show his complete inability to make up his mind'],
#  ['703698295',
#   '7073',
#   '7124',
#   'irresolute and ultimately calculating mind of a man'],
#  ['703698295', '7691', '7704', 'buzzwords and'],
#  ['703698295', '8047', '8060', 'longer sinful'],
#  ['703698295',
#   '8180',
#   '8226',
#   'how exactly it makes adultery and sacrilege OK'],
#  ['703698295', '8470', '8511', 'hard case of the poor, poor woman who has'],
#  ['703698295',
#   '8540',
#   '8629',
#   'husband, and who “finds no other way out than to entrust oneself to a kind-hearted person'],
#  ['703698295', '8767', '8809', 'a “marriage-like relationship” about which'],
#  ['703698295', '8829', '8851', 'be very careful not to'],
#  ['703698295', '8929', '8953', '“cheap adaptation to the'],
#  ['703698295',
#   '8986',
#   '9031',
#   'side, and a “cold application of the dogmatic'],
#  ['703698295', '9151', '9192', 'of the flesh aren’t the worst things ever'],
#  ['703698295', '9211', '9232', '“different levels” of'],
#  ['703698295',
#   '9301',
#   '9388',
#   '“Spirit’s sins” like spiritual pride and avarice and stuff, are worse than “sins of the'],
#  ['703698295', '9438', '9447', 'of “human'],
#  ['703698295',
#   '9526',
#   '9614',
#   'that the Kasperian kerfuffle has totally been blown way, way, WAY out of proportion, and'],
#  ['703698295', '9797', '9816', 'a decisive question'],
#  ['703698295', '9836', '9860', 'a measure of ideological'],
#  ['703698295', '10189', '10225', 'into schism if they didn’t get their'],
#  ['703698295', '10570', '10590', 'imagine anyone being'],
#  ['703698295',
#   '10945',
#   '10991',
#   'what can easily be seen as a desperate attempt'],
#  ['703698295', '11194', '11199', 'be to'],
#  ['703698295',
#   '11308',
#   '11354',
#   'become harder and harder for men of conscience'],
#  ['703698295', '11368', '11374', 'to sit'],
#  ['703698295', '11658', '11692', '“If you want me to write something'],
#  ['703698295', '11974', '11983', 'must meet'],
#  ['703698295', '11997', '12012', 'I know but have'],
#  ['703698295', '12017', '12036', 'seen in a very long'],
#  ['703698295', '12199', '12211', 'to me, ‘Keep'],
#  ['703698295', '12458', '12476', 'right words, “Keep'],
#  ['703698295', '12506', '12512', 'was no'],
#  ['701939679', '1760', '1766', 'him as'],
#  ['701939679', '1772', '1815', 'of the guys.” “He wasn’t someone who was an'],
#  ['694327499', '66', '76', 'year-and-a'],
#  ['694327499', '302', '348', 'Yet conscience can do more than recognize that'],
#  ['694327499',
#   '376',
#   '428',
#   'correspond objectively to the overall demands of the'],
#  ['694327499',
#   '464',
#   '554',
#   'sincerity and honesty what for now is the most generous response which can be given to God'],
#  ['694327499', '568', '576', 'see with'],
#  ['694327499',
#   '579',
#   '639',
#   'certain moral security that it is what God himself is asking'],
#  ['694327499', '762', '806', '“inform” a sinner that his continued sinning'],
#  ['694327499', '814', '853', 'only acceptable to God but is even what'],
#  ['694327499', '912', '927', 'This outrageous'],
#  ['694327499', '973', '987', 'strikes at the'],
#  ['694327499',
#   '1377',
#   '1427',
#   'critics of AL are wrong—every one of them!—because'],
#  ['694327499',
#   '2469',
#   '2537',
#   'a moment: how can objectively immoral behavior ever be characterized'],
#  ['694327499',
#   '2628',
#   '2769',
#   'English because it suggests that falling short of what the moral law requires is an oblation pleasing to God if one’s “limits” make obedience'],
#  ['694327499', '2831', '2874', 'Fastiggi and Goldstein expect us to swallow'],
#  ['694327499',
#   '2929',
#   '3013',
#   'objectively sinful action but a gift of self that moves toward God and the objective'],
#  ['694327499',
#   '3059',
#   '3152',
#   'What the Pope Really Means® would have us believe that objectively immoral behavior, which is'],
#  ['694327499',
#   '3225',
#   '3301',
#   '” is no longer simply objectively immoral behavior but rather a gift of self'],
#  ['694327499', '3398', '3433', 'problem even worse in their attempt'],
#  ['694327499',
#   '3649',
#   '3698',
#   'Do not all those ignorant critics of AL know that'],
#  ['694327499',
#   '3726',
#   '3799',
#   'phrase “obiectivum exemplar,” which, translated literally into English is'],
#  ['694327499', '4410', '4423', 'than divinely'],
#  ['694327499',
#   '4452',
#   '4541',
#   'that binds all men—including Thou Shalt Not Commit Adultery—then basic morality becomes a'],
#  ['694327499', '4766', '4772', 'So, as'],
#  ['694327499',
#   '4782',
#   '4849',
#   'and Goldstein would have it, all the tumult triggered by AL is just'],
#  ['694327499',
#   '5046',
#   '5110',
#   'What the Pope Really Means® is that objectively immoral behavior'],
#  ['694327499', '5375', '5410', 'It seems Fastiggi and Goldstein are'],
#  ['694327499', '5704', '5712', 'Now, how'],
#  ['694327499', '5791', '5798', 'Are you'],
#  ['694327499', '5838', '5875', 'precisely the ones Our Lord condemned'],
#  ['694327499', '5972', '5998', 'truths need not impede the'],
#  ['694327499', '6857', '6888', 'continence is required of those'],
#  ['694327499', '7212', '7229', 'marriages” do not'],
#  ['694327499',
#   '8054',
#   '8122',
#   'manages, with an informed and enlightened conscience, to acknowledge'],
#  ['694327499', '8338', '8362', 'a deliberately ambiguous'],
#  ['694327499', '8642', '8665', '“bent into some kind of'],
#  ['694327499', '8705', '8722', 'responsibility to'],
#  ['694327499',
#   '8906',
#   '8983',
#   'readers—while others disagree—has by that very fact inflicted grave harm upon'],
#  ['694327499',
#   '9510',
#   '9581',
#   'the Correctio] are saying is that it has become clear that orthodoxy is'],
#  ['694327499',
#   '9657',
#   '9702',
#   'is doing is worse than explicit heresy, which'],
#  ['694327499',
#   '9817',
#   '9879',
#   'Holy Matrimony, Confession and Holy Communion, whose integrity'],
#  ['694327499',
#   '10165',
#   '10211',
#   'spread of the Monothelite heresy (no human but'],
#  ['694327499', '10313', '10345', 'the heresy, endorsing the heresy'],
#  ['694327499', '11455', '11497', 'has never been the humble apostle of mercy'],
#  ['694327499',
#   '11524',
#   '11618',
#   'crafted public relations narrative, but rather a cunning ecclesiastical politician, constantly'],
#  ['694327499',
#   '11791',
#   '11860',
#   'in the long annals of its shameful defense of the indefensible to the'],
#  ['695108099', '1579', '1605', 'be on the hunt for whoever'],
#  ['696694316', '167', '213', 'place I saw anyone say that the body and blood'],
#  ['696694316', '472', '512', 'they believe about it came as a bit of a'],
#  ['696694316', '614', '629', 'and unappealing'],
#  ['696694316', '906', '947', 'an important marker of a critical turning'],
#  ['696694316', '1354', '1389', 'unity of faith and of love, drawing'],
#  ['696694316', '1514', '1530', 'religion, I knew'],
#  ['696694316', '1797', '1805', 'and said'],
#  ['696694316',
#   '1819',
#   '1871',
#   'astounding, something so completely unlikely, that I'],
#  ['696694316', '2004', '2048', 'this pope was either mad, bad or telling the'],
#  ['696694316',
#   '2355',
#   '2405',
#   'of His Body and Blood, to perpetuate the sacrifice'],
#  ['696694316', '2497', '2525', 'beloved spouse, the memorial'],
#  ['696694316', '2645', '2663', 'Christ is received'],
#  ['696694316', '2790', '2815', 'sacrifice, which pertains'],
#  ['696694316', '2954', '2973', 'Flesh of Christ and'],
#  ['696694316', '3103', '3144', 'upon reading this shocking statement… “By'],
#  ['696694316', '3311', '3341', 'exposition, and in part on the'],
#  ['696694316', '3411', '3455', 'reason to say anything as wild as this if it'],
#  ['696694316',
#   '3539',
#   '3593',
#   'possibly the strangest and most earth shattering thing'],
#  ['696694316',
#   '3624',
#   '3809',
#   'out of a kind of swamp of intellectual worldliness; presenting the idea to my thirsty mind that there could indeed be fantastic realities far more wonderful than the banal and painfully'],
#  ['696694316', '3927', '3962', 'yes, there were fairies and magical'],
#  ['696694316',
#   '4423',
#   '4500',
#   'it was ridiculous and where it was wrong and political it was outright wicked'],
#  ['696694316', '4553', '4561', 'the most'],
#  ['696694316', '4570', '4599', 'identifiable moment of actual'],
#  ['696694316', '4867', '4896', 'by a single thought: “I could'],
#  ['696694316', '4929', '4955', 'an unlikely thing to think'],
#  ['696694316',
#   '5066',
#   '5126',
#   'things from people who clearly hated the Church; her enemies'],
#  ['696694316', '5163', '5177', 'convict on the'],
#  ['696694316', '5336', '5378', 'about it that didn’t come from her enemies'],
#  ['696694316', '6050', '6093', 'forced me to face up to a reality I’d never'],
#  ['696694316', '6124', '6165', 'the little unassuming wafer, was the most'],
#  ['696694316',
#   '6777',
#   '6823',
#   'as a sacrifice for their own salvation and for'],
#  ['696694316', '6832', '6852', 'the whole world, and'],
#  ['696694316', '7141', '7173', 'the urge to shout down the years'],
#  ['696694316', '7418', '7429', 'private, or'],
#  ['696694316', '7536', '7563', 'the faithful and fill their'],
#  ['696694316',
#   '7721',
#   '7780',
#   'else to interpret it in such a way as to weaken the genuine'],
#  ['696694316', '7932', '7963', 'with a strange kind of helpless'],
#  ['696694316',
#   '8446',
#   '8543',
#   'of the whole substance of the bread into the Body and of the whole substance of the wine into the'],
#  ['696694316', '8729', '8753', 'Hosts which remain after'],
#  ['696694316', '8952', '8986', 'pervading the whole Church, be not'],
#  ['696694316', '9373', '9384', 'The demonic'],
#  ['696694316', '9400', '9415', 'are the driving'],
#  ['696694316',
#   '9452',
#   '9544',
#   'heresy and destruction aren’t really looking at the undermining of marriage as their primary'],
#  ['696694316',
#   '9597',
#   '9686',
#   'is demonically inspired because their hatred is for Christ Himself in the first place and'],
#  ['696694316',
#   '9739',
#   '9790',
#   'They are men who refuse to bend the knee before the'],
#  ['696694316',
#   '9848',
#   '9895',
#   'attack is on the Body and Blood of Christ – can'],
#  ['696694316', '10116', '10129', 'supreme glory'],
#  ['696694316', '10164', '10188', 'defend it from sacrilege'],
#  ['696694316', '11233', '11253', 'fist) that no one in'],
#  ['696694316', '11514', '11550', 'desecrate the sacred species will be'],
#  ['696694316', '12685', '12724', 'a poisoned sea of systematic heresy and'],
#  ['696694316',
#   '12738',
#   '12824',
#   'A dark, impenetrable and “irreversible” winter of persecution of the faithful by their'],
#  ['696694316', '12876', '12883', 'have no'],
#  ['696694316', '12915', '12941', 'so many of these seemingly'],
#  ['696694316', '12988', '13007', 'rife with the usual'],
#  ['696694316', '13240', '13257', 'at all that there'],
#  ['696694316', '13640', '13656', 'whatever neglect'],
#  ['696694316', '14033', '14061', 'all but impossible to escape'],
#  ['696694316', '14196', '14202', 'as the'],
#  ['702077434',
#   '1277',
#   '1329',
#   '“I hated myself for making the worst decision I ever'],
#  ['702077434', '1376', '1385', '“I ruined'],
#  ['702077434', '1389', '1409', 'life and my family’s'],
#  ['710376094', '274', '290', 'still labeled as'],
#  ['710376094', '1929', '1948', 'to look out for the'],
#  ['700662577', '46', '74', 'Public Health Crisis Of Epic'],
#  ['700662577', '120', '143', 'Hurricane Maria wreaked'],
#  ['700662577', '234', '271', 'And it’s a crisis of epic proportions'],
#  ['700662577',
#   '624',
#   '681',
#   'probably because the blurry picture feels like it’s worth'],
#  ['700662577', '737', '754', 'a small sliver of'],
#  ['700662577', '1378', '1393', 'aid to the post'],
#  ['700662577', '2292', '2327', 'The power grid’s failure has caused'],
#  ['700662577',
#   '2762',
#   '2815',
#   'badly damaged, the power grid’s utter annihilation in'],
#  ['700662577', '3618', '3637', 'of epic proportions'],
#  ['700551604', '166', '206', 'JFK-assassination related records except'],
#  ['700551604', '334', '344', 'really put'],
#  ['700551604', '784', '825', 'want to show the American people its long'],
#  ['700551604', '1101', '1106', 'for a'],
#  ['700551604', '1581', '1615', 'what I want and I’ll give you want'],
#  ['700551604', '1648', '1656', 'all your'],
#  ['700551604', '1696', '1736', 'to the JFK assassination be shown to the'],
#  ['700551604', '1771', '1779', 'about it'],
#  ['700551604', '1828', '1864', 'It will end up giving Trump whatever'],
#  ['700551604', '1934', '1954', 'afford to permit the'],
#  ['700551604', '2352', '2383', 'that are more than 50 years old'],
#  ['700551604', '2574', '2613', 'most important and meaningless words in'],
#  ['700551604',
#   '2749',
#   '2796',
#   'person can honestly believe that the release of'],
#  ['700551604', '2800', '2820', 'year-old records are'],
#  ['700551604', '2858', '2874', 'falling into the'],
#  ['700551604', '2889', '2912', 'that the communists are'],
#  ['700551604', '2984', '3011', 'its decades-old JFK records'],
#  ['700551604',
#   '3181',
#   '3256',
#   'What is amazing (or not) is the extreme nonchalance of the mainstream media'],
#  ['700551604',
#   '3359',
#   '3443',
#   'guilt, given that it is absolutely ludicrous to think that “national security” would'],
#  ['700551604', '3476', '3497', 'the CIA’s long-secret'],
#  ['700551604', '4690', '4726', 'frame-up: That Oswald acted alone or'],
#  ['700551604', '4780', '4804', 'lead to nothing but dead'],
#  ['700551604', '5399', '5410', 'a communist'],
#  ['700551604', '5503', '5517', 'Latin American'],
#  ['700551604',
#   '5692',
#   '5794',
#   'assassination on a communist because then they could smear anyone who challenged the official story as'],
#  ['700551604', '5934', '5943', 'else that'],
#  ['700551604', '7252', '7261', 'is no big'],
#  ['700551604', '7383', '7389', 'a rock'],
#  ['700551604',
#   '7664',
#   '7726',
#   'the latter course, especially because it knows that its assets'],
#  ['700551604', '7799', '7835', 'with respect to its ridiculous claim'],
#  ['700551604', '8857', '8864', 'the art'],
#  ['700551604', '8991', '9007', 'mainstream press'],
#  ['700551604', '9126', '9135', 'Trump and'],
#  ['700551604', '9178', '9201', 'JFK assassination cover'],
#  ['701553469', '1530', '1554', 'Democratize SSMU claimed'],
#  ['701553469',
#   '1754',
#   '1800',
#   'working rather hard to intimidate and penalize'],
#  ['701553469', '1846', '1852', 'And to'],
#  ['701553469', '1871', '1887', 'boycott movement'],
#  ['701553469', '2037', '2064', 'me and campaign run against'],
#  ['701553469', '2107', '2138', 'my Jewish identity, and nothing'],
#  ['701553469',
#   '2319',
#   '2376',
#   'I believe in the right to Jewish self-determination.” Lew'],
#  ['701553469', '3045', '3060', 'they are Jewish'],
#  ['701553469',
#   '3128',
#   '3227',
#   'episode is utterly unacceptable, and is merely the latest in a long string of antisemitic incidents'],
#  ['701553469', '3463', '3476', 'Zionist today'],
#  ['701553469',
#   '3851',
#   '3928',
#   'Jewish community from defending itself against the absurd attacks to which it'],
#  ['701553469', '3969', '3996', 'to systematically excluding'],
#  ['694811415', '171', '185', 'Michael Savage'],
#  ['694811415', '297', '325', 'carried out the massacre and'],
#  ['694811415', '513', '539', '100% this is not that kind'],
#  ['694811415', '853', '897', '“I’m not a big conspiracy theory guy, but it'],
#  ['694811415', '1290', '1301', 'not a “lone'],
#  ['694811415', '1580', '1601', 'are intriguing, it is'],
#  ['694811415',
#   '1612',
#   '1668',
#   'to remember that after virtually every terror attack and'],
#  ['694811415',
#   '1737',
#   '1802',
#   'would be capable of carrying out such horrors, with some outright'],
#  ['706600938',
#   '67',
#   '129',
#   'derided by neo-Catholic commentators for relying on supposedly'],
#  ['706600938',
#   '214',
#   '346',
#   'But these critics never demonstrate that the oft-cited quotations are apocryphal; they merely assert that they must be, as they seem'],
#  ['706600938',
#   '440',
#   '512',
#   'at neo-Catholic websites, wherein the neo-Catholic commentator professes'],
#  ['706600938', '908', '938', 'the Church is a divine warning'],
#  ['706600938',
#   '1073',
#   '1156',
#   'around me innovators who wish to dismantle the Sacred Chapel, destroy the universal'],
#  ['706600938',
#   '1163',
#   '1224',
#   'of the Church, reject her ornaments and make her feel remorse'],
#  ['706600938',
#   '1267',
#   '1326',
#   'when the civilized world will deny its God, when the Church'],
#  ['706600938',
#   '1365',
#   '1410',
#   'be tempted to believe that man has become God'],
#  ['706600938', '1468', '1476', 'red lamp'],
#  ['706600938', '2229', '2246', 'priest, one Emile'],
#  ['706600938', '2292', '2309', 'attempted to cast'],
#  ['706600938', '3136', '3161', '“Act bravely, my brethren'],
#  ['706600938',
#   '3228',
#   '3279',
#   'in which there will be great trials and afflictions'],
#  ['706600938', '3345', '3356', 'abound; the'],
#  ['706600938', '3365', '3396', 'of many will grow cold, and the'],
#  ['706600938', '3520', '3560', 'will be so much obscured that there will'],
#  ['706600938', '3588', '3596', 'obey the'],
#  ['706600938', '3777', '3820', 'who, by his cunning, will endeavour to draw'],
#  ['706600938',
#   '3892',
#   '3960',
#   'will be divided, and many others will be entirely destroyed, because'],
#  ['706600938', '4055', '4072', 'and schisms among'],
#  ['706600938', '4233', '4256', 'were they not specially'],
#  ['706600938', '4270', '4306', 'such great confusion, by the immense'],
#  ['706600938', '4323', '4352', '“Those who persevere in their'],
#  ['706600938', '4386', '4426', 'love and zeal for the truth, will suffer'],
#  ['706600938',
#   '4484',
#   '4602',
#   'their persecutors, urged on by the evil spirits, will say they are rendering a great service to God by destroying such'],
#  ['706600938', '4696', '4733', 'and others will trample it under foot'],
#  ['706600938',
#   '4780',
#   '4832',
#   'derision even by those who outwardly profess it, for'],
#  ['706600938', '5640', '5673', 'a prediction of the Great Western'],
#  ['706600938',
#   '5746',
#   '5830',
#   'Peter who leads the faithful into error, widespread apostasy, and the persecution of'],
#  ['706600938',
#   '6213',
#   '6258',
#   'the greatest saints in Church history, one of'],
#  ['706600938', '6280', '6294', 'and revered by'],
#  ['706600938', '6522', '6550', 'depends upon defending every'],
#  ['706600938',
#   '6584',
#   '6658',
#   'somehow consistent with Tradition and declares absolutely inadmissible the'],
#  ['706600938', '6695', '6726', 'office could be a threat to the'],
#  ['706600938', '6990', '7003', 'to resist the'],
#  ['706600938',
#   '7043',
#   '7130',
#   'also licit to resist the one who aggresses souls or who disturbs civil order, or, above'],
#  ['706600938', '7186', '7211', 'is licit to resist by not'],
#  ['706600938', '7523', '7543', 'of Francis like that'],
#  ['706600938', '7635', '7657', 'words and deeds of the'],
#  ['111111112', '566', '579', 'not stand for'],
#  ['111111112',
#   '736',
#   '797',
#   'Defense Initiative, best known for a pro-Israel "Defeat Jihad'],
#  ['111111112',
#   '911',
#   '998',
#   'a striking blow against freedom" and said the "the nation that gave the world the Magna'],
#  ['111111112', '1741', '1769', 'called land of democracy and'],
#  ['111111112', '1801', '1843', 'How many hate preachers are living in this'],
#  ['111111112',
#   '1930',
#   '1987',
#   'Anti-fascism campaigners Hope Not Hate had campaigned for'],
#  ['111111112',
#   '2147',
#   '2206',
#   'some of the most extreme anti-Muslim activists in the world'],
#  ['111111112', '2394', '2409', "Britain doesn't"],
#  ['702077783', '103', '143', 'the worst mass murder in modern American'],
#  ['702077783',
#   '193',
#   '281',
#   'of the Vegas attack is unspeakable, and still the incompetent, clueless authorities know'],
#  ['702077783', '540', '578', 'out of hand jihad as a motive, here is'],
#  ['702077783', '677', '687', 'for events'],
#  ['702077783', '726', '737', 'and tripled'],
#  ['702077783',
#   '1801',
#   '1851',
#   'the worst mass shooting in modern American history'],
#  ['702077783', '2652', '2659', 'was now'],
#  ['702077783', '4507', '4543', 'right to know more, “but they have a'],
#  ['702077783', '4600', '4623', 'that has filled so many'],
#  ['703806098', '230', '250', 'shooting in American'],
#  ['703806098',
#   '2589',
#   '2640',
#   'used in the attack, the American people are clearly'],
#  ['703806098', '2871', '2881', 'attack and'],
#  ['697063039', '1206', '1225', 'over a century, and'],
#  ['697063039', '1393', '1413', 'level of destruction'],
#  ['697063039', '2021', '2039', 'become months, and'],
#  ['697063039', '2054', '2062', 'get more'],
#  ['697063039', '2118', '2146', 'States just so that they can'],
#  ['697063039', '2242', '2258', 'are finding life'],
#  ['704591553', '193', '231', 'against Israel have not dispensed with'],
#  ['704591553', '286', '304', 'perpetrated by BDS'],
#  ['704591553', '767', '801', 'his Jewish identity secret lest he'],
#  ['704591553', '1744', '1784', 'and their arguments ultimately prevailed'],
#  ['704591553', '1880', '1887', 'end; or'],
#  ['704591553',
#   '1980',
#   '2041',
#   'instant targets of a campaign of hate laced with blatant anti'],
#  ['704591553', '2642', '2663', 'impeachment effort to'],
#  ['704591553', '2799', '2821', 'a “misguided joke.” It'],
#  ['704591553', '3164', '3181', 'highlighted Lew’s'],
#  ['704591553',
#   '3269',
#   '3328',
#   'transformed into something harking back to the days of Nazi'],
#  ['704591553', '3754', '3784', 'SSMU activists managed to pick'],
#  ['704591553',
#   '3820',
#   '3875',
#   'It was repulsive display leftist-fascist bigotry at its'],
#  ['704591553', '4016', '4029', 'have gone too'],
#  ['704591553',
#   '4064',
#   '4115',
#   'manifestly anti-Semitic campaign antics were beyond'],
#  ['704591553', '4208', '4220', 'and commonly'],
#  ['704591553', '4232', '4263', '“Zionists” for Jews even though'],
#  ['704591553', '4275', '4288', 'are cognizant'],
#  ['704591553',
#   '4365',
#   '4452',
#   'dispensed with their traditional charade and overtly launched their attack against Jews'],
#  ['697996062',
#   '58',
#   '108',
#   'Two illegal aliens caught smuggling less glamorous'],
#  ['697996062', '284', '295', 'And illegal'],
#  ['697996062', '358', '403', 'an economic industry and a political industry'],
#  ['701837665', '145', '164', 'long-secret records'],
#  ['701837665', '761', '778', 'A blind man could'],
#  ['701837665', '1338', '1368', 'Displaying their naivete, they'],
#  ['701837665',
#   '1533',
#   '1579',
#   'a favor from someone else, the someone else is'],
#  ['701837665', '2955', '2964', 'I want or'],
#  ['701837665',
#   '3220',
#   '3316',
#   'mainstream press is asserting, the records undoubtedly contain more incriminating circumstantial'],
#  ['701837665',
#   '3452',
#   '3548',
#   'media, forever wedded to the official story no matter how ridiculous and illogical it is, simply'],
#  ['701837665', '3742', '3774', 'could refuse to grant Trump what'],
#  ['701837665', '3847', '3862', 'the CIA’s guilt'],
#  ['701837665', '3907', '3928', 'could give Trump what'],
#  ['701837665', '4285', '4318', 'Trump’s supposed “collusion” with'],
#  ['701837665', '5657', '5693', 'security” would be threatened, after'],
#  ['701837665', '5804', '5829', 'change his mind, is, well'],
#  ['701837665', '5961', '6002', 'Because Trump obviously needed collateral'],
#  ['701837665',
#   '6747',
#   '6835',
#   'still being suppressed have nothing to do with “national security.” They have everything'],
#  ['701837665', '7497', '7537', 'have motive, a powerful motive, the same'],
#  ['701837665', '7615', '7649', 'for regime change or assassination'],
#  ['701837665', '8329', '8334', 'has a'],
#  ['701837665', '8346', '8383', 'conformity and deference to authority'],
#  ['701837665', '8408', '8426', 'because nothing is'],
#  ['701837665', '8474', '8494', 'critical, analytical'],
#  ['701837665', '8508', '8520', 'mindset, the'],
#  ['701837665', '8580', '8606', 'communist Marines have you'],
#  ['701837665', '8930', '8937', 'to kill'],
#  ['701837665',
#   '8977',
#   '9023',
#   'do you know who like to kill fellow communists'],
#  ['701837665',
#   '9299',
#   '9347',
#   'America’s sworn Cold War enemy (and former World'],
#  ['701837665', '9704', '9739', 'suspects are communists or traitors'],
#  ['701837665', '9807', '9832', 'traitor and he isn’t even'],
#  ['701837665',
#   '10041',
#   '10154',
#   'that they just let Lee Harvey Oswald, a supposed self-avowed communist skate blissfully across the Cold War stage'],
#  ['701837665', '10490', '10497', 'type of'],
#  ['701837665', '10807', '10827', 'needed to get rid of'],
#  ['701837665', '11059', '11084', 'Killed Ken... Roger Stone'],
#  ['701837665', '11351', '11365', 'a communist or'],
#  ['701837665', '11978', '11997', 'operation ever goes'],
#  ['701837665',
#   '12424',
#   '12504',
#   'of its JFK records would threaten “national security.” One thing is for sure and'],
#  ['698780559',
#   '516',
#   '582',
#   'very authorities who are cramming lies down our throats about this'],
#  ['698780559', '696', '712', 'media has so far'],
#  ['698780559', '1201', '1231', 'crowd killing more than 50 and'],
#  ['698780559', '2206', '2215', 'the union'],
#  ['698780559', '2355', '2380', 'shooting they desperately'],
#  ['701225819', '139', '163', 'Klan, has been denounced'],
#  ['701225819', '232', '246', 'who represents'],
#  ['701225819', '328', '346', 'has been promoting'],
#  ['701225819', '543', '575', 'be rivaled only by Zakkout’s own'],
#  ['701225819', '1230', '1249', 'car into a group of'],
#  ['701225819',
#   '1503',
#   '1583',
#   'Duke Exposes the Real Racist Jewish Supremacists Who Orchestrate the Destruction'],
#  ['701225819',
#   '1763',
#   '1868',
#   'the wild claim that there has been a “complete takeover of American foreign policy and… American politics'],
#  ['701225819', '2272', '2304', 'and inciting material is not the'],
#  ['701225819', '2348', '2367', 'much bigotry coming'],
#  ['701225819',
#   '2777',
#   '2861',
#   'face with Satan, the Arch Deceiver, the enemy of God, and the enemy of the righteous'],
#  ['701225819',
#   '2953',
#   '3068',
#   'personal Facebook page) of a grotesque cartoon containing a worried-looking religious Jew hiding behind an animated'],
#  ['701225819', '3468', '3474', 'with a'],
#  ['701225819',
#   '3765',
#   '3826',
#   'that openly calls for “Death to Israel” and labels the Jewish'],
#  ['701225819', '3925', '3965', 'claiming that “the Holocaust was faked.”'],
#  ['701225819',
#   '4022',
#   '4130',
#   'at the hands of Adolf Hitler and National Socialist Germany during WWII is the biggest lie ever foisted upon'],
#  ['701225819',
#   '4165',
#   '4280',
#   'Realist Report, an anti-Jew, anti-black, anti-gay independent media outlet, which describes Hitler as “the greatest'],
#  ['701225819',
#   '4418',
#   '4486',
#   'who is a decorated veteran of many different wars and battles fought'],
#  ['701225819',
#   '4880',
#   '4926',
#   'as event goers repeatedly shout, “We are Hamas'],
#  ['701225819',
#   '5014',
#   '5107',
#   '“Thank God, every day we conquer the American Jews like our conquests over the Jews of Israel'],
#  ['701225819',
#   '5305',
#   '5363',
#   'from the community, not from Muslims, not from non-Muslims'],
#  ['701225819', '5398', '5432', 'everyone, save this author and his'],
#  ['701225819', '5883', '5894', 'attempts to'],
#  ['701225819',
#   '6050',
#   '6150',
#   'can be condemned and repudiated for spreading their toxic hate, their fan and propagator Zakkout can'],
#  ['705409419', '85', '105', 'whole Catholic world'],
#  ['705409419', '697', '721', '“man of the Council” and'],
#  ['705409419', '938', '977', 'activity—is a withering indictment of a'],
#  ['705409419',
#   '1123',
#   '1186',
#   'his deliberate ambiguity, his fomenting of error, his sowing of'],
#  ['705409419', '1239', '1274', 'and even his reduction of the faith'],
#  ['705409419',
#   '1721',
#   '1793',
#   'a seemingly intentional lack of clarity inevitably risks sinning against'],
#  ['705409419', '1798', '1814', 'Holy Spirit, the'],
#  ['705409419', '1902', '1917', 'to dispel error'],
#  ['705409419', '2129', '2152', 'calumny is alien to the'],
#  ['705409419', '2428', '2444', 'doctrine as dead'],
#  ['705409419', '2534', '2571', 'accused, in your own words, of making'],
#  ['705409419',
#   '2624',
#   '2724',
#   'doctrine… that frees people from worldly ideologies and assures that they are actually preaching and'],
#  ['705409419',
#   '2929',
#   '2997',
#   'can only possess, is an ideology – one that conforms to the world of'],
#  ['705409419',
#   '3062',
#   '3187',
#   'your choice of some bishops, men who seem not merely open to those who hold views counter to Christian belief but who support'],
#  ['705409419', '3346', '3371', 'that you also seem silent'],
#  ['705409419',
#   '3447',
#   '3492',
#   'the faithful, who embody the "sensus fidelium'],
#  ['705409419', '3574', '3602', 'Mystical Body of Christ, and'],
#  ['705409419', '3698', '3738', 'and words too often seem intent on doing'],
#  ['705409419', '3916', '3922', 'not be'],
#  ['705409419',
#   '4035',
#   '4132',
#   'are open to criticism, but that you resent it… Many fear that if they speak their mind, they will'],
#  ['705409419', '4261', '4268', 'is that'],
#  ['705409419',
#   '4284',
#   '4345',
#   'manifest just how weak is the faith of many within the Church'],
#  ['705409419', '4801', '4827', 'popes who are buried there'],
#  ['705409419', '4888', '4898', 'the Church'],
#  ['705409419',
#   '5201',
#   '5269',
#   'United States, Canada or Great Britain, which person would utter the'],
#  ['705409419', '5768', '5780', 'any doubt in'],
#  ['705409419', '6034', '6053', 'raised up by heaven'],
#  ['705409419', '6149', '6174', 'in their candor what even'],
#  ['705409419', '7368', '7397', 'and to rectify the grave harm'],
#  ['696246189', '51', '72', 'A mysterious piece of'],
#  ['696246189', '573', '581', 'piece of'],
#  ['696246189', '2031', '2057', 'out so he would know where'],
#  ['696246189', '2256', '2290', 'maximize accuracy and optimize his'],
#  ['696246189', '2814', '2828', 'a massacre and'],
#  ['706661242', '48', '71', 'the academic discipline'],
#  ['706661242', '263', '275', 'Politics: An'],
#  ['706661242',
#   '1246',
#   '1315',
#   'shows how race, gender and ethnicity (or their variants) stand out as'],
#  ['706661242', '1370', '1380', 'Anyone who'],
#  ['706661242',
#   '1387',
#   '1513',
#   'thinks that political, intellectual, demographic and material factors are what really matter to history, and to society, ought'],
#  ['706661242', '1521', '1529', 'with the'],
#  ['706661242', '1556', '1584', 'Politics program – enroll in'],
#  ['111111122', '282', '320', 'that’s gone wrong is Trump’s fault, he'],
#  ['111111122',
#   '438',
#   '489',
#   'example of how badly Trump does his job more than a'],
#  ['111111122', '784', '799', 'a Trump mistake'],
#  ['111111122',
#   '992',
#   '1044',
#   'might turn out not to be a conservative; to reassure'],
#  ['111111122', '1214', '1225', 'Still, it’s'],
#  ['111111122', '1230', '1238', 'thing to'],
#  ['111111122', '1297', '1306', 'the whole'],
#  ['111111122', '1482', '1512', 'is easily manipulated by those'],
#  ['111111122', '2786', '2809', 'that’s not a sure thing'],
#  ['111111122', '3167', '3192', 'nomination is doomed, but'],
#  ['111111122', '3241', '3280', 'profile fight is always going to hurt a'],
#  ['111111122',
#   '3542',
#   '3605',
#   'process as the accusations against Kavanaugh gained credibility'],
#  ['111111122', '3660', '3687', 'public opinion for Trump is'],
#  ['111111122', '3968', '4002', 'more it appears that the Trump and'],
#  ['111111122', '4453', '4464', 'slur on all'],
#  ['111111122', '4861', '4867', 'die if'],
#  ['111111122', '4984', '4998', 'episodes, that'],
#  ['111111122',
#   '5019',
#   '5081',
#   'House are a gang that can’t shoot straight and that he’s eager'],
#  ['111111122',
#   '5085',
#   '5147',
#   'blame his allies and lash out at his enemies in ugly ways when'],
#  ['111111122', '5210', '5244', 'will be less likely to trust Trump'],
#  ['111111122', '5337', '5366', 'less likely to trust him when'],
#  ['111111122',
#   '5455',
#   '5522',
#   'Trump’s professional reputation is already terrible, but everything'],
#  ['111111122', '5558', '5574', 'Richard Neustadt'],
#  ['111111122', '5674', '5706', 'himself right now, and will have'],
#  ['111111122', '5784', '5799', 'of-his-jib test'],
#  ['111111122', '5892', '5918', 'doing that job should look'],
#  ['111111122', '5961', '5998', 'time Hollywood casting, would wind up'],
#  ['111111122',
#   '6154',
#   '6208',
#   'wavering Republicans) had more than enough information'],
#  ['111111122', '6288', '6327', 'vulnerable to claims about transparency'],
#  ['111111122', '6409', '6439', 'transparency -- and vulnerable'],
#  ['111111122', '6443', '6456', 'bombshells in'],
#  ['111111122', '6582', '6622', "it's an example of Trump taking needless"],
#  ['111111122',
#   '6832',
#   '6882',
#   'of other partisan, conservative judges, and plenty'],
#  ['111111122', '7092', '7115', "don't think there's any"]]

# %%
aaa = predictLabel(rrr, "v1")
# Out:
# Shape of data tensor: (856, 81)
# Loaded model from disk

# %%
aaa
# Out:
# [['710100700', 'Name_Calling,Labeling', '0', '11'],
#  ['710100700', 'Doubt', '1295', '1336'],
#  ['785801366', 'Doubt', '100', '105'],
#  ['785801366', 'Appeal_to_fear-prejudice', '182', '255'],
#  ['785801366', 'Doubt', '330', '409'],
#  ['785801366', 'Exaggeration,Minimisation', '444', '525'],
#  ['785801366', 'Black-and-White_Fallacy', '777', '850'],
#  ['785801366', 'Loaded_Language', '1387', '1401'],
#  ['785801366', 'Causal_Oversimplification', '1462', '1545'],
#  ['785801366', 'Exaggeration,Minimisation', '1612', '1644'],
#  ['785801366', 'Exaggeration,Minimisation', '1752', '1833'],
#  ['785801366', 'Loaded_Language', '1973', '1997'],
#  ['785801366', 'Loaded_Language', '2026', '2046'],
#  ['785801366', 'Name_Calling,Labeling', '2140', '2161'],
#  ['785801366', 'Loaded_Language', '2260', '2275'],
#  ['785801366', 'Repetition', '2397', '2418'],
#  ['785801366', 'Exaggeration,Minimisation', '2529', '2574'],
#  ['785801366', 'Black-and-White_Fallacy', '2625', '2691'],
#  ['785801366', 'Slogans', '3296', '3359'],
#  ['785801366', 'Appeal_to_fear-prejudice', '3823', '3886'],
#  ['785801366', 'Name_Calling,Labeling', '3942', '3982'],
#  ['785801366', 'Name_Calling,Labeling', '3988', '4000'],
#  ['785801366', 'Exaggeration,Minimisation', '4239', '4295'],
#  ['785801366', 'Loaded_Language', '4316', '4328'],
#  ['785801366', 'Loaded_Language', '4370', '4417'],
#  ['785801366', 'Exaggeration,Minimisation', '4526', '4554'],
#  ['785801366', 'Doubt', '4843', '4960'],
#  ['785801366', 'Appeal_to_fear-prejudice', '5224', '5266'],
#  ['785801366', 'Whataboutism', '5760', '5892'],
#  ['785801366', 'Loaded_Language', '5920', '5979'],
#  ['785801366', 'Black-and-White_Fallacy', '6104', '6229'],
#  ['785801366', 'Appeal_to_fear-prejudice', '6420', '6485'],
#  ['785801366', 'Loaded_Language', '6574', '6602'],
#  ['785801366', 'Flag-Waving', '6977', '7000'],
#  ['785801366', 'Doubt', '7098', '7106'],
#  ['785801366', 'Name_Calling,Labeling', '7475', '7499'],
#  ['785801366', 'Slogans', '7504', '7557'],
#  ['785801366', 'Exaggeration,Minimisation', '7590', '7642'],
#  ['785801366', 'Causal_Oversimplification', '7713', '7832'],
#  ['785801366', 'Exaggeration,Minimisation', '7879', '7891'],
#  ['785801366', 'Doubt', '8013', '8091'],
#  ['785801366', 'Loaded_Language', '8160', '8185'],
#  ['785801366', 'Exaggeration,Minimisation', '8201', '8304'],
#  ['785801366', 'Loaded_Language', '8488', '8526'],
#  ['785801366', 'Loaded_Language', '8736', '8793'],
#  ['785801366', 'Exaggeration,Minimisation', '8878', '8953'],
#  ['785801366', 'Exaggeration,Minimisation', '8991', '9111'],
#  ['785801366', 'Whataboutism', '9288', '9391'],
#  ['785801366', 'Whataboutism', '9447', '9489'],
#  ['723501118', 'Exaggeration,Minimisation', '93', '107'],
#  ['723501118', 'Loaded_Language', '121', '193'],
#  ['723501118', 'Loaded_Language', '340', '372'],
#  ['723501118', 'Exaggeration,Minimisation', '414', '449'],
#  ['723501118', 'Exaggeration,Minimisation', '613', '658'],
#  ['723501118', 'Whataboutism', '742', '847'],
#  ['723501118', 'Name_Calling,Labeling', '907', '919'],
#  ['723501118', 'Appeal_to_fear-prejudice', '1366', '1436'],
#  ['723501118', 'Slogans', '1669', '1706'],
#  ['723501118', 'Appeal_to_fear-prejudice', '2532', '2570'],
#  ['999000125', 'Loaded_Language', '210', '272'],
#  ['999000125', 'Name_Calling,Labeling', '749', '760'],
#  ['999000125', 'Doubt', '868', '988'],
#  ['999000125', 'Loaded_Language', '1484', '1490'],
#  ['999000125', 'Slogans', '1542', '1569'],
#  ['999000125', 'Doubt', '2058', '2078'],
#  ['999000125', 'Exaggeration,Minimisation', '2330', '2369'],
#  ['999000125', 'Doubt', '2746', '2809'],
#  ['999000125', 'Name_Calling,Labeling', '3021', '3030'],
#  ['999000125', 'Name_Calling,Labeling', '3223', '3230'],
#  ['999000125', 'Black-and-White_Fallacy', '3246', '3272'],
#  ['999000125', 'Black-and-White_Fallacy', '3300', '3333'],
#  ['999000125', 'Doubt', '3512', '3597'],
#  ['701933838', 'Doubt', '1073', '1114'],
#  ['999000675', 'Loaded_Language', '110', '151'],
#  ['999000675', 'Name_Calling,Labeling', '285', '297'],
#  ['999000675', 'Loaded_Language', '508', '549'],
#  ['999000675', 'Loaded_Language', '966', '994'],
#  ['999000675', 'Exaggeration,Minimisation', '1007', '1034'],
#  ['999000675', 'Appeal_to_fear-prejudice', '1605', '1645'],
#  ['999000675', 'Black-and-White_Fallacy', '1834', '1902'],
#  ['999000675', 'Name_Calling,Labeling', '1945', '2009'],
#  ['999000675', 'Doubt', '2061', '2067'],
#  ['999000675', 'Causal_Oversimplification', '2232', '2283'],
#  ['999000158', 'Loaded_Language', '343', '358'],
#  ['999000158', 'Flag-Waving', '461', '469'],
#  ['999000158', 'Exaggeration,Minimisation', '1236', '1249'],
#  ['999000158', 'Exaggeration,Minimisation', '1638', '1675'],
#  ['999000158', 'Doubt', '1906', '1986'],
#  ['999000158', 'Doubt', '2064', '2107'],
#  ['999000158', 'Name_Calling,Labeling', '2208', '2216'],
#  ['999000158', 'Loaded_Language', '2301', '2328'],
#  ['999000158', 'Name_Calling,Labeling', '2462', '2479'],
#  ['999000158', 'Doubt', '2680', '2744'],
#  ['999000158', 'Loaded_Language', '2827', '2846'],
#  ['999000158', 'Appeal_to_fear-prejudice', '3109', '3129'],
#  ['999000158', 'Doubt', '3427', '3484'],
#  ['999000158', 'Name_Calling,Labeling', '3496', '3515'],
#  ['999000158', 'Loaded_Language', '3542', '3568'],
#  ['999000158', 'Name_Calling,Labeling', '3629', '3656'],
#  ['999000565', 'Loaded_Language', '87', '172'],
#  ['999000565', 'Exaggeration,Minimisation', '339', '378'],
#  ['999000565', 'Loaded_Language', '427', '456'],
#  ['999000565', 'Loaded_Language', '589', '614'],
#  ['999000599', 'Name_Calling,Labeling', '15', '53'],
#  ['999000599', 'Name_Calling,Labeling', '160', '202'],
#  ['999000599', 'Thought-terminating_Cliches', '301', '340'],
#  ['999000599', 'Flag-Waving', '497', '554'],
#  ['999000599', 'Loaded_Language', '707', '715'],
#  ['999000599', 'Flag-Waving', '834', '1000'],
#  ['999000599', 'Doubt', '1070', '1118'],
#  ['999000599', 'Loaded_Language', '1158', '1177'],
#  ['999000599', 'Exaggeration,Minimisation', '1227', '1313'],
#  ['999000599', 'Name_Calling,Labeling', '1476', '1491'],
#  ['999000599', 'Doubt', '1808', '1862'],
#  ['999000599', 'Name_Calling,Labeling', '1875', '1896'],
#  ['999000599', 'Thought-terminating_Cliches', '1935', '1954'],
#  ['999000599', 'Doubt', '2074', '2140'],
#  ['735265649', 'Name_Calling,Labeling', '520', '563'],
#  ['735265649', 'Loaded_Language', '1316', '1331'],
#  ['735265649', 'Loaded_Language', '1385', '1438'],
#  ['735265649', 'Loaded_Language', '1623', '1645'],
#  ['735265649', 'Name_Calling,Labeling', '2011', '2031'],
#  ['999000135', 'Loaded_Language', '59', '106'],
#  ['999000135', 'Doubt', '223', '265'],
#  ['999000135', 'Doubt', '431', '500'],
#  ['999000135', 'Loaded_Language', '572', '585'],
#  ['999000135', 'Exaggeration,Minimisation', '790', '813'],
#  ['999000135', 'Doubt', '871', '906'],
#  ['999000135', 'Exaggeration,Minimisation', '932', '1033'],
#  ['999000135', 'Black-and-White_Fallacy', '1039', '1091'],
#  ['999000135', 'Loaded_Language', '1870', '1891'],
#  ['999000135', 'Black-and-White_Fallacy', '1934', '1976'],
#  ['999000135', 'Exaggeration,Minimisation', '2000', '2055'],
#  ['999000135', 'Loaded_Language', '2160', '2174'],
#  ['999000135', 'Causal_Oversimplification', '2231', '2292'],
#  ['999000135', 'Loaded_Language', '2320', '2343'],
#  ['999000135', 'Doubt', '2394', '2501'],
#  ['999000135', 'Loaded_Language', '2598', '2607'],
#  ['999000135', 'Slogans', '2653', '2688'],
#  ['735855251', 'Name_Calling,Labeling', '1975', '2004'],
#  ['735855251', 'Loaded_Language', '2408', '2420'],
#  ['999000149', 'Appeal_to_fear-prejudice', '97', '141'],
#  ['999000149', 'Exaggeration,Minimisation', '243', '308'],
#  ['999000149', 'Name_Calling,Labeling', '328', '377'],
#  ['999000149', 'Black-and-White_Fallacy', '1292', '1352'],
#  ['999000149', 'Loaded_Language', '1459', '1477'],
#  ['999000149', 'Appeal_to_fear-prejudice', '1552', '1588'],
#  ['999000149', 'Black-and-White_Fallacy', '1602', '1670'],
#  ['999000149', 'Loaded_Language', '2023', '2038'],
#  ['999000149', 'Loaded_Language', '2989', '3069'],
#  ['999000149', 'Black-and-White_Fallacy', '3097', '3143'],
#  ['999000149', 'Repetition', '3192', '3224'],
#  ['722507879', 'Name_Calling,Labeling', '464', '488'],
#  ['722507879', 'Name_Calling,Labeling', '641', '702'],
#  ['722507879', 'Name_Calling,Labeling', '1361', '1380'],
#  ['722507879', 'Loaded_Language', '2598', '2618'],
#  ['722507879', 'Appeal_to_fear-prejudice', '3370', '3407'],
#  ['722507879', 'Name_Calling,Labeling', '6278', '6285'],
#  ['722507879', 'Loaded_Language', '6579', '6611'],
#  ['765197039', 'Reductio_ad_hitlerum', '69', '121'],
#  ['765197039', 'Doubt', '187', '268'],
#  ['765197039', 'Loaded_Language', '336', '351'],
#  ['765197039', 'Loaded_Language', '420', '435'],
#  ['765197039', 'Causal_Oversimplification', '592', '696'],
#  ['765197039', 'Causal_Oversimplification', '713', '780'],
#  ['765197039', 'Doubt', '808', '874'],
#  ['765197039', 'Repetition', '926', '940'],
#  ['765197039', 'Causal_Oversimplification', '1076', '1137'],
#  ['765197039', 'Doubt', '1229', '1281'],
#  ['765197039', 'Whataboutism', '1971', '2041'],
#  ['765197039', 'Exaggeration,Minimisation', '2139', '2185'],
#  ['765197039', 'Doubt', '2199', '2505'],
#  ['765197039', 'Name_Calling,Labeling', '2534', '2569'],
#  ['765197039', 'Reductio_ad_hitlerum', '2649', '2879'],
#  ['765197039', 'Flag-Waving', '2914', '2926'],
#  ['765197039', 'Loaded_Language', '2948', '3062'],
#  ['765197039', 'Loaded_Language', '3219', '3242'],
#  ['765197039', 'Doubt', '3370', '3487'],
#  ['765197039', 'Loaded_Language', '3547', '3578'],
#  ['765197039', 'Black-and-White_Fallacy', '3695', '3753'],
#  ['765197039', 'Doubt', '3797', '3937'],
#  ['765197039', 'Exaggeration,Minimisation', '4041', '4075'],
#  ['765197039', 'Loaded_Language', '4223', '4242'],
#  ['765197039', 'Exaggeration,Minimisation', '4279', '4456'],
#  ['765197039', 'Appeal_to_Authority', '4468', '4528'],
#  ['765197039', 'Doubt', '4554', '4583'],
#  ['765197039', 'Black-and-White_Fallacy', '4619', '4712'],
#  ['765197039', 'Name_Calling,Labeling', '4743', '4789'],
#  ['7634408719', 'Name_Calling,Labeling', '2091', '2111'],
#  ['779394730', 'Loaded_Language', '1205', '1247'],
#  ['779394730', 'Slogans', '1704', '1718'],
#  ['779394730', 'Loaded_Language', '1907', '1927'],
#  ['779394730', 'Loaded_Language', '3287', '3307'],
#  ['779394730', 'Repetition', '3353', '3368'],
#  ['779394730', 'Name_Calling,Labeling', '3486', '3500'],
#  ['779394730', 'Loaded_Language', '3736', '3756'],
#  ['779394730', 'Appeal_to_fear-prejudice', '4009', '4052'],
#  ['779394730', 'Doubt', '4281', '4348'],
#  ['735090638', 'Name_Calling,Labeling', '108', '168'],
#  ['735090638', 'Loaded_Language', '270', '289'],
#  ['735090638', 'Flag-Waving', '926', '944'],
#  ['735090638', 'Flag-Waving', '1042', '1070'],
#  ['735090638', 'Loaded_Language', '1100', '1118'],
#  ['735090638', 'Thought-terminating_Cliches', '2361', '2374'],
#  ['735090638', 'Exaggeration,Minimisation', '2410', '2442'],
#  ['735090638', 'Loaded_Language', '2548', '2564'],
#  ['776535164', 'Name_Calling,Labeling', '495', '503'],
#  ['999000124', 'Exaggeration,Minimisation', '99', '125'],
#  ['999000124', 'Flag-Waving', '557', '595'],
#  ['999000124', 'Doubt', '627', '675'],
#  ['999000124', 'Name_Calling,Labeling', '678', '715'],
#  ['999000124', 'Repetition', '1063', '1078'],
#  ['999000124', 'Loaded_Language', '1269', '1280'],
#  ['723793978', 'Loaded_Language', '179', '193'],
#  ['723793978', 'Exaggeration,Minimisation', '239', '271'],
#  ['723793978', 'Exaggeration,Minimisation', '440', '485'],
#  ['723793978', 'Name_Calling,Labeling', '536', '553'],
#  ['723793978', 'Name_Calling,Labeling', '1418', '1430'],
#  ['111111136', 'Loaded_Language', '63', '95'],
#  ['111111136', 'Exaggeration,Minimisation', '137', '172'],
#  ['111111136', 'Exaggeration,Minimisation', '336', '381'],
#  ['111111136', 'Name_Calling,Labeling', '516', '525'],
#  ['111111136', 'Name_Calling,Labeling', '708', '720'],
#  ['111111136', 'Black-and-White_Fallacy', '1169', '1214'],
#  ['111111136', 'Loaded_Language', '1234', '1242'],
#  ['111111136', 'Causal_Oversimplification', '1579', '1654'],
#  ['111111136', 'Loaded_Language', '1961', '1968'],
#  ['787002327', 'Doubt', '193', '208'],
#  ['787002327', 'Repetition', '288', '307'],
#  ['787002327', 'Repetition', '394', '428'],
#  ['787002327', 'Doubt', '553', '614'],
#  ['787002327', 'Causal_Oversimplification', '1131', '1288'],
#  ['787002327', 'Name_Calling,Labeling', '1795', '1833'],
#  ['787002327', 'Name_Calling,Labeling', '2669', '2692'],
#  ['787002327', 'Black-and-White_Fallacy', '2965', '3061'],
#  ['787002327', 'Loaded_Language', '3575', '3610'],
#  ['787002327', 'Name_Calling,Labeling', '4003', '4061'],
#  ['787002327', 'Appeal_to_fear-prejudice', '4084', '4103'],
#  ['787002327', 'Exaggeration,Minimisation', '4199', '4240'],
#  ['787002327', 'Repetition', '5243', '5283'],
#  ['787002327', 'Name_Calling,Labeling', '5401', '5462'],
#  ['787002327', 'Name_Calling,Labeling', '5601', '5652'],
#  ['787002327', 'Name_Calling,Labeling', '5903', '5932'],
#  ['787002327', 'Loaded_Language', '6168', '6213'],
#  ['787002327', 'Doubt', '6457', '6516'],
#  ['787002327', 'Exaggeration,Minimisation', '6674', '6766'],
#  ['787002327', 'Exaggeration,Minimisation', '6910', '6955'],
#  ['787002327', 'Doubt', '7092', '7137'],
#  ['787002327', 'Exaggeration,Minimisation', '7338', '7364'],
#  ['999001970', 'Loaded_Language', '228', '244'],
#  ['999001970', 'Loaded_Language', '364', '426'],
#  ['999001970', 'Name_Calling,Labeling', '903', '914'],
#  ['999001970', 'Doubt', '1022', '1142'],
#  ['999001970', 'Thought-terminating_Cliches', '1270', '1277'],
#  ['999001970', 'Loaded_Language', '1836', '1842'],
#  ['999001970', 'Slogans', '1894', '1921'],
#  ['999001970', 'Name_Calling,Labeling', '2184', '2191'],
#  ['999001970', 'Black-and-White_Fallacy', '2207', '2233'],
#  ['999001970', 'Black-and-White_Fallacy', '2261', '2294'],
#  ['999001970', 'Doubt', '2473', '2558'],
#  ['741896049', 'Name_Calling,Labeling', '539', '560'],
#  ['741896049', 'Loaded_Language', '1151', '1171'],
#  ['709732928', 'Repetition', '322', '343'],
#  ['709732928', 'Black-and-White_Fallacy', '764', '799'],
#  ['709732928', 'Loaded_Language', '1189', '1232'],
#  ['709732928', 'Loaded_Language', '1405', '1419'],
#  ['709732928', 'Loaded_Language', '1807', '1820'],
#  ['709732928', 'Doubt', '2280', '2318'],
#  ['709732928', 'Exaggeration,Minimisation', '2557', '2587'],
#  ['709732928', 'Loaded_Language', '3001', '3047'],
#  ['709732928', 'Thought-terminating_Cliches', '4325', '4348'],
#  ['709732928', 'Loaded_Language', '5373', '5391'],
#  ['709732928', 'Loaded_Language', '5705', '5713'],
#  ['709732928', 'Exaggeration,Minimisation', '6839', '6866'],
#  ['709732928', 'Thought-terminating_Cliches', '7147', '7172'],
#  ['709732928', 'Causal_Oversimplification', '7197', '7263'],
#  ['709732928', 'Exaggeration,Minimisation', '7326', '7366'],
#  ['709732928', 'Causal_Oversimplification', '7441', '7503'],
#  ['709732928', 'Doubt', '7559', '7569'],
#  ['709732928', 'Exaggeration,Minimisation', '7579', '7604'],
#  ['709732928', 'Exaggeration,Minimisation', '7811', '7855'],
#  ['709732928', 'Name_Calling,Labeling', '8502', '8539'],
#  ['709732928', 'Exaggeration,Minimisation', '9139', '9155'],
#  ['709732928', 'Loaded_Language', '9281', '9289'],
#  ['709732928', 'Name_Calling,Labeling', '9394', '9406'],
#  ['709732928', 'Loaded_Language', '9530', '9545'],
#  ['709732928', 'Exaggeration,Minimisation', '9783', '9792'],
#  ['709732928', 'Exaggeration,Minimisation', '9807', '9848'],
#  ['709732928', 'Doubt', '9881', '9954'],
#  ['709732928', 'Doubt', '10163', '10215'],
#  ['709732928', 'Repetition', '10275', '10286'],
#  ['709732928', 'Loaded_Language', '10416', '10434'],
#  ['709732928', 'Black-and-White_Fallacy', '10525', '10566'],
#  ['709732928', 'Slogans', '10626', '10669'],
#  ['709732928', 'Doubt', '10679', '10699'],
#  ['709732928', 'Doubt', '10777', '10810'],
#  ['709732928', 'Doubt', '11327', '11365'],
#  ['709732928', 'Whataboutism', '11412', '11462'],
#  ['709732928', 'Loaded_Language', '11481', '11489'],
#  ['709732928', 'Doubt', '11751', '11783'],
#  ['709732928', 'Name_Calling,Labeling', '11978', '12005'],
#  ['999001033', 'Causal_Oversimplification', '32', '87'],
#  ['999001033', 'Causal_Oversimplification', '128', '183'],
#  ['999001033', 'Loaded_Language', '343', '406'],
#  ['999001033', 'Loaded_Language', '1172', '1207'],
#  ['999001033', 'Name_Calling,Labeling', '1454', '1460'],
#  ['999001033', 'Loaded_Language', '1556', '1583'],
#  ['999001033', 'Name_Calling,Labeling', '2184', '2192'],
#  ['999001033', 'Loaded_Language', '2335', '2399'],
#  ['999001033', 'Name_Calling,Labeling', '2520', '2549'],
#  ['999001033', 'Doubt', '2843', '2861'],
#  ['999001033', 'Loaded_Language', '3082', '3112'],
#  ['999001033', 'Causal_Oversimplification', '3161', '3201'],
#  ['999001033', 'Loaded_Language', '3206', '3231'],
#  ['999001033', 'Slogans', '3383', '3402'],
#  ['999001033', 'Doubt', '3560', '3594'],
#  ['999001033', 'Loaded_Language', '3705', '3724'],
#  ['730389374', 'Name_Calling,Labeling', '30', '46'],
#  ['730389374', 'Name_Calling,Labeling', '581', '595'],
#  ['730389374', 'Loaded_Language', '1695', '1710'],
#  ['730389374', 'Loaded_Language', '1788', '1821'],
#  ['730389374', 'Slogans', '1910', '1932'],
#  ['730389374', 'Loaded_Language', '2555', '2566'],
#  ['730389374', 'Loaded_Language', '3330', '3337'],
#  ['730389374', 'Thought-terminating_Cliches', '3545', '3561'],
#  ['730389374', 'Repetition', '3823', '3852'],
#  ['730389374', 'Causal_Oversimplification', '4084', '4198'],
#  ['730389374', 'Exaggeration,Minimisation', '4439', '4477'],
#  ['730389374', 'Loaded_Language', '4552', '4597'],
#  ['739091070', 'Loaded_Language', '73', '120'],
#  ['739091070', 'Exaggeration,Minimisation', '563', '583'],
#  ['739091070', 'Exaggeration,Minimisation', '1413', '1476'],
#  ['739091070', 'Causal_Oversimplification', '1496', '1543'],
#  ['739091070', 'Doubt', '1658', '1805'],
#  ['739091070', 'Exaggeration,Minimisation', '1975', '2013'],
#  ['766632016', 'Loaded_Language', '87', '96'],
#  ['766632016', 'Doubt', '114', '234'],
#  ['766632016', 'Appeal_to_Authority', '259', '349'],
#  ['766632016', 'Loaded_Language', '472', '515'],
#  ['766632016', 'Name_Calling,Labeling', '547', '603'],
#  ['766632016', 'Exaggeration,Minimisation', '608', '667'],
#  ['766632016', 'Black-and-White_Fallacy', '1369', '1385'],
#  ['766632016', 'Doubt', '1548', '1577'],
#  ['766632016', 'Loaded_Language', '2084', '2098'],
#  ['766632016', 'Name_Calling,Labeling', '2109', '2117'],
#  ['766632016', 'Name_Calling,Labeling', '2129', '2158'],
#  ['766632016', 'Loaded_Language', '2294', '2303'],
#  ['766632016', 'Exaggeration,Minimisation', '2454', '2480'],
#  ['766632016', 'Loaded_Language', '2516', '2553'],
#  ['766632016', 'Reductio_ad_hitlerum', '2590', '2697'],
#  ['766632016', 'Loaded_Language', '2713', '2731'],
#  ['766632016', 'Exaggeration,Minimisation', '3141', '3169'],
#  ['766632016', 'Loaded_Language', '3487', '3497'],
#  ['766632016', 'Doubt', '3545', '3670'],
#  ['766632016', 'Causal_Oversimplification', '3725', '3838'],
#  ['766632016', 'Doubt', '3858', '3948'],
#  ['766632016', 'Doubt', '4105', '4184'],
#  ['766632016', 'Loaded_Language', '4223', '4248'],
#  ['766632016', 'Loaded_Language', '4286', '4298'],
#  ['766632016', 'Appeal_to_fear-prejudice', '4416', '4455'],
#  ['766632016', 'Appeal_to_fear-prejudice', '4481', '4514'],
#  ['766632016', 'Whataboutism', '4525', '4584'],
#  ['766632016', 'Loaded_Language', '4598', '4653'],
#  ['766632016', 'Whataboutism', '4674', '4754'],
#  ['766632016', 'Exaggeration,Minimisation', '4772', '4823'],
#  ['766632016', 'Loaded_Language', '4845', '4871'],
#  ['766632016', 'Doubt', '5057', '5065'],
#  ['766632016', 'Doubt', '5091', '5167'],
#  ['766632016', 'Loaded_Language', '5183', '5201'],
#  ['766632016', 'Loaded_Language', '5280', '5306'],
#  ['766632016', 'Reductio_ad_hitlerum', '5342', '5402'],
#  ['766632016', 'Loaded_Language', '5414', '5456'],
#  ['766632016', 'Black-and-White_Fallacy', '5512', '5554'],
#  ['766632016', 'Whataboutism', '5614', '5674'],
#  ['766632016', 'Exaggeration,Minimisation', '5701', '5722'],
#  ['766632016', 'Doubt', '5739', '5845'],
#  ['766632016', 'Loaded_Language', '5883', '5906'],
#  ['766632016', 'Black-and-White_Fallacy', '5961', '6014'],
#  ['766632016', 'Name_Calling,Labeling', '6063', '6076'],
#  ['766632016', 'Loaded_Language', '6097', '6118'],
#  ['786731884', 'Repetition', '218', '237'],
#  ['786731884', 'Exaggeration,Minimisation', '318', '412'],
#  ['786731884', 'Doubt', '524', '585'],
#  ['786731884', 'Name_Calling,Labeling', '760', '805'],
#  ['786731884', 'Name_Calling,Labeling', '829', '868'],
#  ['786731884', 'Loaded_Language', '947', '953'],
#  ['786731884', 'Loaded_Language', '1144', '1158'],
#  ['786731884', 'Flag-Waving', '1459', '1493'],
#  ['786731884', 'Loaded_Language', '1559', '1600'],
#  ['786731884', 'Doubt', '1659', '1732'],
#  ['786731884', 'Appeal_to_fear-prejudice', '2049', '2107'],
#  ['786731884', 'Loaded_Language', '2258', '2272'],
#  ['786731884', 'Doubt', '2281', '2336'],
#  ['786731884', 'Name_Calling,Labeling', '2625', '2662'],
#  ['786731884', 'Doubt', '2747', '2856'],
#  ['786731884', 'Black-and-White_Fallacy', '3608', '3667'],
#  ['786731884', 'Loaded_Language', '4226', '4251'],
#  ['786731884', 'Exaggeration,Minimisation', '4267', '4370'],
#  ['786731884', 'Repetition', '4408', '4430'],
#  ['786731884', 'Loaded_Language', '4555', '4593'],
#  ['786731884', 'Loaded_Language', '4803', '4860'],
#  ['723537899', 'Black-and-White_Fallacy', '694', '719'],
#  ['723537899', 'Loaded_Language', '764', '790'],
#  ['723537899', 'Flag-Waving', '859', '871'],
#  ['723537899', 'Loaded_Language', '1262', '1281'],
#  ['723537899', 'Flag-Waving', '2063', '2084'],
#  ['723537899', 'Flag-Waving', '2143', '2167'],
#  ['723537899', 'Loaded_Language', '2190', '2195'],
#  ['723537899', 'Exaggeration,Minimisation', '2276', '2295'],
#  ['723537899', 'Loaded_Language', '2623', '2632'],
#  ['723537899', 'Loaded_Language', '3452', '3470'],
#  ['723537899', 'Exaggeration,Minimisation', '3516', '3559'],
#  ['723537899', 'Black-and-White_Fallacy', '3907', '3953'],
#  ['723537899', 'Loaded_Language', '4525', '4567'],
#  ['999000142', 'Doubt', '125', '228'],
#  ['999000142', 'Repetition', '239', '257'],
#  ['999000142', 'Loaded_Language', '475', '488'],
#  ['999000142', 'Causal_Oversimplification', '566', '661'],
#  ['999000142', 'Loaded_Language', '799', '807'],
#  ['999000142', 'Flag-Waving', '1565', '1731'],
#  ['999000142', 'Loaded_Language', '1916', '1935'],
#  ['999000142', 'Exaggeration,Minimisation', '1985', '2071'],
#  ['999000142', 'Doubt', '2165', '2184'],
#  ['999000142', 'Doubt', '2230', '2305'],
#  ['999000142', 'Doubt', '2346', '2363'],
#  ['999000142', 'Name_Calling,Labeling', '2613', '2637'],
#  ['999000142', 'Loaded_Language', '2679', '2703'],
#  ['999000142', 'Loaded_Language', '2708', '2716'],
#  ['999000142', 'Doubt', '2742', '2801'],
#  ['999000142', 'Loaded_Language', '2917', '2940'],
#  ['999000142', 'Name_Calling,Labeling', '2957', '2967'],
#  ['999000142', 'Doubt', '2981', '3034'],
#  ['999000142', 'Name_Calling,Labeling', '3060', '3102'],
#  ['999000142', 'Name_Calling,Labeling', '3280', '3302'],
#  ['736757214', 'Black-and-White_Fallacy', '285', '370'],
#  ['736757214', 'Exaggeration,Minimisation', '609', '633'],
#  ['7625464289', 'Name_Calling,Labeling', '134', '192'],
#  ['7625464289', 'Causal_Oversimplification', '274', '383'],
#  ['7625464289', 'Loaded_Language', '965', '990'],
#  ['7625464289', 'Name_Calling,Labeling', '1182', '1220'],
#  ['7625464289', 'Loaded_Language', '2105', '2179'],
#  ['7625464289', 'Exaggeration,Minimisation', '2677', '2701'],
#  ['7625464289', 'Doubt', '2715', '2875'],
#  ['7625464289', 'Exaggeration,Minimisation', '2890', '2952'],
#  ['7625464289', 'Loaded_Language', '3049', '3099'],
#  ['7625464289', 'Doubt', '3234', '3358'],
#  ['7625464289', 'Loaded_Language', '3393', '3433'],
#  ['999000155', 'Doubt', '485', '510'],
#  ['999000155', 'Name_Calling,Labeling', '1466', '1475'],
#  ['999000155', 'Loaded_Language', '1914', '1922'],
#  ['999000155', 'Black-and-White_Fallacy', '1966', '2025'],
#  ['999000155', 'Loaded_Language', '2126', '2140'],
#  ['999000155', 'Exaggeration,Minimisation', '2183', '2250'],
#  ['999000155', 'Loaded_Language', '2359', '2410'],
#  ['999000155', 'Loaded_Language', '2429', '2437'],
#  ['999000155', 'Exaggeration,Minimisation', '2465', '2621'],
#  ['999000154', 'Black-and-White_Fallacy', '118', '185'],
#  ['999000154', 'Name_Calling,Labeling', '250', '312'],
#  ['999000154', 'Doubt', '320', '359'],
#  ['999000154', 'Loaded_Language', '472', '516'],
#  ['999000154', 'Black-and-White_Fallacy', '633', '661'],
#  ['999000154', 'Name_Calling,Labeling', '1428', '1456'],
#  ['999000133', 'Doubt', '22', '109'],
#  ['999000133', 'Exaggeration,Minimisation', '137', '235'],
#  ['999000133', 'Loaded_Language', '436', '441'],
#  ['999000133', 'Exaggeration,Minimisation', '766', '816'],
#  ['999000133', 'Loaded_Language', '1801', '1831'],
#  ['740808926', 'Name_Calling,Labeling', '726', '745'],
#  ['740808926', 'Loaded_Language', '1581', '1609'],
#  ['729368012', 'Black-and-White_Fallacy', '3102', '3163'],
#  ['729368012', 'Name_Calling,Labeling', '3803', '3828'],
#  ['729368012', 'Loaded_Language', '4868', '4874'],
#  ['729368012', 'Thought-terminating_Cliches', '5011', '5021'],
#  ['729368012', 'Flag-Waving', '6914', '6969'],
#  ['729368012', 'Name_Calling,Labeling', '7645', '7664'],
#  ['729368012', 'Loaded_Language', '7971', '8021'],
#  ['729368012', 'Name_Calling,Labeling', '8680', '8687'],
#  ['729368012', 'Loaded_Language', '8888', '8911'],
#  ['729368012', 'Name_Calling,Labeling', '9722', '9743'],
#  ['729368012', 'Slogans', '10658', '10698'],
#  ['729368012', 'Exaggeration,Minimisation', '10734', '10774'],
#  ['729368012', 'Doubt', '11124', '11190'],
#  ['694356862', 'Loaded_Language', '86', '121'],
#  ['694356862', 'Name_Calling,Labeling', '600', '626'],
#  ['694356862', 'Whataboutism', '671', '760'],
#  ['694356862', 'Exaggeration,Minimisation', '901', '922'],
#  ['694356862', 'Name_Calling,Labeling', '930', '961'],
#  ['694356862', 'Doubt', '2750', '2786'],
#  ['694356862', 'Exaggeration,Minimisation', '2939', '2986'],
#  ['694356862', 'Loaded_Language', '3974', '3987'],
#  ['694356862', 'Exaggeration,Minimisation', '4301', '4354'],
#  ['694356862', 'Name_Calling,Labeling', '4827', '4841'],
#  ['694356862', 'Loaded_Language', '5061', '5140'],
#  ['694356862', 'Name_Calling,Labeling', '5190', '5206'],
#  ['765029945', 'Causal_Oversimplification', '119', '231'],
#  ['765029945', 'Black-and-White_Fallacy', '247', '324'],
#  ['765029945', 'Doubt', '366', '390'],
#  ['765029945', 'Name_Calling,Labeling', '619', '626'],
#  ['765029945', 'Loaded_Language', '915', '943'],
#  ['765029945', 'Doubt', '1326', '1369'],
#  ['765029945', 'Loaded_Language', '1439', '1448'],
#  ['765029945', 'Loaded_Language', '1519', '1532'],
#  ['765029945', 'Name_Calling,Labeling', '1587', '1608'],
#  ['999000136', 'Loaded_Language', '194', '216'],
#  ['999000136', 'Name_Calling,Labeling', '257', '319'],
#  ['999000136', 'Doubt', '1902', '2069'],
#  ['999000136', 'Loaded_Language', '2376', '2403'],
#  ['999000136', 'Loaded_Language', '2611', '2661'],
#  ['999000136', 'Exaggeration,Minimisation', '2793', '2839'],
#  ['999000136', 'Loaded_Language', '2869', '2879'],
#  ['999000136', 'Causal_Oversimplification', '2904', '3038'],
#  ['999000136', 'Appeal_to_fear-prejudice', '3120', '3167'],
#  ['999000136', 'Loaded_Language', '3478', '3488'],
#  ['999000136', 'Black-and-White_Fallacy', '3610', '3666'],
#  ['999000136', 'Loaded_Language', '3685', '3722'],
#  ['999000136', 'Loaded_Language', '3734', '3755'],
#  ['734265267', 'Name_Calling,Labeling', '1596', '1625'],
#  ['734265267', 'Loaded_Language', '3222', '3229'],
#  ['734265267', 'Exaggeration,Minimisation', '3285', '3317'],
#  ['734265267', 'Flag-Waving', '4154', '4213'],
#  ['767129999', 'Doubt', '261', '307'],
#  ['767129999', 'Exaggeration,Minimisation', '509', '528'],
#  ['767129999', 'Doubt', '1292', '1347'],
#  ['767129999', 'Flag-Waving', '1476', '1513'],
#  ['767129999', 'Loaded_Language', '1582', '1617'],
#  ['767129999', 'Exaggeration,Minimisation', '1696', '1724'],
#  ['767129999', 'Loaded_Language', '1934', '1962'],
#  ['767129999', 'Doubt', '2460', '2499'],
#  ['767129999', 'Exaggeration,Minimisation', '2514', '2572'],
#  ['767129999', 'Doubt', '2599', '2683'],
#  ['7615462239', 'Loaded_Language', '254', '293'],
#  ['7615462239', 'Loaded_Language', '441', '457'],
#  ['7615462239', 'Loaded_Language', '839', '852'],
#  ['7615462239', 'Causal_Oversimplification', '1637', '1714'],
#  ['7615462239', 'Loaded_Language', '1772', '1792'],
#  ['7615462239', 'Name_Calling,Labeling', '1897', '1948'],
#  ['7615462239', 'Exaggeration,Minimisation', '2038', '2153'],
#  ['7615462239', 'Exaggeration,Minimisation', '2273', '2293'],
#  ['7615462239', 'Name_Calling,Labeling', '2305', '2315'],
#  ['7615462239', 'Name_Calling,Labeling', '2371', '2410'],
#  ['7615462239', 'Repetition', '3111', '3169'],
#  ['7615462239', 'Exaggeration,Minimisation', '3364', '3404'],
#  ['7615462239', 'Repetition', '3479', '3508'],
#  ['7615462239', 'Black-and-White_Fallacy', '3568', '3634'],
#  ['7615462239', 'Name_Calling,Labeling', '4316', '4346'],
#  ['7615462239', 'Loaded_Language', '4535', '4563'],
#  ['999000184', 'Name_Calling,Labeling', '234', '255'],
#  ['999000184', 'Name_Calling,Labeling', '317', '342'],
#  ['999000184', 'Name_Calling,Labeling', '428', '475'],
#  ['999000184', 'Doubt', '948', '976'],
#  ['999000184', 'Black-and-White_Fallacy', '980', '1004'],
#  ['999000184', 'Causal_Oversimplification', '1133', '1202'],
#  ['999000184', 'Black-and-White_Fallacy', '1285', '1308'],
#  ['999000184', 'Appeal_to_fear-prejudice', '1709', '1770'],
#  ['999000184', 'Name_Calling,Labeling', '1860', '1886'],
#  ['999000184', 'Flag-Waving', '1911', '1954'],
#  ['999000184', 'Black-and-White_Fallacy', '1963', '2027'],
#  ['999000184', 'Reductio_ad_hitlerum', '2104', '2145'],
#  ['999000184', 'Exaggeration,Minimisation', '2174', '2231'],
#  ['999000184', 'Thought-terminating_Cliches', '2355', '2379'],
#  ['999000184', 'Black-and-White_Fallacy', '2468', '2531'],
#  ['999000184', 'Exaggeration,Minimisation', '2618', '2627'],
#  ['999000184', 'Appeal_to_fear-prejudice', '2730', '2773'],
#  ['999000184', 'Black-and-White_Fallacy', '2787', '2855'],
#  ['999000184', 'Exaggeration,Minimisation', '2892', '2908'],
#  ['999000184', 'Exaggeration,Minimisation', '3521', '3566'],
#  ['999000184', 'Appeal_to_fear-prejudice', '3701', '3734'],
#  ['999000184', 'Name_Calling,Labeling', '3873', '3934'],
#  ['764664283', 'Doubt', '0', '63'],
#  ['764664283', 'Loaded_Language', '254', '303'],
#  ['764664283', 'Appeal_to_fear-prejudice', '333', '383'],
#  ['764664283', 'Loaded_Language', '442', '476'],
#  ['764664283', 'Doubt', '613', '623'],
#  ['764664283', 'Loaded_Language', '678', '732'],
#  ['764664283', 'Thought-terminating_Cliches', '906', '933'],
#  ['764664283', 'Loaded_Language', '992', '1032'],
#  ['764664283', 'Name_Calling,Labeling', '1092', '1100'],
#  ['764664283', 'Black-and-White_Fallacy', '1110', '1148'],
#  ['764664283', 'Loaded_Language', '1152', '1205'],
#  ['764664283', 'Repetition', '1247', '1271'],
#  ['764664283', 'Loaded_Language', '1530', '1596'],
#  ['764664283', 'Loaded_Language', '1673', '1687'],
#  ['764664283', 'Name_Calling,Labeling', '1812', '1838'],
#  ['764664283', 'Name_Calling,Labeling', '1996', '2018'],
#  ['764664283', 'Name_Calling,Labeling', '2062', '2084'],
#  ['764664283', 'Causal_Oversimplification', '2165', '2287'],
#  ['764664283', 'Loaded_Language', '2409', '2519'],
#  ['764664283', 'Black-and-White_Fallacy', '2529', '2581'],
#  ['764664283', 'Appeal_to_fear-prejudice', '2615', '2664'],
#  ['764664283', 'Loaded_Language', '2705', '2725'],
#  ['764664283', 'Loaded_Language', '2811', '2820'],
#  ['764664283', 'Flag-Waving', '3057', '3072'],
#  ['764664283', 'Name_Calling,Labeling', '3098', '3124'],
#  ['764664283', 'Loaded_Language', '3162', '3217'],
#  ['764664283', 'Loaded_Language', '3223', '3229'],
#  ['764664283', 'Name_Calling,Labeling', '3479', '3525'],
#  ['764664283', 'Exaggeration,Minimisation', '3568', '3601'],
#  ['764664283', 'Doubt', '3640', '3667'],
#  ['764664283', 'Loaded_Language', '3739', '3771'],
#  ['764664283', 'Loaded_Language', '3910', '3946'],
#  ['764664283', 'Loaded_Language', '4005', '4021'],
#  ['764664283', 'Loaded_Language', '4110', '4180'],
#  ['764664283', 'Loaded_Language', '4206', '4224'],
#  ['764664283', 'Name_Calling,Labeling', '4299', '4323'],
#  ['764664283', 'Doubt', '5011', '5060'],
#  ['764664283', 'Loaded_Language', '5165', '5232'],
#  ['764664283', 'Loaded_Language', '5405', '5489'],
#  ['764664283', 'Appeal_to_fear-prejudice', '5526', '5563'],
#  ['764664283', 'Doubt', '5637', '5823'],
#  ['764664283', 'Name_Calling,Labeling', '5851', '5857'],
#  ['764664283', 'Loaded_Language', '5946', '5964'],
#  ['764664283', 'Loaded_Language', '6070', '6102'],
#  ['764664283', 'Causal_Oversimplification', '6142', '6178'],
#  ['764664283', 'Loaded_Language', '6460', '6479'],
#  ['764664283', 'Name_Calling,Labeling', '6853', '6884'],
#  ['764664283', 'Name_Calling,Labeling', '6960', '6981'],
#  ['764664283', 'Whataboutism', '7032', '7177'],
#  ['764664283', 'Whataboutism', '7580', '7687'],
#  ['764664283', 'Doubt', '7720', '7825'],
#  ['7786642809', 'Loaded_Language', '222', '230'],
#  ['7786642809', 'Loaded_Language', '393', '412'],
#  ['7786642809', 'Black-and-White_Fallacy', '881', '898'],
#  ['7786642809', 'Doubt', '1334', '1431'],
#  ['7786642809', 'Exaggeration,Minimisation', '1661', '1698'],
#  ['7786642809', 'Name_Calling,Labeling', '2071', '2076'],
#  ['7786642809', 'Loaded_Language', '2823', '2832'],
#  ['7786642809', 'Exaggeration,Minimisation', '3955', '4000'],
#  ['7786642809', 'Loaded_Language', '4438', '4450'],
#  ['7786642809', 'Loaded_Language', '4598', '4614'],
#  ['7786642809', 'Loaded_Language', '5127', '5136'],
#  ['7786642809', 'Doubt', '5465', '5504'],
#  ['7786642809', 'Loaded_Language', '5574', '5622'],
#  ['7786642809', 'Loaded_Language', '5680', '5709'],
#  ['7786642809', 'Loaded_Language', '6081', '6137'],
#  ['7786642809', 'Exaggeration,Minimisation', '6270', '6307'],
#  ['7786642809', 'Exaggeration,Minimisation', '6560', '6706'],
#  ['7786642809', 'Loaded_Language', '6998', '7014'],
#  ['7786642809', 'Causal_Oversimplification', '7041', '7097'],
#  ['7786642809', 'Black-and-White_Fallacy', '7416', '7546'],
#  ['7786642809', 'Doubt', '7658', '7715'],
#  ['7786642809', 'Repetition', '7843', '7883'],
#  ['7786642809', 'Loaded_Language', '8425', '8460'],
#  ['7786642809', 'Loaded_Language', '8733', '8762'],
#  ['7786642809', 'Whataboutism', '8855', '8991'],
#  ['7786642809', 'Exaggeration,Minimisation', '9083', '9127'],
#  ['7786642809', 'Exaggeration,Minimisation', '9193', '9203'],
#  ['7786642809', 'Causal_Oversimplification', '9524', '9617'],
#  ['7786642809', 'Loaded_Language', '9619', '9628'],
#  ['7786642809', 'Doubt', '9674', '9767'],
#  ['7786642809', 'Name_Calling,Labeling', '9810', '9822'],
#  ['7786642809', 'Loaded_Language', '9855', '9868'],
#  ['7786642809', 'Slogans', '9920', '9936'],
#  ['7786642809', 'Loaded_Language', '9955', '9966'],
#  ['7786642809', 'Exaggeration,Minimisation', '10058', '10089'],
#  ['7786642809', 'Doubt', '10154', '10213'],
#  ['7786642809', 'Doubt', '10309', '10381'],
#  ['7786642809', 'Name_Calling,Labeling', '10420', '10453'],
#  ['7786642809', 'Repetition', '10514', '10528'],
#  ['7786642809', 'Appeal_to_fear-prejudice', '10672', '10720'],
#  ['7786642809', 'Doubt', '10832', '10872'],
#  ['7786642809', 'Causal_Oversimplification', '10910', '10993'],
#  ['7786642809', 'Doubt', '11052', '11098'],
#  ['7786642809', 'Loaded_Language', '11246', '11258'],
#  ['7786642809', 'Name_Calling,Labeling', '11529', '11540'],
#  ['7786642809', 'Doubt', '11546', '11693'],
#  ['7786642809', 'Loaded_Language', '11796', '11830'],
#  ['7786642809', 'Loaded_Language', '11986', '11996'],
#  ['7786642809', 'Loaded_Language', '12280', '12293'],
#  ['766084411', 'Doubt', '140', '238'],
#  ['766084411', 'Name_Calling,Labeling', '379', '426'],
#  ['766084411', 'Loaded_Language', '1722', '1738'],
#  ['766084411', 'Causal_Oversimplification', '1987', '2041'],
#  ['766084411', 'Name_Calling,Labeling', '2813', '2843'],
#  ['766084411', 'Loaded_Language', '2922', '2927'],
#  ['766084411', 'Loaded_Language', '3082', '3136'],
#  ['766084411', 'Doubt', '3968', '4010'],
#  ['766084411', 'Doubt', '4259', '4315'],
#  ['766084411', 'Doubt', '4604', '4637'],
#  ['766084411', 'Loaded_Language', '4789', '4801'],
#  ['766084411', 'Exaggeration,Minimisation', '4943', '4965'],
#  ['721710340', 'Name_Calling,Labeling', '3236', '3265'],
#  ['721710340', 'Loaded_Language', '3508', '3527'],
#  ['721710340', 'Flag-Waving', '4267', '4326'],
#  ['7804147009', 'Loaded_Language', '72', '98'],
#  ['7804147009', 'Name_Calling,Labeling', '586', '622'],
#  ['7804147009', 'Loaded_Language', '716', '735'],
#  ['7804147009', 'Loaded_Language', '947', '961'],
#  ['7804147009', 'Loaded_Language', '1144', '1177'],
#  ['7804147009', 'Loaded_Language', '1201', '1228'],
#  ['7804147009', 'Name_Calling,Labeling', '1306', '1336'],
#  ['7804147009', 'Exaggeration,Minimisation', '1375', '1438'],
#  ['7804147009', 'Loaded_Language', '1711', '1727'],
#  ['7804147009', 'Doubt', '1754', '1871'],
#  ['7804147009', 'Doubt', '2159', '2262'],
#  ['7804147009', 'Loaded_Language', '2577', '2587'],
#  ['7804147009', 'Name_Calling,Labeling', '2809', '2826'],
#  ['7804147009', 'Thought-terminating_Cliches', '2929', '2948'],
#  ['7804147009', 'Causal_Oversimplification', '2964', '3009'],
#  ['7804147009', 'Loaded_Language', '3011', '3015'],
#  ['7804147009', 'Loaded_Language', '3022', '3043'],
#  ['7804147009', 'Exaggeration,Minimisation', '3534', '3573'],
#  ['7804147009', 'Doubt', '3591', '3646'],
#  ['7804147009', 'Exaggeration,Minimisation', '3747', '3775'],
#  ['7804147009', 'Reductio_ad_hitlerum', '3797', '3895'],
#  ['7804147009', 'Loaded_Language', '3936', '3971'],
#  ['7804147009', 'Name_Calling,Labeling', '4233', '4249'],
#  ['7804147009', 'Doubt', '4254', '4285'],
#  ['7804147009', 'Exaggeration,Minimisation', '4408', '4471'],
#  ['7804147009', 'Exaggeration,Minimisation', '4525', '4591'],
#  ['7804147009', 'Name_Calling,Labeling', '4656', '4662'],
#  ['7804147009', 'Loaded_Language', '4712', '4758'],
#  ['7804147009', 'Loaded_Language', '4795', '4823'],
#  ['7804147009', 'Exaggeration,Minimisation', '4951', '4992'],
#  ['7804147009', 'Repetition', '5063', '5085'],
#  ['7804147009', 'Exaggeration,Minimisation', '5229', '5265'],
#  ['7804147009', 'Whataboutism', '5460', '5567'],
#  ['7804147009', 'Name_Calling,Labeling', '5583', '5610'],
#  ['7804147009', 'Doubt', '5636', '5712'],
#  ['7804147009', 'Loaded_Language', '5762', '5774'],
#  ['7804147009', 'Exaggeration,Minimisation', '5783', '5801'],
#  ['7804147009', 'Thought-terminating_Cliches', '5897', '5928'],
#  ['7804147009', 'Loaded_Language', '6030', '6076'],
#  ['7804147009', 'Loaded_Language', '6454', '6474'],
#  ['7804147009', 'Loaded_Language', '6512', '6528'],
#  ['7804147009', 'Loaded_Language', '6587', '6601'],
#  ['7804147009', 'Loaded_Language', '6784', '6817'],
#  ['7804147009', 'Loaded_Language', '6845', '6868'],
#  ['7804147009', 'Loaded_Language', '6969', '6986'],
#  ['7804147009', 'Exaggeration,Minimisation', '7237', '7266'],
#  ['7804147009', 'Loaded_Language', '7467', '7495'],
#  ['7804147009', 'Loaded_Language', '7562', '7578'],
#  ['7804147009', 'Exaggeration,Minimisation', '7660', '7698'],
#  ['7804147009', 'Loaded_Language', '7854', '7898'],
#  ['7804147009', 'Thought-terminating_Cliches', '8099', '8116'],
#  ['7804147009', 'Loaded_Language', '8235', '8250'],
#  ['7804147009', 'Loaded_Language', '8863', '8926'],
#  ['7804147009', 'Loaded_Language', '8930', '8968'],
#  ['7804147009', 'Loaded_Language', '9273', '9294'],
#  ['7804147009', 'Loaded_Language', '9323', '9373'],
#  ['7804147009', 'Exaggeration,Minimisation', '9454', '9584'],
#  ['7804147009', 'Causal_Oversimplification', '9635', '9772'],
#  ['7804147009', 'Whataboutism', '9812', '9842'],
#  ['7804147009', 'Loaded_Language', '9869', '9932'],
#  ['7804147009', 'Loaded_Language', '9960', '9989'],
#  ['7804147009', 'Doubt', '10181', '10325'],
#  ['7804147009', 'Doubt', '10371', '10418'],
#  ['7804147009', 'Loaded_Language', '10543', '10556'],
#  ['7804147009', 'Loaded_Language', '10643', '10656'],
#  ['7804147009', 'Loaded_Language', '10700', '10708'],
#  ['7804147009', 'Loaded_Language', '10915', '10935'],
#  ['7804147009', 'Flag-Waving', '10988', '11019'],
#  ['7804147009', 'Name_Calling,Labeling', '11110', '11153'],
#  ['7804147009', 'Loaded_Language', '11226', '11242'],
#  ['7804147009', 'Slogans', '11617', '11624'],
#  ['7804147009', 'Black-and-White_Fallacy', '11628', '11684'],
#  ['7804147009', 'Loaded_Language', '12161', '12184'],
#  ['7804147009', 'Doubt', '12628', '12694'],
#  ['7804147009', 'Exaggeration,Minimisation', '12933', '12961'],
#  ['7804147009', 'Black-and-White_Fallacy', '13056', '13077'],
#  ['7804147009', 'Doubt', '13194', '13219'],
#  ['7804147009', 'Loaded_Language', '13500', '13544'],
#  ['7804147009', 'Name_Calling,Labeling', '13623', '13639'],
#  ['7804147009', 'Name_Calling,Labeling', '13953', '13993'],
#  ['7804147009', 'Loaded_Language', '14001', '14011'],
#  ['7804147009', 'Loaded_Language', '14089', '14132'],
#  ['7804147009', 'Doubt', '14372', '14388'],
#  ['7804147009', 'Black-and-White_Fallacy', '14830', '14871'],
#  ['7804147009', 'Loaded_Language', '15211', '15231'],
#  ['7804147009', 'Black-and-White_Fallacy', '16075', '16146'],
#  ['7804147009', 'Doubt', '16287', '16374'],
#  ['7804147009', 'Loaded_Language', '16640', '16689'],
#  ['7804147009', 'Exaggeration,Minimisation', '16857', '16920'],
#  ['7804147009', 'Loaded_Language', '17662', '17674'],
#  ['7804147009', 'Loaded_Language', '17788', '17816'],
#  ['7804147009', 'Thought-terminating_Cliches', '17989', '18011'],
#  ['7804147009', 'Exaggeration,Minimisation', '18058', '18076'],
#  ['7804147009', 'Loaded_Language', '18080', '18099'],
#  ['7804147009', 'Loaded_Language', '18186', '18218'],
#  ['7804147009', 'Loaded_Language', '18259', '18282'],
#  ['7804147009', 'Loaded_Language', '18353', '18362'],
#  ['7804147009', 'Loaded_Language', '18410', '18446'],
#  ['7804147009', 'Name_Calling,Labeling', '18473', '18536'],
#  ['7804147009', 'Thought-terminating_Cliches', '18633', '18655'],
#  ['7804147009', 'Thought-terminating_Cliches', '18701', '18722'],
#  ['700461600', 'Thought-terminating_Cliches', '123', '132'],
#  ['700461600', 'Thought-terminating_Cliches', '572', '582'],
#  ['700461600', 'Flag-Waving', '688', '755'],
#  ['700461600', 'Name_Calling,Labeling', '895', '967'],
#  ['700461600', 'Black-and-White_Fallacy', '1300', '1334'],
#  ['700461600', 'Loaded_Language', '1899', '1906'],
#  ['700461600', 'Exaggeration,Minimisation', '2109', '2146'],
#  ['700461600', 'Exaggeration,Minimisation', '2157', '2186'],
#  ['700461600', 'Loaded_Language', '2559', '2572'],
#  ['700461600', 'Flag-Waving', '2726', '2751'],
#  ['700461600', 'Loaded_Language', '2913', '2953'],
#  ['700461600', 'Slogans', '3115', '3163'],
#  ['700461600', 'Flag-Waving', '3652', '3659'],
#  ['700461600', 'Name_Calling,Labeling', '4244', '4254'],
#  ['700461600', 'Exaggeration,Minimisation', '4344', '4357'],
#  ['700461600', 'Repetition', '4365', '4382'],
#  ['999001032', 'Loaded_Language', '218', '261'],
#  ['999001032', 'Name_Calling,Labeling', '331', '346'],
#  ['999001032', 'Thought-terminating_Cliches', '363', '379'],
#  ['999001032', 'Black-and-White_Fallacy', '454', '504'],
#  ['999001032', 'Loaded_Language', '607', '646'],
#  ['999001032', 'Exaggeration,Minimisation', '786', '805'],
#  ['999001032', 'Loaded_Language', '1148', '1172'],
#  ['999001032', 'Loaded_Language', '1284', '1310'],
#  ['999001032', 'Exaggeration,Minimisation', '1532', '1558'],
#  ['999001032', 'Name_Calling,Labeling', '1574', '1589'],
#  ['999001032', 'Doubt', '1596', '1616'],
#  ['999001032', 'Doubt', '1986', '1996'],
#  ['999001032', 'Name_Calling,Labeling', '2746', '2754'],
#  ['999001032', 'Loaded_Language', '2941', '2947'],
#  ['999001032', 'Name_Calling,Labeling', '3026', '3035'],
#  ['999001032', 'Loaded_Language', '3280', '3315'],
#  ['999001032', 'Name_Calling,Labeling', '3451', '3486'],
#  ['999001032', 'Name_Calling,Labeling', '3541', '3546'],
#  ['999001032', 'Exaggeration,Minimisation', '3661', '3680'],
#  ['999001032', 'Doubt', '3880', '3915'],
#  ['999001032', 'Loaded_Language', '3978', '3989'],
#  ['999001032', 'Repetition', '4003', '4023'],
#  ['999001032', 'Repetition', '4052', '4062'],
#  ['999001032', 'Appeal_to_Authority', '4108', '4124'],
#  ['999001032', 'Appeal_to_fear-prejudice', '4147', '4154'],
#  ['999001032', 'Loaded_Language', '4157', '4179'],
#  ['999001032', 'Doubt', '4287', '4337'],
#  ['999001032', 'Repetition', '5234', '5247'],
#  ['999001032', 'Exaggeration,Minimisation', '5331', '5353'],
#  ['999001032', 'Causal_Oversimplification', '5381', '5495'],
#  ['999001032', 'Loaded_Language', '5499', '5520'],
#  ['999001032', 'Doubt', '5679', '5733'],
#  ['735815503', 'Name_Calling,Labeling', '359', '384'],
#  ['735815503', 'Loaded_Language', '869', '894'],
#  ['735815503', 'Appeal_to_fear-prejudice', '1357', '1412'],
#  ['780787440', 'Name_Calling,Labeling', '420', '441'],
#  ['780787440', 'Causal_Oversimplification', '493', '546'],
#  ['780787440', 'Loaded_Language', '1026', '1061'],
#  ['780787440', 'Causal_Oversimplification', '1199', '1308'],
#  ['780787440', 'Loaded_Language', '1354', '1378'],
#  ['780787440', 'Loaded_Language', '1452', '1460'],
#  ['780787440', 'Causal_Oversimplification', '1756', '1780'],
#  ['780787440', 'Repetition', '1786', '1798'],
#  ['780787440', 'Exaggeration,Minimisation', '1882', '1904'],
#  ['780787440', 'Loaded_Language', '2109', '2120'],
#  ['780787440', 'Thought-terminating_Cliches', '2316', '2326'],
#  ['780787440', 'Black-and-White_Fallacy', '2563', '2589'],
#  ['780787440', 'Loaded_Language', '2993', '3010'],
#  ['699291100', 'Name_Calling,Labeling', '647', '673'],
#  ['699291100', 'Repetition', '1674', '1691'],
#  ['699291100', 'Name_Calling,Labeling', '1945', '1956'],
#  ['699291100', 'Loaded_Language', '3354', '3389'],
#  ['699291100', 'Loaded_Language', '3997', '4016'],
#  ['699291100', 'Slogans', '4822', '4881'],
#  ['699291100', 'Loaded_Language', '4993', '5012'],
#  ['699291100', 'Name_Calling,Labeling', '6361', '6371']]

# %%
rrr
# Out:
# [['698018235', 'Appeal_to_Authority', '1333', '1351', 'have been canceled'],
#  ['703821117',
#   'Appeal_to_Authority',
#   '3523',
#   '3557',
#   'Guatemalan operation was brilliant'],
#  ['111111131', 'Appeal_to_Authority', '4136', '4150', "I learned he's"],
#  ['703698295', 'Appeal_to_Authority', '1182', '1190', 'Crux, he'],
#  ['694327499',
#   'Appeal_to_Authority',
#   '1503',
#   '1526',
#   'Dr. Robert Fastiggi and'],
#  ['700551604',
#   'Appeal_to_Authority',
#   '6721',
#   '6743',
#   'operation to establish'],
#  ['701553469', 'Appeal_to_Authority', '1993', '2003', 'doubt from'],
#  ['701553469',
#   'Appeal_to_Authority',
#   '2008',
#   '2036',
#   'information circulated about']]

# %%
exportResult(aaa)

# %%
aaa
# Out:
# [['710100700', 'Name_Calling,Labeling', '0', '11'],
#  ['710100700', 'Doubt', '1295', '1336'],
#  ['785801366', 'Doubt', '100', '105'],
#  ['785801366', 'Appeal_to_fear-prejudice', '182', '255'],
#  ['785801366', 'Doubt', '330', '409'],
#  ['785801366', 'Exaggeration,Minimisation', '444', '525'],
#  ['785801366', 'Black-and-White_Fallacy', '777', '850'],
#  ['785801366', 'Loaded_Language', '1387', '1401'],
#  ['785801366', 'Causal_Oversimplification', '1462', '1545'],
#  ['785801366', 'Exaggeration,Minimisation', '1612', '1644'],
#  ['785801366', 'Exaggeration,Minimisation', '1752', '1833'],
#  ['785801366', 'Loaded_Language', '1973', '1997'],
#  ['785801366', 'Loaded_Language', '2026', '2046'],
#  ['785801366', 'Name_Calling,Labeling', '2140', '2161'],
#  ['785801366', 'Loaded_Language', '2260', '2275'],
#  ['785801366', 'Repetition', '2397', '2418'],
#  ['785801366', 'Exaggeration,Minimisation', '2529', '2574'],
#  ['785801366', 'Black-and-White_Fallacy', '2625', '2691'],
#  ['785801366', 'Slogans', '3296', '3359'],
#  ['785801366', 'Appeal_to_fear-prejudice', '3823', '3886'],
#  ['785801366', 'Name_Calling,Labeling', '3942', '3982'],
#  ['785801366', 'Name_Calling,Labeling', '3988', '4000'],
#  ['785801366', 'Exaggeration,Minimisation', '4239', '4295'],
#  ['785801366', 'Loaded_Language', '4316', '4328'],
#  ['785801366', 'Loaded_Language', '4370', '4417'],
#  ['785801366', 'Exaggeration,Minimisation', '4526', '4554'],
#  ['785801366', 'Doubt', '4843', '4960'],
#  ['785801366', 'Appeal_to_fear-prejudice', '5224', '5266'],
#  ['785801366', 'Whataboutism', '5760', '5892'],
#  ['785801366', 'Loaded_Language', '5920', '5979'],
#  ['785801366', 'Black-and-White_Fallacy', '6104', '6229'],
#  ['785801366', 'Appeal_to_fear-prejudice', '6420', '6485'],
#  ['785801366', 'Loaded_Language', '6574', '6602'],
#  ['785801366', 'Flag-Waving', '6977', '7000'],
#  ['785801366', 'Doubt', '7098', '7106'],
#  ['785801366', 'Name_Calling,Labeling', '7475', '7499'],
#  ['785801366', 'Slogans', '7504', '7557'],
#  ['785801366', 'Exaggeration,Minimisation', '7590', '7642'],
#  ['785801366', 'Causal_Oversimplification', '7713', '7832'],
#  ['785801366', 'Exaggeration,Minimisation', '7879', '7891'],
#  ['785801366', 'Doubt', '8013', '8091'],
#  ['785801366', 'Loaded_Language', '8160', '8185'],
#  ['785801366', 'Exaggeration,Minimisation', '8201', '8304'],
#  ['785801366', 'Loaded_Language', '8488', '8526'],
#  ['785801366', 'Loaded_Language', '8736', '8793'],
#  ['785801366', 'Exaggeration,Minimisation', '8878', '8953'],
#  ['785801366', 'Exaggeration,Minimisation', '8991', '9111'],
#  ['785801366', 'Whataboutism', '9288', '9391'],
#  ['785801366', 'Whataboutism', '9447', '9489'],
#  ['723501118', 'Exaggeration,Minimisation', '93', '107'],
#  ['723501118', 'Loaded_Language', '121', '193'],
#  ['723501118', 'Loaded_Language', '340', '372'],
#  ['723501118', 'Exaggeration,Minimisation', '414', '449'],
#  ['723501118', 'Exaggeration,Minimisation', '613', '658'],
#  ['723501118', 'Whataboutism', '742', '847'],
#  ['723501118', 'Name_Calling,Labeling', '907', '919'],
#  ['723501118', 'Appeal_to_fear-prejudice', '1366', '1436'],
#  ['723501118', 'Slogans', '1669', '1706'],
#  ['723501118', 'Appeal_to_fear-prejudice', '2532', '2570'],
#  ['999000125', 'Loaded_Language', '210', '272'],
#  ['999000125', 'Name_Calling,Labeling', '749', '760'],
#  ['999000125', 'Doubt', '868', '988'],
#  ['999000125', 'Loaded_Language', '1484', '1490'],
#  ['999000125', 'Slogans', '1542', '1569'],
#  ['999000125', 'Doubt', '2058', '2078'],
#  ['999000125', 'Exaggeration,Minimisation', '2330', '2369'],
#  ['999000125', 'Doubt', '2746', '2809'],
#  ['999000125', 'Name_Calling,Labeling', '3021', '3030'],
#  ['999000125', 'Name_Calling,Labeling', '3223', '3230'],
#  ['999000125', 'Black-and-White_Fallacy', '3246', '3272'],
#  ['999000125', 'Black-and-White_Fallacy', '3300', '3333'],
#  ['999000125', 'Doubt', '3512', '3597'],
#  ['701933838', 'Doubt', '1073', '1114'],
#  ['999000675', 'Loaded_Language', '110', '151'],
#  ['999000675', 'Name_Calling,Labeling', '285', '297'],
#  ['999000675', 'Loaded_Language', '508', '549'],
#  ['999000675', 'Loaded_Language', '966', '994'],
#  ['999000675', 'Exaggeration,Minimisation', '1007', '1034'],
#  ['999000675', 'Appeal_to_fear-prejudice', '1605', '1645'],
#  ['999000675', 'Black-and-White_Fallacy', '1834', '1902'],
#  ['999000675', 'Name_Calling,Labeling', '1945', '2009'],
#  ['999000675', 'Doubt', '2061', '2067'],
#  ['999000675', 'Causal_Oversimplification', '2232', '2283'],
#  ['999000158', 'Loaded_Language', '343', '358'],
#  ['999000158', 'Flag-Waving', '461', '469'],
#  ['999000158', 'Exaggeration,Minimisation', '1236', '1249'],
#  ['999000158', 'Exaggeration,Minimisation', '1638', '1675'],
#  ['999000158', 'Doubt', '1906', '1986'],
#  ['999000158', 'Doubt', '2064', '2107'],
#  ['999000158', 'Name_Calling,Labeling', '2208', '2216'],
#  ['999000158', 'Loaded_Language', '2301', '2328'],
#  ['999000158', 'Name_Calling,Labeling', '2462', '2479'],
#  ['999000158', 'Doubt', '2680', '2744'],
#  ['999000158', 'Loaded_Language', '2827', '2846'],
#  ['999000158', 'Appeal_to_fear-prejudice', '3109', '3129'],
#  ['999000158', 'Doubt', '3427', '3484'],
#  ['999000158', 'Name_Calling,Labeling', '3496', '3515'],
#  ['999000158', 'Loaded_Language', '3542', '3568'],
#  ['999000158', 'Name_Calling,Labeling', '3629', '3656'],
#  ['999000565', 'Loaded_Language', '87', '172'],
#  ['999000565', 'Exaggeration,Minimisation', '339', '378'],
#  ['999000565', 'Loaded_Language', '427', '456'],
#  ['999000565', 'Loaded_Language', '589', '614'],
#  ['999000599', 'Name_Calling,Labeling', '15', '53'],
#  ['999000599', 'Name_Calling,Labeling', '160', '202'],
#  ['999000599', 'Thought-terminating_Cliches', '301', '340'],
#  ['999000599', 'Flag-Waving', '497', '554'],
#  ['999000599', 'Loaded_Language', '707', '715'],
#  ['999000599', 'Flag-Waving', '834', '1000'],
#  ['999000599', 'Doubt', '1070', '1118'],
#  ['999000599', 'Loaded_Language', '1158', '1177'],
#  ['999000599', 'Exaggeration,Minimisation', '1227', '1313'],
#  ['999000599', 'Name_Calling,Labeling', '1476', '1491'],
#  ['999000599', 'Doubt', '1808', '1862'],
#  ['999000599', 'Name_Calling,Labeling', '1875', '1896'],
#  ['999000599', 'Thought-terminating_Cliches', '1935', '1954'],
#  ['999000599', 'Doubt', '2074', '2140'],
#  ['735265649', 'Name_Calling,Labeling', '520', '563'],
#  ['735265649', 'Loaded_Language', '1316', '1331'],
#  ['735265649', 'Loaded_Language', '1385', '1438'],
#  ['735265649', 'Loaded_Language', '1623', '1645'],
#  ['735265649', 'Name_Calling,Labeling', '2011', '2031'],
#  ['999000135', 'Loaded_Language', '59', '106'],
#  ['999000135', 'Doubt', '223', '265'],
#  ['999000135', 'Doubt', '431', '500'],
#  ['999000135', 'Loaded_Language', '572', '585'],
#  ['999000135', 'Exaggeration,Minimisation', '790', '813'],
#  ['999000135', 'Doubt', '871', '906'],
#  ['999000135', 'Exaggeration,Minimisation', '932', '1033'],
#  ['999000135', 'Black-and-White_Fallacy', '1039', '1091'],
#  ['999000135', 'Loaded_Language', '1870', '1891'],
#  ['999000135', 'Black-and-White_Fallacy', '1934', '1976'],
#  ['999000135', 'Exaggeration,Minimisation', '2000', '2055'],
#  ['999000135', 'Loaded_Language', '2160', '2174'],
#  ['999000135', 'Causal_Oversimplification', '2231', '2292'],
#  ['999000135', 'Loaded_Language', '2320', '2343'],
#  ['999000135', 'Doubt', '2394', '2501'],
#  ['999000135', 'Loaded_Language', '2598', '2607'],
#  ['999000135', 'Slogans', '2653', '2688'],
#  ['735855251', 'Name_Calling,Labeling', '1975', '2004'],
#  ['735855251', 'Loaded_Language', '2408', '2420'],
#  ['999000149', 'Appeal_to_fear-prejudice', '97', '141'],
#  ['999000149', 'Exaggeration,Minimisation', '243', '308'],
#  ['999000149', 'Name_Calling,Labeling', '328', '377'],
#  ['999000149', 'Black-and-White_Fallacy', '1292', '1352'],
#  ['999000149', 'Loaded_Language', '1459', '1477'],
#  ['999000149', 'Appeal_to_fear-prejudice', '1552', '1588'],
#  ['999000149', 'Black-and-White_Fallacy', '1602', '1670'],
#  ['999000149', 'Loaded_Language', '2023', '2038'],
#  ['999000149', 'Loaded_Language', '2989', '3069'],
#  ['999000149', 'Black-and-White_Fallacy', '3097', '3143'],
#  ['999000149', 'Repetition', '3192', '3224'],
#  ['722507879', 'Name_Calling,Labeling', '464', '488'],
#  ['722507879', 'Name_Calling,Labeling', '641', '702'],
#  ['722507879', 'Name_Calling,Labeling', '1361', '1380'],
#  ['722507879', 'Loaded_Language', '2598', '2618'],
#  ['722507879', 'Appeal_to_fear-prejudice', '3370', '3407'],
#  ['722507879', 'Name_Calling,Labeling', '6278', '6285'],
#  ['722507879', 'Loaded_Language', '6579', '6611'],
#  ['765197039', 'Reductio_ad_hitlerum', '69', '121'],
#  ['765197039', 'Doubt', '187', '268'],
#  ['765197039', 'Loaded_Language', '336', '351'],
#  ['765197039', 'Loaded_Language', '420', '435'],
#  ['765197039', 'Causal_Oversimplification', '592', '696'],
#  ['765197039', 'Causal_Oversimplification', '713', '780'],
#  ['765197039', 'Doubt', '808', '874'],
#  ['765197039', 'Repetition', '926', '940'],
#  ['765197039', 'Causal_Oversimplification', '1076', '1137'],
#  ['765197039', 'Doubt', '1229', '1281'],
#  ['765197039', 'Whataboutism', '1971', '2041'],
#  ['765197039', 'Exaggeration,Minimisation', '2139', '2185'],
#  ['765197039', 'Doubt', '2199', '2505'],
#  ['765197039', 'Name_Calling,Labeling', '2534', '2569'],
#  ['765197039', 'Reductio_ad_hitlerum', '2649', '2879'],
#  ['765197039', 'Flag-Waving', '2914', '2926'],
#  ['765197039', 'Loaded_Language', '2948', '3062'],
#  ['765197039', 'Loaded_Language', '3219', '3242'],
#  ['765197039', 'Doubt', '3370', '3487'],
#  ['765197039', 'Loaded_Language', '3547', '3578'],
#  ['765197039', 'Black-and-White_Fallacy', '3695', '3753'],
#  ['765197039', 'Doubt', '3797', '3937'],
#  ['765197039', 'Exaggeration,Minimisation', '4041', '4075'],
#  ['765197039', 'Loaded_Language', '4223', '4242'],
#  ['765197039', 'Exaggeration,Minimisation', '4279', '4456'],
#  ['765197039', 'Appeal_to_Authority', '4468', '4528'],
#  ['765197039', 'Doubt', '4554', '4583'],
#  ['765197039', 'Black-and-White_Fallacy', '4619', '4712'],
#  ['765197039', 'Name_Calling,Labeling', '4743', '4789'],
#  ['7634408719', 'Name_Calling,Labeling', '2091', '2111'],
#  ['779394730', 'Loaded_Language', '1205', '1247'],
#  ['779394730', 'Slogans', '1704', '1718'],
#  ['779394730', 'Loaded_Language', '1907', '1927'],
#  ['779394730', 'Loaded_Language', '3287', '3307'],
#  ['779394730', 'Repetition', '3353', '3368'],
#  ['779394730', 'Name_Calling,Labeling', '3486', '3500'],
#  ['779394730', 'Loaded_Language', '3736', '3756'],
#  ['779394730', 'Appeal_to_fear-prejudice', '4009', '4052'],
#  ['779394730', 'Doubt', '4281', '4348'],
#  ['735090638', 'Name_Calling,Labeling', '108', '168'],
#  ['735090638', 'Loaded_Language', '270', '289'],
#  ['735090638', 'Flag-Waving', '926', '944'],
#  ['735090638', 'Flag-Waving', '1042', '1070'],
#  ['735090638', 'Loaded_Language', '1100', '1118'],
#  ['735090638', 'Thought-terminating_Cliches', '2361', '2374'],
#  ['735090638', 'Exaggeration,Minimisation', '2410', '2442'],
#  ['735090638', 'Loaded_Language', '2548', '2564'],
#  ['776535164', 'Name_Calling,Labeling', '495', '503'],
#  ['999000124', 'Exaggeration,Minimisation', '99', '125'],
#  ['999000124', 'Flag-Waving', '557', '595'],
#  ['999000124', 'Doubt', '627', '675'],
#  ['999000124', 'Name_Calling,Labeling', '678', '715'],
#  ['999000124', 'Repetition', '1063', '1078'],
#  ['999000124', 'Loaded_Language', '1269', '1280'],
#  ['723793978', 'Loaded_Language', '179', '193'],
#  ['723793978', 'Exaggeration,Minimisation', '239', '271'],
#  ['723793978', 'Exaggeration,Minimisation', '440', '485'],
#  ['723793978', 'Name_Calling,Labeling', '536', '553'],
#  ['723793978', 'Name_Calling,Labeling', '1418', '1430'],
#  ['111111136', 'Loaded_Language', '63', '95'],
#  ['111111136', 'Exaggeration,Minimisation', '137', '172'],
#  ['111111136', 'Exaggeration,Minimisation', '336', '381'],
#  ['111111136', 'Name_Calling,Labeling', '516', '525'],
#  ['111111136', 'Name_Calling,Labeling', '708', '720'],
#  ['111111136', 'Black-and-White_Fallacy', '1169', '1214'],
#  ['111111136', 'Loaded_Language', '1234', '1242'],
#  ['111111136', 'Causal_Oversimplification', '1579', '1654'],
#  ['111111136', 'Loaded_Language', '1961', '1968'],
#  ['787002327', 'Doubt', '193', '208'],
#  ['787002327', 'Repetition', '288', '307'],
#  ['787002327', 'Repetition', '394', '428'],
#  ['787002327', 'Doubt', '553', '614'],
#  ['787002327', 'Causal_Oversimplification', '1131', '1288'],
#  ['787002327', 'Name_Calling,Labeling', '1795', '1833'],
#  ['787002327', 'Name_Calling,Labeling', '2669', '2692'],
#  ['787002327', 'Black-and-White_Fallacy', '2965', '3061'],
#  ['787002327', 'Loaded_Language', '3575', '3610'],
#  ['787002327', 'Name_Calling,Labeling', '4003', '4061'],
#  ['787002327', 'Appeal_to_fear-prejudice', '4084', '4103'],
#  ['787002327', 'Exaggeration,Minimisation', '4199', '4240'],
#  ['787002327', 'Repetition', '5243', '5283'],
#  ['787002327', 'Name_Calling,Labeling', '5401', '5462'],
#  ['787002327', 'Name_Calling,Labeling', '5601', '5652'],
#  ['787002327', 'Name_Calling,Labeling', '5903', '5932'],
#  ['787002327', 'Loaded_Language', '6168', '6213'],
#  ['787002327', 'Doubt', '6457', '6516'],
#  ['787002327', 'Exaggeration,Minimisation', '6674', '6766'],
#  ['787002327', 'Exaggeration,Minimisation', '6910', '6955'],
#  ['787002327', 'Doubt', '7092', '7137'],
#  ['787002327', 'Exaggeration,Minimisation', '7338', '7364'],
#  ['999001970', 'Loaded_Language', '228', '244'],
#  ['999001970', 'Loaded_Language', '364', '426'],
#  ['999001970', 'Name_Calling,Labeling', '903', '914'],
#  ['999001970', 'Doubt', '1022', '1142'],
#  ['999001970', 'Thought-terminating_Cliches', '1270', '1277'],
#  ['999001970', 'Loaded_Language', '1836', '1842'],
#  ['999001970', 'Slogans', '1894', '1921'],
#  ['999001970', 'Name_Calling,Labeling', '2184', '2191'],
#  ['999001970', 'Black-and-White_Fallacy', '2207', '2233'],
#  ['999001970', 'Black-and-White_Fallacy', '2261', '2294'],
#  ['999001970', 'Doubt', '2473', '2558'],
#  ['741896049', 'Name_Calling,Labeling', '539', '560'],
#  ['741896049', 'Loaded_Language', '1151', '1171'],
#  ['709732928', 'Repetition', '322', '343'],
#  ['709732928', 'Black-and-White_Fallacy', '764', '799'],
#  ['709732928', 'Loaded_Language', '1189', '1232'],
#  ['709732928', 'Loaded_Language', '1405', '1419'],
#  ['709732928', 'Loaded_Language', '1807', '1820'],
#  ['709732928', 'Doubt', '2280', '2318'],
#  ['709732928', 'Exaggeration,Minimisation', '2557', '2587'],
#  ['709732928', 'Loaded_Language', '3001', '3047'],
#  ['709732928', 'Thought-terminating_Cliches', '4325', '4348'],
#  ['709732928', 'Loaded_Language', '5373', '5391'],
#  ['709732928', 'Loaded_Language', '5705', '5713'],
#  ['709732928', 'Exaggeration,Minimisation', '6839', '6866'],
#  ['709732928', 'Thought-terminating_Cliches', '7147', '7172'],
#  ['709732928', 'Causal_Oversimplification', '7197', '7263'],
#  ['709732928', 'Exaggeration,Minimisation', '7326', '7366'],
#  ['709732928', 'Causal_Oversimplification', '7441', '7503'],
#  ['709732928', 'Doubt', '7559', '7569'],
#  ['709732928', 'Exaggeration,Minimisation', '7579', '7604'],
#  ['709732928', 'Exaggeration,Minimisation', '7811', '7855'],
#  ['709732928', 'Name_Calling,Labeling', '8502', '8539'],
#  ['709732928', 'Exaggeration,Minimisation', '9139', '9155'],
#  ['709732928', 'Loaded_Language', '9281', '9289'],
#  ['709732928', 'Name_Calling,Labeling', '9394', '9406'],
#  ['709732928', 'Loaded_Language', '9530', '9545'],
#  ['709732928', 'Exaggeration,Minimisation', '9783', '9792'],
#  ['709732928', 'Exaggeration,Minimisation', '9807', '9848'],
#  ['709732928', 'Doubt', '9881', '9954'],
#  ['709732928', 'Doubt', '10163', '10215'],
#  ['709732928', 'Repetition', '10275', '10286'],
#  ['709732928', 'Loaded_Language', '10416', '10434'],
#  ['709732928', 'Black-and-White_Fallacy', '10525', '10566'],
#  ['709732928', 'Slogans', '10626', '10669'],
#  ['709732928', 'Doubt', '10679', '10699'],
#  ['709732928', 'Doubt', '10777', '10810'],
#  ['709732928', 'Doubt', '11327', '11365'],
#  ['709732928', 'Whataboutism', '11412', '11462'],
#  ['709732928', 'Loaded_Language', '11481', '11489'],
#  ['709732928', 'Doubt', '11751', '11783'],
#  ['709732928', 'Name_Calling,Labeling', '11978', '12005'],
#  ['999001033', 'Causal_Oversimplification', '32', '87'],
#  ['999001033', 'Causal_Oversimplification', '128', '183'],
#  ['999001033', 'Loaded_Language', '343', '406'],
#  ['999001033', 'Loaded_Language', '1172', '1207'],
#  ['999001033', 'Name_Calling,Labeling', '1454', '1460'],
#  ['999001033', 'Loaded_Language', '1556', '1583'],
#  ['999001033', 'Name_Calling,Labeling', '2184', '2192'],
#  ['999001033', 'Loaded_Language', '2335', '2399'],
#  ['999001033', 'Name_Calling,Labeling', '2520', '2549'],
#  ['999001033', 'Doubt', '2843', '2861'],
#  ['999001033', 'Loaded_Language', '3082', '3112'],
#  ['999001033', 'Causal_Oversimplification', '3161', '3201'],
#  ['999001033', 'Loaded_Language', '3206', '3231'],
#  ['999001033', 'Slogans', '3383', '3402'],
#  ['999001033', 'Doubt', '3560', '3594'],
#  ['999001033', 'Loaded_Language', '3705', '3724'],
#  ['730389374', 'Name_Calling,Labeling', '30', '46'],
#  ['730389374', 'Name_Calling,Labeling', '581', '595'],
#  ['730389374', 'Loaded_Language', '1695', '1710'],
#  ['730389374', 'Loaded_Language', '1788', '1821'],
#  ['730389374', 'Slogans', '1910', '1932'],
#  ['730389374', 'Loaded_Language', '2555', '2566'],
#  ['730389374', 'Loaded_Language', '3330', '3337'],
#  ['730389374', 'Thought-terminating_Cliches', '3545', '3561'],
#  ['730389374', 'Repetition', '3823', '3852'],
#  ['730389374', 'Causal_Oversimplification', '4084', '4198'],
#  ['730389374', 'Exaggeration,Minimisation', '4439', '4477'],
#  ['730389374', 'Loaded_Language', '4552', '4597'],
#  ['739091070', 'Loaded_Language', '73', '120'],
#  ['739091070', 'Exaggeration,Minimisation', '563', '583'],
#  ['739091070', 'Exaggeration,Minimisation', '1413', '1476'],
#  ['739091070', 'Causal_Oversimplification', '1496', '1543'],
#  ['739091070', 'Doubt', '1658', '1805'],
#  ['739091070', 'Exaggeration,Minimisation', '1975', '2013'],
#  ['766632016', 'Loaded_Language', '87', '96'],
#  ['766632016', 'Doubt', '114', '234'],
#  ['766632016', 'Appeal_to_Authority', '259', '349'],
#  ['766632016', 'Loaded_Language', '472', '515'],
#  ['766632016', 'Name_Calling,Labeling', '547', '603'],
#  ['766632016', 'Exaggeration,Minimisation', '608', '667'],
#  ['766632016', 'Black-and-White_Fallacy', '1369', '1385'],
#  ['766632016', 'Doubt', '1548', '1577'],
#  ['766632016', 'Loaded_Language', '2084', '2098'],
#  ['766632016', 'Name_Calling,Labeling', '2109', '2117'],
#  ['766632016', 'Name_Calling,Labeling', '2129', '2158'],
#  ['766632016', 'Loaded_Language', '2294', '2303'],
#  ['766632016', 'Exaggeration,Minimisation', '2454', '2480'],
#  ['766632016', 'Loaded_Language', '2516', '2553'],
#  ['766632016', 'Reductio_ad_hitlerum', '2590', '2697'],
#  ['766632016', 'Loaded_Language', '2713', '2731'],
#  ['766632016', 'Exaggeration,Minimisation', '3141', '3169'],
#  ['766632016', 'Loaded_Language', '3487', '3497'],
#  ['766632016', 'Doubt', '3545', '3670'],
#  ['766632016', 'Causal_Oversimplification', '3725', '3838'],
#  ['766632016', 'Doubt', '3858', '3948'],
#  ['766632016', 'Doubt', '4105', '4184'],
#  ['766632016', 'Loaded_Language', '4223', '4248'],
#  ['766632016', 'Loaded_Language', '4286', '4298'],
#  ['766632016', 'Appeal_to_fear-prejudice', '4416', '4455'],
#  ['766632016', 'Appeal_to_fear-prejudice', '4481', '4514'],
#  ['766632016', 'Whataboutism', '4525', '4584'],
#  ['766632016', 'Loaded_Language', '4598', '4653'],
#  ['766632016', 'Whataboutism', '4674', '4754'],
#  ['766632016', 'Exaggeration,Minimisation', '4772', '4823'],
#  ['766632016', 'Loaded_Language', '4845', '4871'],
#  ['766632016', 'Doubt', '5057', '5065'],
#  ['766632016', 'Doubt', '5091', '5167'],
#  ['766632016', 'Loaded_Language', '5183', '5201'],
#  ['766632016', 'Loaded_Language', '5280', '5306'],
#  ['766632016', 'Reductio_ad_hitlerum', '5342', '5402'],
#  ['766632016', 'Loaded_Language', '5414', '5456'],
#  ['766632016', 'Black-and-White_Fallacy', '5512', '5554'],
#  ['766632016', 'Whataboutism', '5614', '5674'],
#  ['766632016', 'Exaggeration,Minimisation', '5701', '5722'],
#  ['766632016', 'Doubt', '5739', '5845'],
#  ['766632016', 'Loaded_Language', '5883', '5906'],
#  ['766632016', 'Black-and-White_Fallacy', '5961', '6014'],
#  ['766632016', 'Name_Calling,Labeling', '6063', '6076'],
#  ['766632016', 'Loaded_Language', '6097', '6118'],
#  ['786731884', 'Repetition', '218', '237'],
#  ['786731884', 'Exaggeration,Minimisation', '318', '412'],
#  ['786731884', 'Doubt', '524', '585'],
#  ['786731884', 'Name_Calling,Labeling', '760', '805'],
#  ['786731884', 'Name_Calling,Labeling', '829', '868'],
#  ['786731884', 'Loaded_Language', '947', '953'],
#  ['786731884', 'Loaded_Language', '1144', '1158'],
#  ['786731884', 'Flag-Waving', '1459', '1493'],
#  ['786731884', 'Loaded_Language', '1559', '1600'],
#  ['786731884', 'Doubt', '1659', '1732'],
#  ['786731884', 'Appeal_to_fear-prejudice', '2049', '2107'],
#  ['786731884', 'Loaded_Language', '2258', '2272'],
#  ['786731884', 'Doubt', '2281', '2336'],
#  ['786731884', 'Name_Calling,Labeling', '2625', '2662'],
#  ['786731884', 'Doubt', '2747', '2856'],
#  ['786731884', 'Black-and-White_Fallacy', '3608', '3667'],
#  ['786731884', 'Loaded_Language', '4226', '4251'],
#  ['786731884', 'Exaggeration,Minimisation', '4267', '4370'],
#  ['786731884', 'Repetition', '4408', '4430'],
#  ['786731884', 'Loaded_Language', '4555', '4593'],
#  ['786731884', 'Loaded_Language', '4803', '4860'],
#  ['723537899', 'Black-and-White_Fallacy', '694', '719'],
#  ['723537899', 'Loaded_Language', '764', '790'],
#  ['723537899', 'Flag-Waving', '859', '871'],
#  ['723537899', 'Loaded_Language', '1262', '1281'],
#  ['723537899', 'Flag-Waving', '2063', '2084'],
#  ['723537899', 'Flag-Waving', '2143', '2167'],
#  ['723537899', 'Loaded_Language', '2190', '2195'],
#  ['723537899', 'Exaggeration,Minimisation', '2276', '2295'],
#  ['723537899', 'Loaded_Language', '2623', '2632'],
#  ['723537899', 'Loaded_Language', '3452', '3470'],
#  ['723537899', 'Exaggeration,Minimisation', '3516', '3559'],
#  ['723537899', 'Black-and-White_Fallacy', '3907', '3953'],
#  ['723537899', 'Loaded_Language', '4525', '4567'],
#  ['999000142', 'Doubt', '125', '228'],
#  ['999000142', 'Repetition', '239', '257'],
#  ['999000142', 'Loaded_Language', '475', '488'],
#  ['999000142', 'Causal_Oversimplification', '566', '661'],
#  ['999000142', 'Loaded_Language', '799', '807'],
#  ['999000142', 'Flag-Waving', '1565', '1731'],
#  ['999000142', 'Loaded_Language', '1916', '1935'],
#  ['999000142', 'Exaggeration,Minimisation', '1985', '2071'],
#  ['999000142', 'Doubt', '2165', '2184'],
#  ['999000142', 'Doubt', '2230', '2305'],
#  ['999000142', 'Doubt', '2346', '2363'],
#  ['999000142', 'Name_Calling,Labeling', '2613', '2637'],
#  ['999000142', 'Loaded_Language', '2679', '2703'],
#  ['999000142', 'Loaded_Language', '2708', '2716'],
#  ['999000142', 'Doubt', '2742', '2801'],
#  ['999000142', 'Loaded_Language', '2917', '2940'],
#  ['999000142', 'Name_Calling,Labeling', '2957', '2967'],
#  ['999000142', 'Doubt', '2981', '3034'],
#  ['999000142', 'Name_Calling,Labeling', '3060', '3102'],
#  ['999000142', 'Name_Calling,Labeling', '3280', '3302'],
#  ['736757214', 'Black-and-White_Fallacy', '285', '370'],
#  ['736757214', 'Exaggeration,Minimisation', '609', '633'],
#  ['7625464289', 'Name_Calling,Labeling', '134', '192'],
#  ['7625464289', 'Causal_Oversimplification', '274', '383'],
#  ['7625464289', 'Loaded_Language', '965', '990'],
#  ['7625464289', 'Name_Calling,Labeling', '1182', '1220'],
#  ['7625464289', 'Loaded_Language', '2105', '2179'],
#  ['7625464289', 'Exaggeration,Minimisation', '2677', '2701'],
#  ['7625464289', 'Doubt', '2715', '2875'],
#  ['7625464289', 'Exaggeration,Minimisation', '2890', '2952'],
#  ['7625464289', 'Loaded_Language', '3049', '3099'],
#  ['7625464289', 'Doubt', '3234', '3358'],
#  ['7625464289', 'Loaded_Language', '3393', '3433'],
#  ['999000155', 'Doubt', '485', '510'],
#  ['999000155', 'Name_Calling,Labeling', '1466', '1475'],
#  ['999000155', 'Loaded_Language', '1914', '1922'],
#  ['999000155', 'Black-and-White_Fallacy', '1966', '2025'],
#  ['999000155', 'Loaded_Language', '2126', '2140'],
#  ['999000155', 'Exaggeration,Minimisation', '2183', '2250'],
#  ['999000155', 'Loaded_Language', '2359', '2410'],
#  ['999000155', 'Loaded_Language', '2429', '2437'],
#  ['999000155', 'Exaggeration,Minimisation', '2465', '2621'],
#  ['999000154', 'Black-and-White_Fallacy', '118', '185'],
#  ['999000154', 'Name_Calling,Labeling', '250', '312'],
#  ['999000154', 'Doubt', '320', '359'],
#  ['999000154', 'Loaded_Language', '472', '516'],
#  ['999000154', 'Black-and-White_Fallacy', '633', '661'],
#  ['999000154', 'Name_Calling,Labeling', '1428', '1456'],
#  ['999000133', 'Doubt', '22', '109'],
#  ['999000133', 'Exaggeration,Minimisation', '137', '235'],
#  ['999000133', 'Loaded_Language', '436', '441'],
#  ['999000133', 'Exaggeration,Minimisation', '766', '816'],
#  ['999000133', 'Loaded_Language', '1801', '1831'],
#  ['740808926', 'Name_Calling,Labeling', '726', '745'],
#  ['740808926', 'Loaded_Language', '1581', '1609'],
#  ['729368012', 'Black-and-White_Fallacy', '3102', '3163'],
#  ['729368012', 'Name_Calling,Labeling', '3803', '3828'],
#  ['729368012', 'Loaded_Language', '4868', '4874'],
#  ['729368012', 'Thought-terminating_Cliches', '5011', '5021'],
#  ['729368012', 'Flag-Waving', '6914', '6969'],
#  ['729368012', 'Name_Calling,Labeling', '7645', '7664'],
#  ['729368012', 'Loaded_Language', '7971', '8021'],
#  ['729368012', 'Name_Calling,Labeling', '8680', '8687'],
#  ['729368012', 'Loaded_Language', '8888', '8911'],
#  ['729368012', 'Name_Calling,Labeling', '9722', '9743'],
#  ['729368012', 'Slogans', '10658', '10698'],
#  ['729368012', 'Exaggeration,Minimisation', '10734', '10774'],
#  ['729368012', 'Doubt', '11124', '11190'],
#  ['694356862', 'Loaded_Language', '86', '121'],
#  ['694356862', 'Name_Calling,Labeling', '600', '626'],
#  ['694356862', 'Whataboutism', '671', '760'],
#  ['694356862', 'Exaggeration,Minimisation', '901', '922'],
#  ['694356862', 'Name_Calling,Labeling', '930', '961'],
#  ['694356862', 'Doubt', '2750', '2786'],
#  ['694356862', 'Exaggeration,Minimisation', '2939', '2986'],
#  ['694356862', 'Loaded_Language', '3974', '3987'],
#  ['694356862', 'Exaggeration,Minimisation', '4301', '4354'],
#  ['694356862', 'Name_Calling,Labeling', '4827', '4841'],
#  ['694356862', 'Loaded_Language', '5061', '5140'],
#  ['694356862', 'Name_Calling,Labeling', '5190', '5206'],
#  ['765029945', 'Causal_Oversimplification', '119', '231'],
#  ['765029945', 'Black-and-White_Fallacy', '247', '324'],
#  ['765029945', 'Doubt', '366', '390'],
#  ['765029945', 'Name_Calling,Labeling', '619', '626'],
#  ['765029945', 'Loaded_Language', '915', '943'],
#  ['765029945', 'Doubt', '1326', '1369'],
#  ['765029945', 'Loaded_Language', '1439', '1448'],
#  ['765029945', 'Loaded_Language', '1519', '1532'],
#  ['765029945', 'Name_Calling,Labeling', '1587', '1608'],
#  ['999000136', 'Loaded_Language', '194', '216'],
#  ['999000136', 'Name_Calling,Labeling', '257', '319'],
#  ['999000136', 'Doubt', '1902', '2069'],
#  ['999000136', 'Loaded_Language', '2376', '2403'],
#  ['999000136', 'Loaded_Language', '2611', '2661'],
#  ['999000136', 'Exaggeration,Minimisation', '2793', '2839'],
#  ['999000136', 'Loaded_Language', '2869', '2879'],
#  ['999000136', 'Causal_Oversimplification', '2904', '3038'],
#  ['999000136', 'Appeal_to_fear-prejudice', '3120', '3167'],
#  ['999000136', 'Loaded_Language', '3478', '3488'],
#  ['999000136', 'Black-and-White_Fallacy', '3610', '3666'],
#  ['999000136', 'Loaded_Language', '3685', '3722'],
#  ['999000136', 'Loaded_Language', '3734', '3755'],
#  ['734265267', 'Name_Calling,Labeling', '1596', '1625'],
#  ['734265267', 'Loaded_Language', '3222', '3229'],
#  ['734265267', 'Exaggeration,Minimisation', '3285', '3317'],
#  ['734265267', 'Flag-Waving', '4154', '4213'],
#  ['767129999', 'Doubt', '261', '307'],
#  ['767129999', 'Exaggeration,Minimisation', '509', '528'],
#  ['767129999', 'Doubt', '1292', '1347'],
#  ['767129999', 'Flag-Waving', '1476', '1513'],
#  ['767129999', 'Loaded_Language', '1582', '1617'],
#  ['767129999', 'Exaggeration,Minimisation', '1696', '1724'],
#  ['767129999', 'Loaded_Language', '1934', '1962'],
#  ['767129999', 'Doubt', '2460', '2499'],
#  ['767129999', 'Exaggeration,Minimisation', '2514', '2572'],
#  ['767129999', 'Doubt', '2599', '2683'],
#  ['7615462239', 'Loaded_Language', '254', '293'],
#  ['7615462239', 'Loaded_Language', '441', '457'],
#  ['7615462239', 'Loaded_Language', '839', '852'],
#  ['7615462239', 'Causal_Oversimplification', '1637', '1714'],
#  ['7615462239', 'Loaded_Language', '1772', '1792'],
#  ['7615462239', 'Name_Calling,Labeling', '1897', '1948'],
#  ['7615462239', 'Exaggeration,Minimisation', '2038', '2153'],
#  ['7615462239', 'Exaggeration,Minimisation', '2273', '2293'],
#  ['7615462239', 'Name_Calling,Labeling', '2305', '2315'],
#  ['7615462239', 'Name_Calling,Labeling', '2371', '2410'],
#  ['7615462239', 'Repetition', '3111', '3169'],
#  ['7615462239', 'Exaggeration,Minimisation', '3364', '3404'],
#  ['7615462239', 'Repetition', '3479', '3508'],
#  ['7615462239', 'Black-and-White_Fallacy', '3568', '3634'],
#  ['7615462239', 'Name_Calling,Labeling', '4316', '4346'],
#  ['7615462239', 'Loaded_Language', '4535', '4563'],
#  ['999000184', 'Name_Calling,Labeling', '234', '255'],
#  ['999000184', 'Name_Calling,Labeling', '317', '342'],
#  ['999000184', 'Name_Calling,Labeling', '428', '475'],
#  ['999000184', 'Doubt', '948', '976'],
#  ['999000184', 'Black-and-White_Fallacy', '980', '1004'],
#  ['999000184', 'Causal_Oversimplification', '1133', '1202'],
#  ['999000184', 'Black-and-White_Fallacy', '1285', '1308'],
#  ['999000184', 'Appeal_to_fear-prejudice', '1709', '1770'],
#  ['999000184', 'Name_Calling,Labeling', '1860', '1886'],
#  ['999000184', 'Flag-Waving', '1911', '1954'],
#  ['999000184', 'Black-and-White_Fallacy', '1963', '2027'],
#  ['999000184', 'Reductio_ad_hitlerum', '2104', '2145'],
#  ['999000184', 'Exaggeration,Minimisation', '2174', '2231'],
#  ['999000184', 'Thought-terminating_Cliches', '2355', '2379'],
#  ['999000184', 'Black-and-White_Fallacy', '2468', '2531'],
#  ['999000184', 'Exaggeration,Minimisation', '2618', '2627'],
#  ['999000184', 'Appeal_to_fear-prejudice', '2730', '2773'],
#  ['999000184', 'Black-and-White_Fallacy', '2787', '2855'],
#  ['999000184', 'Exaggeration,Minimisation', '2892', '2908'],
#  ['999000184', 'Exaggeration,Minimisation', '3521', '3566'],
#  ['999000184', 'Appeal_to_fear-prejudice', '3701', '3734'],
#  ['999000184', 'Name_Calling,Labeling', '3873', '3934'],
#  ['764664283', 'Doubt', '0', '63'],
#  ['764664283', 'Loaded_Language', '254', '303'],
#  ['764664283', 'Appeal_to_fear-prejudice', '333', '383'],
#  ['764664283', 'Loaded_Language', '442', '476'],
#  ['764664283', 'Doubt', '613', '623'],
#  ['764664283', 'Loaded_Language', '678', '732'],
#  ['764664283', 'Thought-terminating_Cliches', '906', '933'],
#  ['764664283', 'Loaded_Language', '992', '1032'],
#  ['764664283', 'Name_Calling,Labeling', '1092', '1100'],
#  ['764664283', 'Black-and-White_Fallacy', '1110', '1148'],
#  ['764664283', 'Loaded_Language', '1152', '1205'],
#  ['764664283', 'Repetition', '1247', '1271'],
#  ['764664283', 'Loaded_Language', '1530', '1596'],
#  ['764664283', 'Loaded_Language', '1673', '1687'],
#  ['764664283', 'Name_Calling,Labeling', '1812', '1838'],
#  ['764664283', 'Name_Calling,Labeling', '1996', '2018'],
#  ['764664283', 'Name_Calling,Labeling', '2062', '2084'],
#  ['764664283', 'Causal_Oversimplification', '2165', '2287'],
#  ['764664283', 'Loaded_Language', '2409', '2519'],
#  ['764664283', 'Black-and-White_Fallacy', '2529', '2581'],
#  ['764664283', 'Appeal_to_fear-prejudice', '2615', '2664'],
#  ['764664283', 'Loaded_Language', '2705', '2725'],
#  ['764664283', 'Loaded_Language', '2811', '2820'],
#  ['764664283', 'Flag-Waving', '3057', '3072'],
#  ['764664283', 'Name_Calling,Labeling', '3098', '3124'],
#  ['764664283', 'Loaded_Language', '3162', '3217'],
#  ['764664283', 'Loaded_Language', '3223', '3229'],
#  ['764664283', 'Name_Calling,Labeling', '3479', '3525'],
#  ['764664283', 'Exaggeration,Minimisation', '3568', '3601'],
#  ['764664283', 'Doubt', '3640', '3667'],
#  ['764664283', 'Loaded_Language', '3739', '3771'],
#  ['764664283', 'Loaded_Language', '3910', '3946'],
#  ['764664283', 'Loaded_Language', '4005', '4021'],
#  ['764664283', 'Loaded_Language', '4110', '4180'],
#  ['764664283', 'Loaded_Language', '4206', '4224'],
#  ['764664283', 'Name_Calling,Labeling', '4299', '4323'],
#  ['764664283', 'Doubt', '5011', '5060'],
#  ['764664283', 'Loaded_Language', '5165', '5232'],
#  ['764664283', 'Loaded_Language', '5405', '5489'],
#  ['764664283', 'Appeal_to_fear-prejudice', '5526', '5563'],
#  ['764664283', 'Doubt', '5637', '5823'],
#  ['764664283', 'Name_Calling,Labeling', '5851', '5857'],
#  ['764664283', 'Loaded_Language', '5946', '5964'],
#  ['764664283', 'Loaded_Language', '6070', '6102'],
#  ['764664283', 'Causal_Oversimplification', '6142', '6178'],
#  ['764664283', 'Loaded_Language', '6460', '6479'],
#  ['764664283', 'Name_Calling,Labeling', '6853', '6884'],
#  ['764664283', 'Name_Calling,Labeling', '6960', '6981'],
#  ['764664283', 'Whataboutism', '7032', '7177'],
#  ['764664283', 'Whataboutism', '7580', '7687'],
#  ['764664283', 'Doubt', '7720', '7825'],
#  ['7786642809', 'Loaded_Language', '222', '230'],
#  ['7786642809', 'Loaded_Language', '393', '412'],
#  ['7786642809', 'Black-and-White_Fallacy', '881', '898'],
#  ['7786642809', 'Doubt', '1334', '1431'],
#  ['7786642809', 'Exaggeration,Minimisation', '1661', '1698'],
#  ['7786642809', 'Name_Calling,Labeling', '2071', '2076'],
#  ['7786642809', 'Loaded_Language', '2823', '2832'],
#  ['7786642809', 'Exaggeration,Minimisation', '3955', '4000'],
#  ['7786642809', 'Loaded_Language', '4438', '4450'],
#  ['7786642809', 'Loaded_Language', '4598', '4614'],
#  ['7786642809', 'Loaded_Language', '5127', '5136'],
#  ['7786642809', 'Doubt', '5465', '5504'],
#  ['7786642809', 'Loaded_Language', '5574', '5622'],
#  ['7786642809', 'Loaded_Language', '5680', '5709'],
#  ['7786642809', 'Loaded_Language', '6081', '6137'],
#  ['7786642809', 'Exaggeration,Minimisation', '6270', '6307'],
#  ['7786642809', 'Exaggeration,Minimisation', '6560', '6706'],
#  ['7786642809', 'Loaded_Language', '6998', '7014'],
#  ['7786642809', 'Causal_Oversimplification', '7041', '7097'],
#  ['7786642809', 'Black-and-White_Fallacy', '7416', '7546'],
#  ['7786642809', 'Doubt', '7658', '7715'],
#  ['7786642809', 'Repetition', '7843', '7883'],
#  ['7786642809', 'Loaded_Language', '8425', '8460'],
#  ['7786642809', 'Loaded_Language', '8733', '8762'],
#  ['7786642809', 'Whataboutism', '8855', '8991'],
#  ['7786642809', 'Exaggeration,Minimisation', '9083', '9127'],
#  ['7786642809', 'Exaggeration,Minimisation', '9193', '9203'],
#  ['7786642809', 'Causal_Oversimplification', '9524', '9617'],
#  ['7786642809', 'Loaded_Language', '9619', '9628'],
#  ['7786642809', 'Doubt', '9674', '9767'],
#  ['7786642809', 'Name_Calling,Labeling', '9810', '9822'],
#  ['7786642809', 'Loaded_Language', '9855', '9868'],
#  ['7786642809', 'Slogans', '9920', '9936'],
#  ['7786642809', 'Loaded_Language', '9955', '9966'],
#  ['7786642809', 'Exaggeration,Minimisation', '10058', '10089'],
#  ['7786642809', 'Doubt', '10154', '10213'],
#  ['7786642809', 'Doubt', '10309', '10381'],
#  ['7786642809', 'Name_Calling,Labeling', '10420', '10453'],
#  ['7786642809', 'Repetition', '10514', '10528'],
#  ['7786642809', 'Appeal_to_fear-prejudice', '10672', '10720'],
#  ['7786642809', 'Doubt', '10832', '10872'],
#  ['7786642809', 'Causal_Oversimplification', '10910', '10993'],
#  ['7786642809', 'Doubt', '11052', '11098'],
#  ['7786642809', 'Loaded_Language', '11246', '11258'],
#  ['7786642809', 'Name_Calling,Labeling', '11529', '11540'],
#  ['7786642809', 'Doubt', '11546', '11693'],
#  ['7786642809', 'Loaded_Language', '11796', '11830'],
#  ['7786642809', 'Loaded_Language', '11986', '11996'],
#  ['7786642809', 'Loaded_Language', '12280', '12293'],
#  ['766084411', 'Doubt', '140', '238'],
#  ['766084411', 'Name_Calling,Labeling', '379', '426'],
#  ['766084411', 'Loaded_Language', '1722', '1738'],
#  ['766084411', 'Causal_Oversimplification', '1987', '2041'],
#  ['766084411', 'Name_Calling,Labeling', '2813', '2843'],
#  ['766084411', 'Loaded_Language', '2922', '2927'],
#  ['766084411', 'Loaded_Language', '3082', '3136'],
#  ['766084411', 'Doubt', '3968', '4010'],
#  ['766084411', 'Doubt', '4259', '4315'],
#  ['766084411', 'Doubt', '4604', '4637'],
#  ['766084411', 'Loaded_Language', '4789', '4801'],
#  ['766084411', 'Exaggeration,Minimisation', '4943', '4965'],
#  ['721710340', 'Name_Calling,Labeling', '3236', '3265'],
#  ['721710340', 'Loaded_Language', '3508', '3527'],
#  ['721710340', 'Flag-Waving', '4267', '4326'],
#  ['7804147009', 'Loaded_Language', '72', '98'],
#  ['7804147009', 'Name_Calling,Labeling', '586', '622'],
#  ['7804147009', 'Loaded_Language', '716', '735'],
#  ['7804147009', 'Loaded_Language', '947', '961'],
#  ['7804147009', 'Loaded_Language', '1144', '1177'],
#  ['7804147009', 'Loaded_Language', '1201', '1228'],
#  ['7804147009', 'Name_Calling,Labeling', '1306', '1336'],
#  ['7804147009', 'Exaggeration,Minimisation', '1375', '1438'],
#  ['7804147009', 'Loaded_Language', '1711', '1727'],
#  ['7804147009', 'Doubt', '1754', '1871'],
#  ['7804147009', 'Doubt', '2159', '2262'],
#  ['7804147009', 'Loaded_Language', '2577', '2587'],
#  ['7804147009', 'Name_Calling,Labeling', '2809', '2826'],
#  ['7804147009', 'Thought-terminating_Cliches', '2929', '2948'],
#  ['7804147009', 'Causal_Oversimplification', '2964', '3009'],
#  ['7804147009', 'Loaded_Language', '3011', '3015'],
#  ['7804147009', 'Loaded_Language', '3022', '3043'],
#  ['7804147009', 'Exaggeration,Minimisation', '3534', '3573'],
#  ['7804147009', 'Doubt', '3591', '3646'],
#  ['7804147009', 'Exaggeration,Minimisation', '3747', '3775'],
#  ['7804147009', 'Reductio_ad_hitlerum', '3797', '3895'],
#  ['7804147009', 'Loaded_Language', '3936', '3971'],
#  ['7804147009', 'Name_Calling,Labeling', '4233', '4249'],
#  ['7804147009', 'Doubt', '4254', '4285'],
#  ['7804147009', 'Exaggeration,Minimisation', '4408', '4471'],
#  ['7804147009', 'Exaggeration,Minimisation', '4525', '4591'],
#  ['7804147009', 'Name_Calling,Labeling', '4656', '4662'],
#  ['7804147009', 'Loaded_Language', '4712', '4758'],
#  ['7804147009', 'Loaded_Language', '4795', '4823'],
#  ['7804147009', 'Exaggeration,Minimisation', '4951', '4992'],
#  ['7804147009', 'Repetition', '5063', '5085'],
#  ['7804147009', 'Exaggeration,Minimisation', '5229', '5265'],
#  ['7804147009', 'Whataboutism', '5460', '5567'],
#  ['7804147009', 'Name_Calling,Labeling', '5583', '5610'],
#  ['7804147009', 'Doubt', '5636', '5712'],
#  ['7804147009', 'Loaded_Language', '5762', '5774'],
#  ['7804147009', 'Exaggeration,Minimisation', '5783', '5801'],
#  ['7804147009', 'Thought-terminating_Cliches', '5897', '5928'],
#  ['7804147009', 'Loaded_Language', '6030', '6076'],
#  ['7804147009', 'Loaded_Language', '6454', '6474'],
#  ['7804147009', 'Loaded_Language', '6512', '6528'],
#  ['7804147009', 'Loaded_Language', '6587', '6601'],
#  ['7804147009', 'Loaded_Language', '6784', '6817'],
#  ['7804147009', 'Loaded_Language', '6845', '6868'],
#  ['7804147009', 'Loaded_Language', '6969', '6986'],
#  ['7804147009', 'Exaggeration,Minimisation', '7237', '7266'],
#  ['7804147009', 'Loaded_Language', '7467', '7495'],
#  ['7804147009', 'Loaded_Language', '7562', '7578'],
#  ['7804147009', 'Exaggeration,Minimisation', '7660', '7698'],
#  ['7804147009', 'Loaded_Language', '7854', '7898'],
#  ['7804147009', 'Thought-terminating_Cliches', '8099', '8116'],
#  ['7804147009', 'Loaded_Language', '8235', '8250'],
#  ['7804147009', 'Loaded_Language', '8863', '8926'],
#  ['7804147009', 'Loaded_Language', '8930', '8968'],
#  ['7804147009', 'Loaded_Language', '9273', '9294'],
#  ['7804147009', 'Loaded_Language', '9323', '9373'],
#  ['7804147009', 'Exaggeration,Minimisation', '9454', '9584'],
#  ['7804147009', 'Causal_Oversimplification', '9635', '9772'],
#  ['7804147009', 'Whataboutism', '9812', '9842'],
#  ['7804147009', 'Loaded_Language', '9869', '9932'],
#  ['7804147009', 'Loaded_Language', '9960', '9989'],
#  ['7804147009', 'Doubt', '10181', '10325'],
#  ['7804147009', 'Doubt', '10371', '10418'],
#  ['7804147009', 'Loaded_Language', '10543', '10556'],
#  ['7804147009', 'Loaded_Language', '10643', '10656'],
#  ['7804147009', 'Loaded_Language', '10700', '10708'],
#  ['7804147009', 'Loaded_Language', '10915', '10935'],
#  ['7804147009', 'Flag-Waving', '10988', '11019'],
#  ['7804147009', 'Name_Calling,Labeling', '11110', '11153'],
#  ['7804147009', 'Loaded_Language', '11226', '11242'],
#  ['7804147009', 'Slogans', '11617', '11624'],
#  ['7804147009', 'Black-and-White_Fallacy', '11628', '11684'],
#  ['7804147009', 'Loaded_Language', '12161', '12184'],
#  ['7804147009', 'Doubt', '12628', '12694'],
#  ['7804147009', 'Exaggeration,Minimisation', '12933', '12961'],
#  ['7804147009', 'Black-and-White_Fallacy', '13056', '13077'],
#  ['7804147009', 'Doubt', '13194', '13219'],
#  ['7804147009', 'Loaded_Language', '13500', '13544'],
#  ['7804147009', 'Name_Calling,Labeling', '13623', '13639'],
#  ['7804147009', 'Name_Calling,Labeling', '13953', '13993'],
#  ['7804147009', 'Loaded_Language', '14001', '14011'],
#  ['7804147009', 'Loaded_Language', '14089', '14132'],
#  ['7804147009', 'Doubt', '14372', '14388'],
#  ['7804147009', 'Black-and-White_Fallacy', '14830', '14871'],
#  ['7804147009', 'Loaded_Language', '15211', '15231'],
#  ['7804147009', 'Black-and-White_Fallacy', '16075', '16146'],
#  ['7804147009', 'Doubt', '16287', '16374'],
#  ['7804147009', 'Loaded_Language', '16640', '16689'],
#  ['7804147009', 'Exaggeration,Minimisation', '16857', '16920'],
#  ['7804147009', 'Loaded_Language', '17662', '17674'],
#  ['7804147009', 'Loaded_Language', '17788', '17816'],
#  ['7804147009', 'Thought-terminating_Cliches', '17989', '18011'],
#  ['7804147009', 'Exaggeration,Minimisation', '18058', '18076'],
#  ['7804147009', 'Loaded_Language', '18080', '18099'],
#  ['7804147009', 'Loaded_Language', '18186', '18218'],
#  ['7804147009', 'Loaded_Language', '18259', '18282'],
#  ['7804147009', 'Loaded_Language', '18353', '18362'],
#  ['7804147009', 'Loaded_Language', '18410', '18446'],
#  ['7804147009', 'Name_Calling,Labeling', '18473', '18536'],
#  ['7804147009', 'Thought-terminating_Cliches', '18633', '18655'],
#  ['7804147009', 'Thought-terminating_Cliches', '18701', '18722'],
#  ['700461600', 'Thought-terminating_Cliches', '123', '132'],
#  ['700461600', 'Thought-terminating_Cliches', '572', '582'],
#  ['700461600', 'Flag-Waving', '688', '755'],
#  ['700461600', 'Name_Calling,Labeling', '895', '967'],
#  ['700461600', 'Black-and-White_Fallacy', '1300', '1334'],
#  ['700461600', 'Loaded_Language', '1899', '1906'],
#  ['700461600', 'Exaggeration,Minimisation', '2109', '2146'],
#  ['700461600', 'Exaggeration,Minimisation', '2157', '2186'],
#  ['700461600', 'Loaded_Language', '2559', '2572'],
#  ['700461600', 'Flag-Waving', '2726', '2751'],
#  ['700461600', 'Loaded_Language', '2913', '2953'],
#  ['700461600', 'Slogans', '3115', '3163'],
#  ['700461600', 'Flag-Waving', '3652', '3659'],
#  ['700461600', 'Name_Calling,Labeling', '4244', '4254'],
#  ['700461600', 'Exaggeration,Minimisation', '4344', '4357'],
#  ['700461600', 'Repetition', '4365', '4382'],
#  ['999001032', 'Loaded_Language', '218', '261'],
#  ['999001032', 'Name_Calling,Labeling', '331', '346'],
#  ['999001032', 'Thought-terminating_Cliches', '363', '379'],
#  ['999001032', 'Black-and-White_Fallacy', '454', '504'],
#  ['999001032', 'Loaded_Language', '607', '646'],
#  ['999001032', 'Exaggeration,Minimisation', '786', '805'],
#  ['999001032', 'Loaded_Language', '1148', '1172'],
#  ['999001032', 'Loaded_Language', '1284', '1310'],
#  ['999001032', 'Exaggeration,Minimisation', '1532', '1558'],
#  ['999001032', 'Name_Calling,Labeling', '1574', '1589'],
#  ['999001032', 'Doubt', '1596', '1616'],
#  ['999001032', 'Doubt', '1986', '1996'],
#  ['999001032', 'Name_Calling,Labeling', '2746', '2754'],
#  ['999001032', 'Loaded_Language', '2941', '2947'],
#  ['999001032', 'Name_Calling,Labeling', '3026', '3035'],
#  ['999001032', 'Loaded_Language', '3280', '3315'],
#  ['999001032', 'Name_Calling,Labeling', '3451', '3486'],
#  ['999001032', 'Name_Calling,Labeling', '3541', '3546'],
#  ['999001032', 'Exaggeration,Minimisation', '3661', '3680'],
#  ['999001032', 'Doubt', '3880', '3915'],
#  ['999001032', 'Loaded_Language', '3978', '3989'],
#  ['999001032', 'Repetition', '4003', '4023'],
#  ['999001032', 'Repetition', '4052', '4062'],
#  ['999001032', 'Appeal_to_Authority', '4108', '4124'],
#  ['999001032', 'Appeal_to_fear-prejudice', '4147', '4154'],
#  ['999001032', 'Loaded_Language', '4157', '4179'],
#  ['999001032', 'Doubt', '4287', '4337'],
#  ['999001032', 'Repetition', '5234', '5247'],
#  ['999001032', 'Exaggeration,Minimisation', '5331', '5353'],
#  ['999001032', 'Causal_Oversimplification', '5381', '5495'],
#  ['999001032', 'Loaded_Language', '5499', '5520'],
#  ['999001032', 'Doubt', '5679', '5733'],
#  ['735815503', 'Name_Calling,Labeling', '359', '384'],
#  ['735815503', 'Loaded_Language', '869', '894'],
#  ['735815503', 'Appeal_to_fear-prejudice', '1357', '1412'],
#  ['780787440', 'Name_Calling,Labeling', '420', '441'],
#  ['780787440', 'Causal_Oversimplification', '493', '546'],
#  ['780787440', 'Loaded_Language', '1026', '1061'],
#  ['780787440', 'Causal_Oversimplification', '1199', '1308'],
#  ['780787440', 'Loaded_Language', '1354', '1378'],
#  ['780787440', 'Loaded_Language', '1452', '1460'],
#  ['780787440', 'Causal_Oversimplification', '1756', '1780'],
#  ['780787440', 'Repetition', '1786', '1798'],
#  ['780787440', 'Exaggeration,Minimisation', '1882', '1904'],
#  ['780787440', 'Loaded_Language', '2109', '2120'],
#  ['780787440', 'Thought-terminating_Cliches', '2316', '2326'],
#  ['780787440', 'Black-and-White_Fallacy', '2563', '2589'],
#  ['780787440', 'Loaded_Language', '2993', '3010'],
#  ['699291100', 'Name_Calling,Labeling', '647', '673'],
#  ['699291100', 'Repetition', '1674', '1691'],
#  ['699291100', 'Name_Calling,Labeling', '1945', '1956'],
#  ['699291100', 'Loaded_Language', '3354', '3389'],
#  ['699291100', 'Loaded_Language', '3997', '4016'],
#  ['699291100', 'Slogans', '4822', '4881'],
#  ['699291100', 'Loaded_Language', '4993', '5012'],
#  ['699291100', 'Name_Calling,Labeling', '6361', '6371']]

# %%
#filter individual models
result = [x for x in result if x not in ["Slogans", "Name_Calling,Labeling", "Loaded_Language"]]
