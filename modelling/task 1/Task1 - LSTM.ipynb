# %%
# %matplotlib inline

# Import libraries
import pandas as pd
import numpy as np
import os
import re
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

from keras.models import Sequential
from keras.layers import Embedding, LSTM, Bidirectional, GlobalMaxPool1D, Dense, Dropout

from sklearn.metrics import f1_score, confusion_matrix
# Out:
# Using TensorFlow backend.

# %%
# Set Path
path = os.path.abspath('..')

# %% [markdown]
# ## Read data

# %%
df = pd.read_csv(os.path.join(path, 'data', 'raw', 'task1.train.txt'), delimiter='\t', names=['article', 'id', 'label'])

# %%
df
# Out:
#                                                  article         id  \
# 0      Et tu, Rhody?  A recent editorial in the Provi...  727600136
# 1      A recent post in The Farmington Mirror — our t...  731714618
# 2      President Donald Trump, as he often does while...  731714635
# 3      February is Black History Month, and nothing l...  728627182
# 4      The snow was so heavy, whipped up by gusting w...  728627443
# 5      Four months after the Sandy Hook School shooti...  732126660
# 6      The first major newspaper article about Donald...  728144791
# 7      For three years, starting in 2008, New York ar...  728605281
# 8      President Donald Trump's tumultuous administra...  731383701
# 9      With Hartford on edge about the future of Aetn...  734075146
# 10     An employee at a Hibachi Express in Florida ha...  730014413
# 11     With the toll of the carnage from the country’...  731000618
# 12     The State Department's point-man on North Kore...  734267317
# 13     The Trump Organization announced Monday that i...  734268392
# 14     Aer Lingus’ service from Bradley International...  732544725
# 15     For its show “Constellations,” which ends its ...  732544983
# 16     The Corporation for Public Broadcasting (CPB) ...  733933352
# 17     All five members of New Britain’s state legisl...  729599944
# 18     The leader and second in command of a credit-c...  729092528
# 19     After eight years as the state’s relentless ch...  729092995
# 20     Aetna Inc. is being sued in yet another legal ...  729093525
# 21     Erin Stewart will be out of sight, but not out...  732605196
# 22     Dozens of Meriden residents and city officials...  732605617
# 23     Two classic American novels will no longer be ...  729829440
# 24     We asked our friends on Facebook and Twitter t...  728544641
# 25     MassMutual announced Thursday it is closing it...  729313115
# 26     Amid federal inaction on gun control, the Demo...  733130852
# 27     Linda Greenhouse, the award-winning New York T...  733131088
# 28     Stephen Colbert would like to change the votin...  732789288
# 29     In the wake of the shooting death of 15-year-o...  729194501
# ...                                                  ...        ...
# 35956  “The best way to teach your kids about taxes i...  694381164
# 35957  [This article is excerpted from volume 2, chap...  694381211
# 35958  I remember the moment I got the HPV vaccine. I...  694381405
# 35959  “These are, after all, the same entities who i...  694382687
# 35960  Madagascar isn’t getting this epidemic of the ...  701521336
# 35961  WikiLeaks founder Julian Assange has accused H...  698536805
# 35962  Every ideologically driven citizen has one law...  698537030
# 35963  On 31 August 1888 Mary Ann Nichols, the first ...  783694526
# 35964  By nature all men are equal in liberty but not...  783694592
# 35965  The following is the foreword that I have writ...  783694820
# 35966  https://www.lewrockwell.com/lrc-blog/american-...  783929870
# 35967  Joe Lauria, editor-in-chief of Consortium News...  784033478
# 35968  Just because he’s dead doesn’t mean John McCai...  784266021
# 35969  A recently posted commentary by Ben Shapiro on...  784266637
# 35970  Moscow has seen attempts to meddle in the Russ...  784555004
# 35971  Seven years after the beginning of the war aga...  784555056
# 35972  In April 2005, a Republican-led Department of ...  784555422
# 35973  Many of us in the South have maintained our fa...  784556485
# 35974  In an interview with Consortium News Editor-in...  784855236
# 35975  Shop all books by Judge Napolitano  Last week,...  784855886
# 35976  https://www.lewrockwell.com/lrc-blog/why-bob-w...  785266460
# 35977  Fellow Americans,  Please know: I am black; I ...  785149287
# 35978  The past is not dead; it is people who are sle...  785429194
# 35979  The New York Times continues to outdo itself i...  785429583
# 35980  “It’s very depressing. You want to read a depr...  785430430
# 35981  From The Telegraph:  Towns in Brazil have beco...  785781276
# 35982  The second episode of Consortium News on Flash...  785781322
# 35983  It is beginning.  Actually, it’s been happenin...  785781455
# 35984  Justin’s note: As regular Dispatch readers kno...  785781711
# 35985  “No man can serve two masters” (Matthew 6:24)....  786060460
#
#                 label
# 0      non-propaganda
# 1      non-propaganda
# 2      non-propaganda
# 3      non-propaganda
# 4      non-propaganda
# 5      non-propaganda
# 6      non-propaganda
# 7      non-propaganda
# 8      non-propaganda
# 9      non-propaganda
# 10     non-propaganda
# 11     non-propaganda
# 12     non-propaganda
# 13     non-propaganda
# 14     non-propaganda
# 15     non-propaganda
# 16     non-propaganda
# 17     non-propaganda
# 18     non-propaganda
# 19     non-propaganda
# 20     non-propaganda
# 21     non-propaganda
# 22     non-propaganda
# 23     non-propaganda
# 24     non-propaganda
# 25     non-propaganda
# 26     non-propaganda
# 27     non-propaganda
# 28     non-propaganda
# 29     non-propaganda
# ...               ...
# 35956      propaganda
# 35957      propaganda
# 35958      propaganda
# 35959      propaganda
# 35960      propaganda
# 35961      propaganda
# 35962      propaganda
# 35963      propaganda
# 35964      propaganda
# 35965      propaganda
# 35966      propaganda
# 35967      propaganda
# 35968      propaganda
# 35969      propaganda
# 35970      propaganda
# 35971      propaganda
# 35972      propaganda
# 35973      propaganda
# 35974      propaganda
# 35975      propaganda
# 35976      propaganda
# 35977      propaganda
# 35978      propaganda
# 35979      propaganda
# 35980      propaganda
# 35981      propaganda
# 35982      propaganda
# 35983      propaganda
# 35984      propaganda
# 35985      propaganda
#
# [35986 rows x 3 columns]

# %%
df.shape
# Out:
# (35986, 3)

# %%
df['article'][0]
# Out:
# 'Et tu, Rhody?  A recent editorial in the Providence Journal cataloged everything it could find wrong with Connecticut and ended with this suggestion: “Gov. Gina Raimondo should see if at least some of those jobs could come to Rhode Island. It is certainly less risky than the Nutmeg State.”  We beg your pardon.  The state with world-famous pension problems and persistent economic issues of its own is “less risky”?  The Journal itself reported just a few weeks ago on Rhode Island’s own significant economic problems, which in many ways reflect Connecticut’s.  Rhode Island enjoys a legacy of corruption that not even Connecticut can match. The ProJo won a Pulitzer Prize in 1994 for uncovering widespread corruption within its own court system.  What, exactly, is to be gained from moving to Rhode Island?  Like Connecticut, Rhode Island has an income tax and an estate tax with comparable rates. (Forbes magazine listed it as one of the states “Where Not To Die.” Connecticut made the list, too.)  Connecticut and Rhode Island’s interdependence has been limited, with the exception of the interstate economy created by Electric Boat in Groton. There have been no border wars and very little bloodshed. A few jokes about Rhode Island’s size, maybe, but if we’re being honest, Connecticut doesn’t really have a lot going on in that department either.  A little interstate competition is fine, but if Connecticut suffers, so does Rhode Island — and all of New England, for that matter.  Connecticut is losing residents at a troubling rate, but Rhode Island has an outmigration problem of its own. From 2015 to 2016, the Ocean State experienced a net loss of about 2,000 tax filers, who took with them more than $182 million in adjusted gross income. The top destination states for people who fled Rhode Island were Massachusetts, Florida and — wait for it — Connecticut.  Connecticut residents moved to Rhode Island as well, of course. But Connecticut’s population is 3½ times as big as Rhode Island’s. So the 1,175 tax filers who left Rhode Island for Connecticut represent a far larger portion of the Ocean State than the 1,220 who moved from Connecticut to Rhode Island. If any state should be concerned about losing residents to its neighbor, it’s Rhode Island.  But we don’t want to poach Rhode Islanders. We’d rather celebrate Electric Boat’s growth and the burgeoning workforce that supports both states. We’d rather cheer CVS for buying Aetna and keeping it in Hartford than try to woo CVS from Woonsocket.  A booming Connecticut, especially in the insurance and defense industries, only helps Rhode Island.  As Electric Boat — headquartered in Connecticut, might we emphasize — grows over the next decade, the effect on Little Rhody will be profound, as the ProJo’s editorial board pointed out. A thriving border economy helps both states as supplier chains develop and as feeder businesses bloom.  But for the same reasons that the stain of a Hartford bankruptcy would spread to the suburbs, if Connecticut becomes an economic wasteland, the effects would be felt across New England.  If Rhode Island and Connecticut want to find a way out of the muck, far better for them to work together.  Yes, Connecticut can learn from Rhode Island. Connecticut’s pension problems are similar to those that threatened to swamp Rhode Island, but there are key differences, especially in that Connecticut’s pensions are contractual, where in Rhode Island, they were set by state statute.  Rhode Island made some tough choices and anticipated a legal battle to solve its problems. Connecticut leaders might have to find the stomach for the same type of strategy.  Connecticut and Rhode Island have a lot in common, including language. We both drive around the rotary to get a grinder at Cumbie’s, for example. And we are glad that Rhode Island has made progress on its pension issues.  But that’s no reason to try to poach a few residents. A regional approach would be much wiser.'

# %%
df['label'].value_counts()
# Out:
# non-propaganda    31965
# propaganda         4021
# Name: label, dtype: int64

# %% [markdown]
# ## Process data

# %% [markdown]
# ### Recode the label

# %%
df['target'] = df['label'].map({'propaganda': 1, 'non-propaganda': 0})

# %% [markdown]
# ### Clean the text

# %%
lemmatizer = WordNetLemmatizer()
stop_words = stopwords.words("english")

# %%
cvec = CountVectorizer()
tokenizer = cvec.build_tokenizer()

# %%
def clean_text(text):
    
    # Remove special chars and punctuation
    text = " ".join(tokenizer(text))
    
    # lowcase
    text = text.lower()
    
    # Lematize
    text = [lemmatizer.lemmatize(token) for token in text.split(" ")]
    
    # Lematize
    text = [lemmatizer.lemmatize(token, "v") for token in text]
    
    # Remove stopwords
    text = [word for word in text if not word in stop_words]
    
    text = " ".join(text)
    
    return text

# %%
df['article_prep'] = df['article'].apply(clean_text)

# %%
df
# Out:
#                                                  article         id  \
# 0      Et tu, Rhody?  A recent editorial in the Provi...  727600136
# 1      A recent post in The Farmington Mirror — our t...  731714618
# 2      President Donald Trump, as he often does while...  731714635
# 3      February is Black History Month, and nothing l...  728627182
# 4      The snow was so heavy, whipped up by gusting w...  728627443
# 5      Four months after the Sandy Hook School shooti...  732126660
# 6      The first major newspaper article about Donald...  728144791
# 7      For three years, starting in 2008, New York ar...  728605281
# 8      President Donald Trump's tumultuous administra...  731383701
# 9      With Hartford on edge about the future of Aetn...  734075146
# 10     An employee at a Hibachi Express in Florida ha...  730014413
# 11     With the toll of the carnage from the country’...  731000618
# 12     The State Department's point-man on North Kore...  734267317
# 13     The Trump Organization announced Monday that i...  734268392
# 14     Aer Lingus’ service from Bradley International...  732544725
# 15     For its show “Constellations,” which ends its ...  732544983
# 16     The Corporation for Public Broadcasting (CPB) ...  733933352
# 17     All five members of New Britain’s state legisl...  729599944
# 18     The leader and second in command of a credit-c...  729092528
# 19     After eight years as the state’s relentless ch...  729092995
# 20     Aetna Inc. is being sued in yet another legal ...  729093525
# 21     Erin Stewart will be out of sight, but not out...  732605196
# 22     Dozens of Meriden residents and city officials...  732605617
# 23     Two classic American novels will no longer be ...  729829440
# 24     We asked our friends on Facebook and Twitter t...  728544641
# 25     MassMutual announced Thursday it is closing it...  729313115
# 26     Amid federal inaction on gun control, the Demo...  733130852
# 27     Linda Greenhouse, the award-winning New York T...  733131088
# 28     Stephen Colbert would like to change the votin...  732789288
# 29     In the wake of the shooting death of 15-year-o...  729194501
# ...                                                  ...        ...
# 35956  “The best way to teach your kids about taxes i...  694381164
# 35957  [This article is excerpted from volume 2, chap...  694381211
# 35958  I remember the moment I got the HPV vaccine. I...  694381405
# 35959  “These are, after all, the same entities who i...  694382687
# 35960  Madagascar isn’t getting this epidemic of the ...  701521336
# 35961  WikiLeaks founder Julian Assange has accused H...  698536805
# 35962  Every ideologically driven citizen has one law...  698537030
# 35963  On 31 August 1888 Mary Ann Nichols, the first ...  783694526
# 35964  By nature all men are equal in liberty but not...  783694592
# 35965  The following is the foreword that I have writ...  783694820
# 35966  https://www.lewrockwell.com/lrc-blog/american-...  783929870
# 35967  Joe Lauria, editor-in-chief of Consortium News...  784033478
# 35968  Just because he’s dead doesn’t mean John McCai...  784266021
# 35969  A recently posted commentary by Ben Shapiro on...  784266637
# 35970  Moscow has seen attempts to meddle in the Russ...  784555004
# 35971  Seven years after the beginning of the war aga...  784555056
# 35972  In April 2005, a Republican-led Department of ...  784555422
# 35973  Many of us in the South have maintained our fa...  784556485
# 35974  In an interview with Consortium News Editor-in...  784855236
# 35975  Shop all books by Judge Napolitano  Last week,...  784855886
# 35976  https://www.lewrockwell.com/lrc-blog/why-bob-w...  785266460
# 35977  Fellow Americans,  Please know: I am black; I ...  785149287
# 35978  The past is not dead; it is people who are sle...  785429194
# 35979  The New York Times continues to outdo itself i...  785429583
# 35980  “It’s very depressing. You want to read a depr...  785430430
# 35981  From The Telegraph:  Towns in Brazil have beco...  785781276
# 35982  The second episode of Consortium News on Flash...  785781322
# 35983  It is beginning.  Actually, it’s been happenin...  785781455
# 35984  Justin’s note: As regular Dispatch readers kno...  785781711
# 35985  “No man can serve two masters” (Matthew 6:24)....  786060460
#
#                 label  target  \
# 0      non-propaganda       0
# 1      non-propaganda       0
# 2      non-propaganda       0
# 3      non-propaganda       0
# 4      non-propaganda       0
# 5      non-propaganda       0
# 6      non-propaganda       0
# 7      non-propaganda       0
# 8      non-propaganda       0
# 9      non-propaganda       0
# 10     non-propaganda       0
# 11     non-propaganda       0
# 12     non-propaganda       0
# 13     non-propaganda       0
# 14     non-propaganda       0
# 15     non-propaganda       0
# 16     non-propaganda       0
# 17     non-propaganda       0
# 18     non-propaganda       0
# 19     non-propaganda       0
# 20     non-propaganda       0
# 21     non-propaganda       0
# 22     non-propaganda       0
# 23     non-propaganda       0
# 24     non-propaganda       0
# 25     non-propaganda       0
# 26     non-propaganda       0
# 27     non-propaganda       0
# 28     non-propaganda       0
# 29     non-propaganda       0
# ...               ...     ...
# 35956      propaganda       1
# 35957      propaganda       1
# 35958      propaganda       1
# 35959      propaganda       1
# 35960      propaganda       1
# 35961      propaganda       1
# 35962      propaganda       1
# 35963      propaganda       1
# 35964      propaganda       1
# 35965      propaganda       1
# 35966      propaganda       1
# 35967      propaganda       1
# 35968      propaganda       1
# 35969      propaganda       1
# 35970      propaganda       1
# 35971      propaganda       1
# 35972      propaganda       1
# 35973      propaganda       1
# 35974      propaganda       1
# 35975      propaganda       1
# 35976      propaganda       1
# 35977      propaganda       1
# 35978      propaganda       1
# 35979      propaganda       1
# 35980      propaganda       1
# 35981      propaganda       1
# 35982      propaganda       1
# 35983      propaganda       1
# 35984      propaganda       1
# 35985      propaganda       1
#
#                                             article_prep
# 0      et tu rhody recent editorial providence journa...
# 1      recent post farmington mirror town version oni...
# 2      president donald trump often doe respond natur...
# 3      february black history month nothing loom larg...
# 4      snow wa heavy whip gusting wind travel wa near...
# 5      four month sandy hook school shoot connecticut...
# 6      first major newspaper article donald trump 197...
# 7      three year start 2008 new york art dealer robe...
# 8      president donald trump tumultuous administrati...
# 9      hartford edge future aetna cv health corp chie...
# 10     employee hibachi express florida ha sentence s...
# 11     toll carnage country latest school shoot still...
# 12     state department point man north korea joseph ...
# 13     trump organization announce monday donate prof...
# 14     aer lingus service bradley international airpo...
# 15     show constellation end run feb 22 theaterworks...
# 16     corporation public broadcast cpb announce gran...
# 17     five member new britain state legislative dele...
# 18     leader second command credit card fraud scheme...
# 19     eight year state relentless champion better ed...
# 20     aetna inc sue yet another legal action disclos...
# 21     erin stewart sight mind thank twitter republic...
# 22     dozen meriden resident city official rally aro...
# 23     two classic american novel longer require read...
# 24     ask friend facebook twitter fill blank state s...
# 25     massmutual announce thursday close office enfi...
# 26     amid federal inaction gun control democratic g...
# 27     linda greenhouse award win new york time repor...
# 28     stephen colbert would like change vote age som...
# 29     wake shoot death 15 year old ethan song guilfo...
# ...                                                  ...
# 35956  best way teach kid tax eat 30 ice cream bill m...
# 35957  article excerpt volume chapter 11 austrian per...
# 35958  remember moment get hpv vaccine wa young impre...
# 35959  entity insist north korean would able launch v...
# 35960  madagascar get epidemic pneumonic plague contr...
# 35961  wikileaks founder julian assange ha accuse hil...
# 35962  every ideologically drive citizen ha one law w...
# 35963  31 august 1888 mary ann nichols first victim j...
# 35964  nature men equal liberty endowment thomas aqui...
# 35965  follow foreword write outstanding new piece li...
# 35966  http www lewrockwell com lrc blog american non...
# 35967  joe lauria editor chief consortium news saturd...
# 35968  dead mean john mccain kill people hat since mc...
# 35969  recently post commentary ben shapiro national ...
# 35970  moscow ha see attempt meddle russian election ...
# 35971  seven year begin war syria fight proxy jihadis...
# 35972  april 2005 republican lead department justice ...
# 35973  many u south maintain faith constitutional rig...
# 35974  interview consortium news editor chief joe lau...
# 35975  shop book judge napolitano last week wa intrig...
# 35976  http www lewrockwell com lrc blog bob woodward...
# 35977  fellow american please know black grow segrega...
# 35978  past dead people sleep current night daymares ...
# 35979  new york time continue outdo production fake n...
# 35980  depress want read depress book say one critic ...
# 35981  telegraph town brazil become refugee camp tide...
# 35982  second episode consortium news flash point foc...
# 35983  begin actually happen long time like slowly me...
# 35984  justin note regular dispatch reader know every...
# 35985  man serve two master matthew 24 fine print bot...
#
# [35986 rows x 5 columns]

# %% [markdown]
# ## Make the splits

# %%
# The whole sample is split on 3 parts - dev, val, test
df_dev, df_val = train_test_split(df, test_size = 0.25, random_state = 42, stratify=df['target'])

# %%
df_dev['sample'] = 'dev'
df_val['sample'] = 'val'
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Sample sizes
print(df_dev.shape)
print(df_val.shape)
# Out:
# (26989, 6)
# (8997, 6)

# %%
df.head()
# Out:
#                                              article         id  \
# 0  Et tu, Rhody?  A recent editorial in the Provi...  727600136
# 1  A recent post in The Farmington Mirror — our t...  731714618
# 2  President Donald Trump, as he often does while...  731714635
# 3  February is Black History Month, and nothing l...  728627182
# 4  The snow was so heavy, whipped up by gusting w...  728627443
#
#             label  target                                       article_prep
# 0  non-propaganda       0  et tu rhody recent editorial providence journa...
# 1  non-propaganda       0  recent post farmington mirror town version oni...
# 2  non-propaganda       0  president donald trump often doe respond natur...
# 3  non-propaganda       0  february black history month nothing loom larg...
# 4  non-propaganda       0  snow wa heavy whip gusting wind travel wa near...

# %%
# Check the lengths
df_dev['article_prep'].apply(lambda x: len(x.split(" "))).mean()
# Out:
# 347.5890177479714

# %%
df_dev['article_prep'].apply(lambda x: len(x.split(" "))).describe()
# Out:
# count    26989.000000
# mean       347.589018
# std        291.868117
# min          4.000000
# 25%        171.000000
# 50%        281.000000
# 75%        449.000000
# max      12122.000000
# Name: article_prep, dtype: float64

# %% [markdown]
# ## Prepare for modelling

# %%
features = 'article_prep'

# %%
# Dev

# Prepare the X
df_dev_x = df_dev[features]

# Prepare the y
df_dev_y = df_dev['target'].ravel()

# %%
# Val

# Prepare the X
df_val_x = df_val[features]

# Prepare the y
df_val_y = df_val['target'].ravel()

# %% [markdown]
# ### Tokenization

# %%
max_features = 6000
tokenizer = Tokenizer(num_words = max_features)

# %%
tokenizer.fit_on_texts(df_dev_x)

# %%
df_dev_x_tokens = tokenizer.texts_to_sequences(df_dev_x)
df_val_x_tokens = tokenizer.texts_to_sequences(df_val_x)

# %% [markdown]
# ### Padding

# %%
max_sequence_length = 348

# %%
df_dev_x_pad = pad_sequences(df_dev_x_tokens, maxlen=max_sequence_length)
df_val_x_pad = pad_sequences(df_val_x_tokens, maxlen=max_sequence_length)

# %% [markdown]
# ## Modelling

# %%
embed_size = 200

# %%
model = Sequential()
model.add(Embedding(max_features, embed_size))
model.add(Bidirectional(LSTM(32, return_sequences=True)))
model.add(GlobalMaxPool1D())
model.add(Dense(20, activation="relu"))
model.add(Dropout(0.1))
model.add(Dense(1, activation="sigmoid"))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 200)         1200000
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, None, 64)          59648
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                1300
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 1,260,969
# Trainable params: 1,260,969
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(df_dev_x_pad, df_dev_y, batch_size=128, epochs=2)
# Out:
# Epoch 1/2
# 26989/26989 [==============================] - 435s 16ms/step - loss: 0.2535 - acc: 0.9165
# Epoch 2/2
# 26989/26989 [==============================] - 446s 17ms/step - loss: 0.0986 - acc: 0.9661

# %% [markdown]
# ### Check the performance

# %%
# dev
df_dev_y_pred = model.predict(df_dev_x_pad, verbose=1).round()
# Out:
# 26989/26989 [==============================] - 367s 14ms/step

# %%
print('F1-score: {0}'.format(f1_score(df_dev_y_pred, df_dev_y)))
confusion_matrix(df_dev_y_pred, df_dev_y)
# Out:
# F1-score: 0.933853459972863
# array([[23846,   263],
#        [  127,  2753]], dtype=int64)

# %%
# val
df_val_y_pred = model.predict(df_val_x_pad, verbose=1).round()
# Out:
# 8997/8997 [==============================] - 124s 14ms/step

# %%
print('F1-score: {0}'.format(f1_score(df_val_y_pred, df_val_y)))
confusion_matrix(df_val_y_pred, df_val_y)
# Out:
# F1-score: 0.8184679958027282
# array([[7871,  225],
#        [ 121,  780]], dtype=int64)
