# %%
# %matplotlib inline

# Import libraries
import pandas as pd
import numpy as np
import os
import re
import glob
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

from keras.models import Sequential
from keras.layers import Embedding, LSTM, Bidirectional, GlobalMaxPool1D, Dense, Dropout

from sklearn.metrics import f1_score, confusion_matrix

import glob
# Out:
# Using TensorFlow backend.

# %%
# Set Path
path = os.path.abspath('..')

# %% [markdown]
# ## Read data

# %%
def dataprep_task2(path):
    """Dataprep for Task2 It will return the new data
    :param path: Path to the article's taks3 labels file.
    Example:
    >>> dataprep_task2("datasets-v5/tasks-2-3/train/article111111112.task2.labels")
    """
    dir_name = os.path.dirname(path)
    article_id = os.path.basename(path).split('.')[0]
    article_name = os.path.join(dir_name, f'{article_id}.txt')

    with open(article_name, 'r', encoding='utf8') as f:
        records = f.readlines()

    df = pd.DataFrame(records, columns=['sentences'])

    another_df = pd.read_csv(path, sep='\t', names = ['article', 'N_sentence', 'is_propaganda'], encoding='utf8')
    
    result_df = pd.concat([df, another_df], axis=1)
    
    return result_df.loc[result_df['sentences'] != '\n', :]

# %%
fileNames = glob.glob(os.path.join(path, 'data', 'raw', 'tasks-2-3', 'train') + "/*.task2.labels")

# %%
res_list = list()

for f in fileNames:
    res_list.append(dataprep_task2(f))

# %%
df = pd.concat(res_list)

# %%
df.iloc[2]['sentences']
# Out:
# 'Pamela Geller and Robert Spencer co-founded anti-Muslim group Stop Islamization of America.\n'

# %%
df['sentences'] = df['sentences'].str.replace('\n', '')

# %%
df.shape
# Out:
# (14263, 4)

# %%
df
# Out:
#                                              sentences    article  N_sentence  \
# 0                  US bloggers banned from entering UK  111111112           1
# 2    Two prominent US bloggers have been banned fro...  111111112           3
# 4    Pamela Geller and Robert Spencer co-founded an...  111111112           5
# 6    They were due to speak at an English Defence L...  111111112           7
# 8    A government spokesman said individuals whose ...  111111112           9
# 10   He added: "We condemn all those whose behaviou...  111111112          11
# 12                                    'Right decision'  111111112          13
# 13   Ms Geller, of the Atlas Shrugs blog, and Mr Sp...  111111112          14
# 14   On both of their blogs the pair called their b...  111111112          15
# 16   They were due to attend a march planned by the...  111111112          17
# 18   Keith Vaz, chairman of the Home Affairs Select...  111111112          19
# 19                         This is the right decision.  111111112          20
# 20   The UK should never become a stage for inflamm...  111111112          21
# 22   EDL leader Tommy Robinson, meanwhile, criticis...  111111112          23
# 24   "It's embarrassing for this so-called land of ...  111111112          25
# 26   "How many hate preachers are living in this co...  111111112          27
# 27   It just shows what sort of a two-tier system w...  111111112          28
# 29                                     'Foster hatred'  111111112          30
# 30   Anti-fascism campaigners Hope Not Hate had cam...  111111112          31
# 32   A researcher with the organisation, Matthew Co...  111111112          33
# 34   "These two are among some of the most extreme ...  111111112          35
# 35   They've nothing to contribute to life in this ...  111111112          36
# 37   "They're not here to contribute to good commun...  111111112          38
# 38   They only wanted to come here and help the EDL...  111111112          39
# 39   Britain doesn't need more hate even just for a...  111111112          40
# 41   Mr Spencer put up a copy of what appears to be...  111111112          42
# 43   The letters, both dated Tuesday, claim that bo...  111111112          44
# 45   Both letters gave examples of anti-Muslim view...  111111112          46
# 0    Kate Steinle's death at the hands of a Mexican...  111111113           1
# 2    The surprise acquittal of Jose Ines Garcia Zar...  111111113           3
# ..                                                 ...        ...         ...
# 103  The Guardian did not make a mistake in vilifyi...  999001621         104
# 104                  It did what it is designed to do.  999001621         105
# 105  We have previously shown that the Guardian eve...  999001621         106
# 106  It is openly publishing Goebbels' cartoons and...  999001621         107
# 107  There is no longer any line that it does not d...  999001621         108
# 108  Unfortunately other 'western' media are not mu...  999001621         109
# 109  Within hours of being published the Guardian p...  999001621         110
# 110  That did not hinder other outlets to add to it...  999001621         111
# 111  Politico allowed "a former CIA officer," writi...  999001621         112
# 112  Rather than being the bombshell smoking gun th...  999001621         113
# 113  Is it possible someone planted this story as a...  999001621         114
# 114                                                ...  999001621         115
# 115  Harding is likely a major target for anyone wr...  999001621         116
# 116                                                ...  999001621         117
# 117  If this latest story about Manafort and Assang...  999001621         118
# 118  The is zero evidence in the Politico screed th...  999001621         119
# 119           It is fake news about a fake news story.  999001621         120
# 120  It also included the false claim that Glenn Gr...  999001621         121
# 121                      That claim was later removed.  999001621         122
# 122  We have seen a similar pattern in the Skripal ...  999001621         123
# 123  When 'western' intelligence get caught in spre...  999001621         124
# 124  Unfortunately no western main stream media can...  999001621         125
# 125  The Guardian is only one of many which peddle ...  999001621         126
# 126  It is on all of us to debunk them and to educa...  999001621         127
# 127                                                ---  999001621         128
# 128         This is a Moon of Alabama fundraiser week.  999001621         129
# 129          No one pays me to write these blog posts.  999001621         130
# 130  If you appreciated this one, or any of the 7,0...  999001621         131
# 131  Posted by b on November 29, 2018 at 10:23 AM |...  999001621         132
# 132                                           Comments  999001621         133
#
#       is_propaganda
# 0    non-propaganda
# 2    non-propaganda
# 4        propaganda
# 6    non-propaganda
# 8    non-propaganda
# 10       propaganda
# 12   non-propaganda
# 13       propaganda
# 14       propaganda
# 16   non-propaganda
# 18   non-propaganda
# 19   non-propaganda
# 20       propaganda
# 22   non-propaganda
# 24       propaganda
# 26       propaganda
# 27   non-propaganda
# 29   non-propaganda
# 30   non-propaganda
# 32       propaganda
# 34   non-propaganda
# 35   non-propaganda
# 37   non-propaganda
# 38   non-propaganda
# 39   non-propaganda
# 41   non-propaganda
# 43   non-propaganda
# 45   non-propaganda
# 0    non-propaganda
# 2        propaganda
# ..              ...
# 103      propaganda
# 104      propaganda
# 105      propaganda
# 106      propaganda
# 107      propaganda
# 108      propaganda
# 109  non-propaganda
# 110      propaganda
# 111      propaganda
# 112      propaganda
# 113      propaganda
# 114  non-propaganda
# 115  non-propaganda
# 116  non-propaganda
# 117  non-propaganda
# 118      propaganda
# 119      propaganda
# 120  non-propaganda
# 121  non-propaganda
# 122  non-propaganda
# 123  non-propaganda
# 124      propaganda
# 125      propaganda
# 126      propaganda
# 127  non-propaganda
# 128  non-propaganda
# 129  non-propaganda
# 130  non-propaganda
# 131  non-propaganda
# 132  non-propaganda
#
# [14263 rows x 4 columns]

# %% [markdown]
# ## Process data

# %% [markdown]
# ### Recode the label

# %%
df['target'] = df['is_propaganda'].map({'propaganda': 1, 'non-propaganda': 0})

# %%
df
# Out:
#                                              sentences    article  N_sentence  \
# 0                  US bloggers banned from entering UK  111111112           1
# 2    Two prominent US bloggers have been banned fro...  111111112           3
# 4    Pamela Geller and Robert Spencer co-founded an...  111111112           5
# 6    They were due to speak at an English Defence L...  111111112           7
# 8    A government spokesman said individuals whose ...  111111112           9
# 10   He added: "We condemn all those whose behaviou...  111111112          11
# 12                                    'Right decision'  111111112          13
# 13   Ms Geller, of the Atlas Shrugs blog, and Mr Sp...  111111112          14
# 14   On both of their blogs the pair called their b...  111111112          15
# 16   They were due to attend a march planned by the...  111111112          17
# 18   Keith Vaz, chairman of the Home Affairs Select...  111111112          19
# 19                         This is the right decision.  111111112          20
# 20   The UK should never become a stage for inflamm...  111111112          21
# 22   EDL leader Tommy Robinson, meanwhile, criticis...  111111112          23
# 24   "It's embarrassing for this so-called land of ...  111111112          25
# 26   "How many hate preachers are living in this co...  111111112          27
# 27   It just shows what sort of a two-tier system w...  111111112          28
# 29                                     'Foster hatred'  111111112          30
# 30   Anti-fascism campaigners Hope Not Hate had cam...  111111112          31
# 32   A researcher with the organisation, Matthew Co...  111111112          33
# 34   "These two are among some of the most extreme ...  111111112          35
# 35   They've nothing to contribute to life in this ...  111111112          36
# 37   "They're not here to contribute to good commun...  111111112          38
# 38   They only wanted to come here and help the EDL...  111111112          39
# 39   Britain doesn't need more hate even just for a...  111111112          40
# 41   Mr Spencer put up a copy of what appears to be...  111111112          42
# 43   The letters, both dated Tuesday, claim that bo...  111111112          44
# 45   Both letters gave examples of anti-Muslim view...  111111112          46
# 0    Kate Steinle's death at the hands of a Mexican...  111111113           1
# 2    The surprise acquittal of Jose Ines Garcia Zar...  111111113           3
# ..                                                 ...        ...         ...
# 103  The Guardian did not make a mistake in vilifyi...  999001621         104
# 104                  It did what it is designed to do.  999001621         105
# 105  We have previously shown that the Guardian eve...  999001621         106
# 106  It is openly publishing Goebbels' cartoons and...  999001621         107
# 107  There is no longer any line that it does not d...  999001621         108
# 108  Unfortunately other 'western' media are not mu...  999001621         109
# 109  Within hours of being published the Guardian p...  999001621         110
# 110  That did not hinder other outlets to add to it...  999001621         111
# 111  Politico allowed "a former CIA officer," writi...  999001621         112
# 112  Rather than being the bombshell smoking gun th...  999001621         113
# 113  Is it possible someone planted this story as a...  999001621         114
# 114                                                ...  999001621         115
# 115  Harding is likely a major target for anyone wr...  999001621         116
# 116                                                ...  999001621         117
# 117  If this latest story about Manafort and Assang...  999001621         118
# 118  The is zero evidence in the Politico screed th...  999001621         119
# 119           It is fake news about a fake news story.  999001621         120
# 120  It also included the false claim that Glenn Gr...  999001621         121
# 121                      That claim was later removed.  999001621         122
# 122  We have seen a similar pattern in the Skripal ...  999001621         123
# 123  When 'western' intelligence get caught in spre...  999001621         124
# 124  Unfortunately no western main stream media can...  999001621         125
# 125  The Guardian is only one of many which peddle ...  999001621         126
# 126  It is on all of us to debunk them and to educa...  999001621         127
# 127                                                ---  999001621         128
# 128         This is a Moon of Alabama fundraiser week.  999001621         129
# 129          No one pays me to write these blog posts.  999001621         130
# 130  If you appreciated this one, or any of the 7,0...  999001621         131
# 131  Posted by b on November 29, 2018 at 10:23 AM |...  999001621         132
# 132                                           Comments  999001621         133
#
#       is_propaganda  target
# 0    non-propaganda       0
# 2    non-propaganda       0
# 4        propaganda       1
# 6    non-propaganda       0
# 8    non-propaganda       0
# 10       propaganda       1
# 12   non-propaganda       0
# 13       propaganda       1
# 14       propaganda       1
# 16   non-propaganda       0
# 18   non-propaganda       0
# 19   non-propaganda       0
# 20       propaganda       1
# 22   non-propaganda       0
# 24       propaganda       1
# 26       propaganda       1
# 27   non-propaganda       0
# 29   non-propaganda       0
# 30   non-propaganda       0
# 32       propaganda       1
# 34   non-propaganda       0
# 35   non-propaganda       0
# 37   non-propaganda       0
# 38   non-propaganda       0
# 39   non-propaganda       0
# 41   non-propaganda       0
# 43   non-propaganda       0
# 45   non-propaganda       0
# 0    non-propaganda       0
# 2        propaganda       1
# ..              ...     ...
# 103      propaganda       1
# 104      propaganda       1
# 105      propaganda       1
# 106      propaganda       1
# 107      propaganda       1
# 108      propaganda       1
# 109  non-propaganda       0
# 110      propaganda       1
# 111      propaganda       1
# 112      propaganda       1
# 113      propaganda       1
# 114  non-propaganda       0
# 115  non-propaganda       0
# 116  non-propaganda       0
# 117  non-propaganda       0
# 118      propaganda       1
# 119      propaganda       1
# 120  non-propaganda       0
# 121  non-propaganda       0
# 122  non-propaganda       0
# 123  non-propaganda       0
# 124      propaganda       1
# 125      propaganda       1
# 126      propaganda       1
# 127  non-propaganda       0
# 128  non-propaganda       0
# 129  non-propaganda       0
# 130  non-propaganda       0
# 131  non-propaganda       0
# 132  non-propaganda       0
#
# [14263 rows x 5 columns]

# %% [markdown]
# ### Clean the text

# %%
lemmatizer = WordNetLemmatizer()
stop_words = stopwords.words("english")

# %%
cvec = CountVectorizer()
tokenizer = cvec.build_tokenizer()

# %%
def clean_text(text):
    
    # Remove special chars and punctuation
    text = " ".join(tokenizer(text))
    
    # lowcase
    text = text.lower()
    
    # Lematize
    text = [lemmatizer.lemmatize(token) for token in text.split(" ")]
    
    # Lematize
    text = [lemmatizer.lemmatize(token, "v") for token in text]
    
    # Remove stopwords
    text = [word for word in text if not word in stop_words]
    
    text = " ".join(text)
    
    return text

# %%
df['sentences_prep'] = df['sentences'].apply(clean_text)

# %%
df['len'] = df['sentences_prep'].apply(lambda x: len(x.split()))

# %%
df = df[df['len']>3]

# %% [markdown]
# ## Make the splits

# %%
# The whole sample is split on 3 parts - dev, val, test
art_id_dev, art_id_val = train_test_split(df['article'].unique(), test_size = 0.25, random_state = 42)

# %%
print(art_id_dev.size)
print(art_id_val.size)
# Out:
# 219
# 74

# %%
df_dev = df[df['article'].isin(art_id_dev)]
df_val = df[df['article'].isin(art_id_val)]

# %%
df_dev['sample'] = 'dev'
df_val['sample'] = 'val'
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Sample sizes
print(df_dev.shape)
print(df_val.shape)
# Out:
# (9342, 8)
# (2804, 8)

# %%
# Check the length of the longest text
df_dev['sentences_prep'].apply(lambda x: len(x.split(" "))).mean()
# Out:
# 13.400449582530507

# %%
df_dev['sentences_prep'].apply(lambda x: len(x.split(" "))).describe()
# Out:
# count    9342.000000
# mean       13.400450
# std         8.032138
# min         4.000000
# 25%         7.000000
# 50%        12.000000
# 75%        17.000000
# max        74.000000
# Name: sentences_prep, dtype: float64

# %% [markdown]
# ## Prepare for modelling

# %%
features = 'sentences_prep'

# %%
# Dev

# Prepare the X
df_dev_x = df_dev[features]

# Prepare the y
df_dev_y = df_dev['target'].ravel()

# %%
# Val

# Prepare the X
df_val_x = df_val[features]

# Prepare the y
df_val_y = df_val['target'].ravel()

# %% [markdown]
# ### Tokenization

# %%
max_features = 6000
tokenizer = Tokenizer(num_words = max_features)

# %%
tokenizer.fit_on_texts(df_dev_x)

# %%
df_dev_x_tokens = tokenizer.texts_to_sequences(df_dev_x)
df_val_x_tokens = tokenizer.texts_to_sequences(df_val_x)

# %% [markdown]
# ### Padding

# %%
max_sequence_length = 14

# %%
df_dev_x_pad = pad_sequences(df_dev_x_tokens, maxlen=max_sequence_length)
df_val_x_pad = pad_sequences(df_val_x_tokens, maxlen=max_sequence_length)

# %% [markdown]
# ## Modelling

# %%
embed_size = 100

# %%
model = Sequential()
model.add(Embedding(max_features, embed_size))
model.add(Bidirectional(LSTM(32, return_sequences=True)))
model.add(GlobalMaxPool1D())
model.add(Dense(20, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(1, activation="sigmoid"))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 100)         600000
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, None, 64)          34048
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                1300
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 635,369
# Trainable params: 635,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(df_dev_x_pad, df_dev_y, batch_size=32, epochs=10)
# Out:
# Epoch 1/10
# 9342/9342 [==============================] - 8s 831us/step - loss: 0.5862 - acc: 0.7065
# Epoch 2/10
# 9342/9342 [==============================] - 7s 699us/step - loss: 0.4361 - acc: 0.8054
# Epoch 3/10
# 9342/9342 [==============================] - 7s 718us/step - loss: 0.3177 - acc: 0.8698
# Epoch 4/10
# 9342/9342 [==============================] - 7s 701us/step - loss: 0.2329 - acc: 0.9102
# Epoch 5/10
# 9342/9342 [==============================] - 7s 703us/step - loss: 0.1691 - acc: 0.9390
# Epoch 6/10
# 9342/9342 [==============================] - 7s 702us/step - loss: 0.1281 - acc: 0.9570
# Epoch 7/10
# 9342/9342 [==============================] - 7s 708us/step - loss: 0.0957 - acc: 0.9669
# Epoch 8/10
# 9342/9342 [==============================] - 7s 747us/step - loss: 0.0762 - acc: 0.9768
# Epoch 9/10
# 9342/9342 [==============================] - 7s 756us/step - loss: 0.0634 - acc: 0.9803
# Epoch 10/10
# 9342/9342 [==============================] - 7s 743us/step - loss: 0.0519 - acc: 0.9819

# %% [markdown]
# ### Check the performance

# %%
# dev
df_dev_y_pred = model.predict(df_dev_x_pad, verbose=1).round()
# Out:
# 9342/9342 [==============================] - 1s 114us/step

# %%
print('F1-score: {0}'.format(f1_score(df_dev_y_pred, df_dev_y)))
confusion_matrix(df_dev_y_pred, df_dev_y)
# Out:
# F1-score: 0.9837685250529287
# array([[6462,   25],
#        [  67, 2788]], dtype=int64)

# %%
# val
df_val_y_pred = model.predict(df_val_x_pad, verbose=1).round()
# Out:
# 2804/2804 [==============================] - 0s 103us/step

# %%
print('F1-score: {0}'.format(f1_score(df_val_y_pred, df_val_y)))
confusion_matrix(df_val_y_pred, df_val_y)
# Out:
# F1-score: 0.413968253968254
# array([[1555,  415],
#        [ 508,  326]], dtype=int64)
