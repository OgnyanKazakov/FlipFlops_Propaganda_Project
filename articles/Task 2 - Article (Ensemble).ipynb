# %% [markdown]
# # Summary

# %% [markdown]
# For Task 2 (Sentence classification), we decided to develop multiple models independently and ensemble them into one final classifier. <br>We tried both <b>Stacking</b> via Logistic Regression and <b>Majority Voting</b> as ensembling strategies. We chose to go with <b>Stacking</b> as it performed better on the DEV set.

# %% [markdown]
# # Components

# %% [markdown]
# In short, we developed the following 4 components:
# 1. Random Forest classifier over Glove-based sentence embeddings
# 2. Neural Net with LSTM layer
# 3. XGB classifier over W2V-based sentence embeddings
# 4. Predictions of Task 3 Model (Neural Net)

# %% [markdown]
# # Import Components

# %%
import pandas as pd
import numpy as np
import os
import pickle

path = r"C:\Projects\Propaganda Detection\FlipFlops_Propaganda_Project"

# %%
mod_1_rf_train = pd.read_pickle(os.path.join(path,"modelling","task2","result_task2_train_niki.pkl"))
print(mod_1_rf_train.shape)
mod_1_rf_train.head(10)
# Out:
# (15170, 4)
#          aid sid  rf_200d_slen_SCORE  rf_200d_slen_PRED
# 0  111111112   1            0.416656                  0
# 1  111111112   2            0.427768                  0
# 2  111111112   3            0.431391                  0
# 3  111111112   4            0.427768                  0
# 4  111111112   5            0.503309                  1
# 5  111111112   6            0.427768                  0
# 6  111111112   7            0.454190                  0
# 7  111111112   8            0.427768                  0
# 8  111111112   9            0.504925                  1
# 9  111111112  10            0.427768                  0

# %%
mod_23_nn_xgb_train = pd.read_csv(os.path.join(path,"modelling","task2","task2_train_scoring.csv"))
print(mod_23_nn_xgb_train.shape)
mod_23_nn_xgb_train.head(10)
# Out:
# (15170, 4)
#    article_id  N_sentence  lstm_v_sent  xgb_v_sent
# 0   111111112           1     0.000220    0.163508
# 1   111111112           2     0.430642    0.137205
# 2   111111112           3     0.000388    0.222913
# 3   111111112           4     0.430642    0.137205
# 4   111111112           5     0.999856    0.678963
# 5   111111112           6     0.430642    0.137205
# 6   111111112           7     0.000011    0.260172
# 7   111111112           8     0.430642    0.137205
# 8   111111112           9     0.000744    0.235220
# 9   111111112          10     0.430642    0.137205

# %%
mod_4_nn_train = pd.read_csv(os.path.join(path,"modelling","task2","result_task2_TRAIN_mitko.txt"),
                             sep="\t",names=["aid","sid","mod_4_nn_PRED"])
print(mod_4_nn_train.shape)
mod_4_nn_train.head(10)
# Out:
# (15170, 3)
#          aid  sid mod_4_nn_PRED
# 0  111111112    1    propaganda
# 1  111111112    2    propaganda
# 2  111111112    3    propaganda
# 3  111111112    4    propaganda
# 4  111111112    5    propaganda
# 5  111111112    6    propaganda
# 6  111111112    7    propaganda
# 7  111111112    8    propaganda
# 8  111111112    9    propaganda
# 9  111111112   10    propaganda

# %%
mod_4_nn_train["mod_4_nn_PRED"].value_counts()
# Out:
# propaganda        14956
# non-propaganda      214
# Name: mod_4_nn_PRED, dtype: int64

# %% [markdown]
# # Import Performance

# %%
path2 = r"C:\Projects\Propaganda Detection"
task2_train_flag = pd.read_pickle(os.path.join(path2,"Data","task2_train_sent_flag.pkl"))
print(task2_train_flag.shape)
task2_train_flag.head(10)
# Out:
# (15170, 7)
#          aid sid                                           sentence  \
# 0  111111112   1                US bloggers banned from entering UK
# 1  111111112   2
# 2  111111112   3  Two prominent US bloggers have been banned fro...
# 3  111111112   4
# 4  111111112   5  Pamela Geller and Robert Spencer co-founded an...
# 5  111111112   6
# 6  111111112   7  They were due to speak at an English Defence L...
# 7  111111112   8
# 8  111111112   9  A government spokesman said individuals whose ...
# 9  111111112  10
#
#              flag  flag_bin  slen_ch  slen_w
# 0  non-propaganda         0       35       6
# 1  non-propaganda         0        0       0
# 2  non-propaganda         0       90      16
# 3  non-propaganda         0        0       0
# 4      propaganda         1       91      14
# 5  non-propaganda         0        0       0
# 6  non-propaganda         0      106      19
# 7  non-propaganda         0        0       0
# 8  non-propaganda         0      133      20
# 9  non-propaganda         0        0       0

# %% [markdown]
# # Evaluate Individual Components

# %%
mod_1_rf_train["key"] = mod_1_rf_train["aid"].map(str)+"_"+mod_1_rf_train["sid"].map(str)
mod_23_nn_xgb_train["key"] = mod_23_nn_xgb_train["article_id"].map(str)+"_"+mod_23_nn_xgb_train["N_sentence"].map(str)
mod_4_nn_train["key"] = mod_4_nn_train["aid"].map(str)+"_"+mod_4_nn_train["sid"].map(str)
task2_train_flag["key"] = task2_train_flag["aid"].map(str)+"_"+task2_train_flag["sid"]
task2_train_flag.head()
# Out:
#          aid sid                                           sentence  \
# 0  111111112   1                US bloggers banned from entering UK
# 1  111111112   2
# 2  111111112   3  Two prominent US bloggers have been banned fro...
# 3  111111112   4
# 4  111111112   5  Pamela Geller and Robert Spencer co-founded an...
#
#              flag  flag_bin  slen_ch  slen_w          key
# 0  non-propaganda         0       35       6  111111112_1
# 1  non-propaganda         0        0       0  111111112_2
# 2  non-propaganda         0       90      16  111111112_3
# 3  non-propaganda         0        0       0  111111112_4
# 4      propaganda         1       91      14  111111112_5

# %%
mod_1234_train = mod_1_rf_train.set_index("key")[["rf_200d_slen_SCORE","rf_200d_slen_PRED"]].join(task2_train_flag.set_index("key"))
print(mod_1234_train.shape)
mod_1234_train.head(10)
# Out:
# (15170, 9)
#               rf_200d_slen_SCORE  rf_200d_slen_PRED        aid sid  \
# key
# 111111112_1             0.416656                  0  111111112   1
# 111111112_2             0.427768                  0  111111112   2
# 111111112_3             0.431391                  0  111111112   3
# 111111112_4             0.427768                  0  111111112   4
# 111111112_5             0.503309                  1  111111112   5
# 111111112_6             0.427768                  0  111111112   6
# 111111112_7             0.454190                  0  111111112   7
# 111111112_8             0.427768                  0  111111112   8
# 111111112_9             0.504925                  1  111111112   9
# 111111112_10            0.427768                  0  111111112  10
#
#                                                        sentence  \
# key
# 111111112_1                 US bloggers banned from entering UK
# 111111112_2
# 111111112_3   Two prominent US bloggers have been banned fro...
# 111111112_4
# 111111112_5   Pamela Geller and Robert Spencer co-founded an...
# 111111112_6
# 111111112_7   They were due to speak at an English Defence L...
# 111111112_8
# 111111112_9   A government spokesman said individuals whose ...
# 111111112_10
#
#                         flag  flag_bin  slen_ch  slen_w
# key
# 111111112_1   non-propaganda         0       35       6
# 111111112_2   non-propaganda         0        0       0
# 111111112_3   non-propaganda         0       90      16
# 111111112_4   non-propaganda         0        0       0
# 111111112_5       propaganda         1       91      14
# 111111112_6   non-propaganda         0        0       0
# 111111112_7   non-propaganda         0      106      19
# 111111112_8   non-propaganda         0        0       0
# 111111112_9   non-propaganda         0      133      20
# 111111112_10  non-propaganda         0        0       0

# %%
mod_1234_train = mod_1234_train.join(mod_23_nn_xgb_train.set_index("key")[["lstm_v_sent","xgb_v_sent"]])
mod_1234_train.head(10)
# Out:
#               rf_200d_slen_SCORE  rf_200d_slen_PRED        aid sid  \
# key
# 111111112_1             0.416656                  0  111111112   1
# 111111112_2             0.427768                  0  111111112   2
# 111111112_3             0.431391                  0  111111112   3
# 111111112_4             0.427768                  0  111111112   4
# 111111112_5             0.503309                  1  111111112   5
# 111111112_6             0.427768                  0  111111112   6
# 111111112_7             0.454190                  0  111111112   7
# 111111112_8             0.427768                  0  111111112   8
# 111111112_9             0.504925                  1  111111112   9
# 111111112_10            0.427768                  0  111111112  10
#
#                                                        sentence  \
# key
# 111111112_1                 US bloggers banned from entering UK
# 111111112_2
# 111111112_3   Two prominent US bloggers have been banned fro...
# 111111112_4
# 111111112_5   Pamela Geller and Robert Spencer co-founded an...
# 111111112_6
# 111111112_7   They were due to speak at an English Defence L...
# 111111112_8
# 111111112_9   A government spokesman said individuals whose ...
# 111111112_10
#
#                         flag  flag_bin  slen_ch  slen_w  lstm_v_sent  \
# key
# 111111112_1   non-propaganda         0       35       6     0.000220
# 111111112_2   non-propaganda         0        0       0     0.430642
# 111111112_3   non-propaganda         0       90      16     0.000388
# 111111112_4   non-propaganda         0        0       0     0.430642
# 111111112_5       propaganda         1       91      14     0.999856
# 111111112_6   non-propaganda         0        0       0     0.430642
# 111111112_7   non-propaganda         0      106      19     0.000011
# 111111112_8   non-propaganda         0        0       0     0.430642
# 111111112_9   non-propaganda         0      133      20     0.000744
# 111111112_10  non-propaganda         0        0       0     0.430642
#
#               xgb_v_sent
# key
# 111111112_1     0.163508
# 111111112_2     0.137205
# 111111112_3     0.222913
# 111111112_4     0.137205
# 111111112_5     0.678963
# 111111112_6     0.137205
# 111111112_7     0.260172
# 111111112_8     0.137205
# 111111112_9     0.235220
# 111111112_10    0.137205

# %%
mod_1234_train = mod_1234_train.join(mod_4_nn_train.set_index("key")[["mod_4_nn_PRED"]])
mod_1234_train.head(10)
# Out:
#               rf_200d_slen_SCORE  rf_200d_slen_PRED        aid sid  \
# key
# 111111112_1             0.416656                  0  111111112   1
# 111111112_2             0.427768                  0  111111112   2
# 111111112_3             0.431391                  0  111111112   3
# 111111112_4             0.427768                  0  111111112   4
# 111111112_5             0.503309                  1  111111112   5
# 111111112_6             0.427768                  0  111111112   6
# 111111112_7             0.454190                  0  111111112   7
# 111111112_8             0.427768                  0  111111112   8
# 111111112_9             0.504925                  1  111111112   9
# 111111112_10            0.427768                  0  111111112  10
#
#                                                        sentence  \
# key
# 111111112_1                 US bloggers banned from entering UK
# 111111112_2
# 111111112_3   Two prominent US bloggers have been banned fro...
# 111111112_4
# 111111112_5   Pamela Geller and Robert Spencer co-founded an...
# 111111112_6
# 111111112_7   They were due to speak at an English Defence L...
# 111111112_8
# 111111112_9   A government spokesman said individuals whose ...
# 111111112_10
#
#                         flag  flag_bin  slen_ch  slen_w  lstm_v_sent  \
# key
# 111111112_1   non-propaganda         0       35       6     0.000220
# 111111112_2   non-propaganda         0        0       0     0.430642
# 111111112_3   non-propaganda         0       90      16     0.000388
# 111111112_4   non-propaganda         0        0       0     0.430642
# 111111112_5       propaganda         1       91      14     0.999856
# 111111112_6   non-propaganda         0        0       0     0.430642
# 111111112_7   non-propaganda         0      106      19     0.000011
# 111111112_8   non-propaganda         0        0       0     0.430642
# 111111112_9   non-propaganda         0      133      20     0.000744
# 111111112_10  non-propaganda         0        0       0     0.430642
#
#               xgb_v_sent mod_4_nn_PRED
# key
# 111111112_1     0.163508    propaganda
# 111111112_2     0.137205    propaganda
# 111111112_3     0.222913    propaganda
# 111111112_4     0.137205    propaganda
# 111111112_5     0.678963    propaganda
# 111111112_6     0.137205    propaganda
# 111111112_7     0.260172    propaganda
# 111111112_8     0.137205    propaganda
# 111111112_9     0.235220    propaganda
# 111111112_10    0.137205    propaganda

# %%
mod_1234_train["mod_4_nn_SCORE"] = (mod_1234_train["mod_4_nn_PRED"]=="propaganda").map(int)
mod_1234_train.head(10)
# Out:
#               rf_200d_slen_SCORE  rf_200d_slen_PRED        aid sid  \
# key
# 111111112_1             0.416656                  0  111111112   1
# 111111112_2             0.427768                  0  111111112   2
# 111111112_3             0.431391                  0  111111112   3
# 111111112_4             0.427768                  0  111111112   4
# 111111112_5             0.503309                  1  111111112   5
# 111111112_6             0.427768                  0  111111112   6
# 111111112_7             0.454190                  0  111111112   7
# 111111112_8             0.427768                  0  111111112   8
# 111111112_9             0.504925                  1  111111112   9
# 111111112_10            0.427768                  0  111111112  10
#
#                                                        sentence  \
# key
# 111111112_1                 US bloggers banned from entering UK
# 111111112_2
# 111111112_3   Two prominent US bloggers have been banned fro...
# 111111112_4
# 111111112_5   Pamela Geller and Robert Spencer co-founded an...
# 111111112_6
# 111111112_7   They were due to speak at an English Defence L...
# 111111112_8
# 111111112_9   A government spokesman said individuals whose ...
# 111111112_10
#
#                         flag  flag_bin  slen_ch  slen_w  lstm_v_sent  \
# key
# 111111112_1   non-propaganda         0       35       6     0.000220
# 111111112_2   non-propaganda         0        0       0     0.430642
# 111111112_3   non-propaganda         0       90      16     0.000388
# 111111112_4   non-propaganda         0        0       0     0.430642
# 111111112_5       propaganda         1       91      14     0.999856
# 111111112_6   non-propaganda         0        0       0     0.430642
# 111111112_7   non-propaganda         0      106      19     0.000011
# 111111112_8   non-propaganda         0        0       0     0.430642
# 111111112_9   non-propaganda         0      133      20     0.000744
# 111111112_10  non-propaganda         0        0       0     0.430642
#
#               xgb_v_sent mod_4_nn_PRED  mod_4_nn_SCORE
# key
# 111111112_1     0.163508    propaganda               1
# 111111112_2     0.137205    propaganda               1
# 111111112_3     0.222913    propaganda               1
# 111111112_4     0.137205    propaganda               1
# 111111112_5     0.678963    propaganda               1
# 111111112_6     0.137205    propaganda               1
# 111111112_7     0.260172    propaganda               1
# 111111112_8     0.137205    propaganda               1
# 111111112_9     0.235220    propaganda               1
# 111111112_10    0.137205    propaganda               1

# %% [markdown]
# # Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, f1_score

# %%
#Train-Test split
train_ids = np.random.choice(mod_1234_train["aid"].unique(),size=220,replace=False)
train_ids
# Out:
# array([ 729303442,  999000870,  787668628,  729670169,  789615291,
#         999000145,  770945799,  725498022,  701225819,  754508491,
#         777488669,  741655444,  999000880,  778139122,  999001621,
#         763761219,  764518567,  758472954,  757843275,  703806098,
#         729578579,  721890296,  761564397,  999000159,  712382330,
#         729348908,  758756657,  788900262,  795693029,  736231219,
#         758882558, 7651970399,  762206044,  761610997,  727736557,
#         111111112,  999001226,  711566593,  732154721,  771406408,
#         790665855,  730222442,  999000147,  733754480, 7709564349,
#         724095598,  738060046,  111111137,  730573740,  787759779,
#         770376380,  718312499,  701553469,  790266787,  764609985,
#         754111899,  757243988,  725238842,  774145019,  741802985,
#         789121798,  698018235,  706636401,  731178960,  770156851,
#         761546223,  758812201,  705409419,  762147609,  700551604,
#         782086447,  728343601,  755459860,  729940206,  790720480,
#         762956953,  761874505,  727174208,  715790840,  762340819,
#         999001188,  776616374,  776368676,  786344683,  773937361,
#         781847297,  727405181,  729581752,  786250729,  728680557,
#         703698295,  761674108,  731762731,  793921939,  715588833,
#         711596363,  790483991,  999001241,  737255982,  756114837,
#         774637726,  696735702,  769962328,  757713354,  697444415,
#         697959084,  771546417,  776049384,  759468687,  728972961,
#         762546428,  752287274,  727736595,  737194975, 7709388279,
#         786527921,  757611486,  706661242,  755170235,  727634031,
#         711964584,  999000849,  763260610,  759337941,  780414700,
#         724791253,  999000312,  788173482,  729700539,  729549972,
#         790777028,  781768042,  704856340,  776373795,  111111113,
#         762160164,  698092698,  732610971,  783702663,  757964238,
#         701837665,  735815173,  111111122,  696264594,  788726416,
#         755393220,  697996062, 7618970899, 7385423989,  765953146,
#         723883127,  695108099,  727497152,  740356006,  727658675,
#         730559808,  769752554,  702077783,  774904810,  788816478,
#         694327499,  795691173,  793467906,  795079843,  769427494,
#         754179642,  723823436,  711622457,  772947654,  739140767,
#         737457870,  706600938,  795379208,  721406153,  701939679,
#         727869189,  728169864,  729561658,  704591553,  761780613,
#         771254016,  713130996,  754231597,  790677230,  771655795,
#         765913191,  999001296,  732708002,  764715911,  758469195,
#         763440871,  793534424,  770956434,  780786973,  696694316,
#         790720714,  765982381,  789370909,  769682854,  761897089,
#         766942310,  695833178,  786919720,  770581969,  773520636,
#         728758697,  782017101,  788056108,  710376094,  731063195,
#         761334950,  769962236,  716469423,  758669180,  775448623,
#         730268758,  759478604,  757171650,  999001293,  754348478],
#       dtype=int64)

# %%
model_vars = ["rf_200d_slen_SCORE","lstm_v_sent","xgb_v_sent","mod_4_nn_SCORE"]

X_train = mod_1234_train.loc[mod_1234_train["aid"].isin(train_ids)][model_vars]
y_train = mod_1234_train.loc[mod_1234_train["aid"].isin(train_ids)]["flag_bin"]

X_test = mod_1234_train.loc[~mod_1234_train["aid"].isin(train_ids)][model_vars]
y_test = mod_1234_train.loc[~mod_1234_train["aid"].isin(train_ids)]["flag_bin"]

print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (11591, 4) (11591,) (3579, 4) (3579,)

# %%
ensemble_v1 = LogisticRegression(C=5)
ensemble_v1.fit(X_train,y_train)

print("F1 Train:",f1_score(y_train,ensemble_v1.predict(X_train)))
print("F1 Test:",f1_score(y_test,ensemble_v1.predict(X_test)))

print("Gini Train:",2*roc_auc_score(y_train,ensemble_v1.predict_proba(X_train)[:,1])-1)
print("Gini Test:",2*roc_auc_score(y_test,ensemble_v1.predict_proba(X_test)[:,1])-1)
# Out:
# F1 Train: 0.8349480359344725
# F1 Test: 0.8365384615384616
# Gini Train: 0.8793627823045815
# Gini Test: 0.883550721160087

# %%
with open(os.path.join(path2,"Models","ensemble_v1.pkl"),"wb") as f:
    pickle.dump(ensemble_v1,f,protocol=-1)
